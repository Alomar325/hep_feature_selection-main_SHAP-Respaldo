# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/Users/Alex/Downloads/atlas-higgs-challenge-2014-v2.csv")

# %%
df.head()
# Out:
#    EventId  DER_mass_MMC  DER_mass_transverse_met_lep  DER_mass_vis  DER_pt_h  \
# 0   100000       138.470                       51.655        97.827    27.980
# 1   100001       160.937                       68.768       103.235    48.146
# 2   100002      -999.000                      162.172       125.953    35.635
# 3   100003       143.905                       81.417        80.943     0.414
# 4   100004       175.864                       16.915       134.805    16.405
#
#    DER_deltaeta_jet_jet  DER_mass_jet_jet  DER_prodeta_jet_jet  \
# 0                  0.91           124.711                2.666
# 1               -999.00          -999.000             -999.000
# 2               -999.00          -999.000             -999.000
# 3               -999.00          -999.000             -999.000
# 4               -999.00          -999.000             -999.000
#
#    DER_deltar_tau_lep  DER_pt_tot  ...  PRI_jet_leading_eta  \
# ...

# %%
df['Label']
# Out:
# 0         s
# 1         b
# 2         b
# 3         b
# 4         b
#          ..
# 818233    s
# 818234    s
# 818235    b
# 818236    b
# 818237    b
# Name: Label, Length: 818238, dtype: object

# %%
contS = 0
contB = 0
for i in df['Label']:
    if (i == 's'):
        contS = contS + 1
    else:
        contB = contB + 1
        
print("contS: ",contS)
print("contB:",contB)
# Out:
# contS:  279560
# contB: 538678

# %%
df2 = df.replace('s', 1)
df2.head()
df3 = df2.replace('b', 0)

# %%
df3['Label']
# Out:
# 0         1
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 818233    1
# 818234    1
# 818235    0
# 818236    0
# 818237    0
# Name: Label, Length: 818238, dtype: int64

# %%
#df3 = df3.drop(labels=['KaggleSet','EventId','index', 'KaggleWeight', 'Weight'], axis=1) 
#este es para cuando se usa el set de adatos reducido
df3 = df3.drop(labels=['KaggleSet','EventId', 'KaggleWeight', 'Weight'], axis=1)
#este con el total de los datos
df3.head()
# Out:
#    DER_mass_MMC  DER_mass_transverse_met_lep  DER_mass_vis  DER_pt_h  \
# 0       138.470                       51.655        97.827    27.980
# 1       160.937                       68.768       103.235    48.146
# 2      -999.000                      162.172       125.953    35.635
# 3       143.905                       81.417        80.943     0.414
# 4       175.864                       16.915       134.805    16.405
#
#    DER_deltaeta_jet_jet  DER_mass_jet_jet  DER_prodeta_jet_jet  \
# 0                  0.91           124.711                2.666
# 1               -999.00          -999.000             -999.000
# 2               -999.00          -999.000             -999.000
# 3               -999.00          -999.000             -999.000
# 4               -999.00          -999.000             -999.000
#
#    DER_deltar_tau_lep  DER_pt_tot  DER_sum_pt  ...  PRI_met_sumet  \
# 0               3.064      41.928     197.760  ...        258.733
# ...

# %%
df3.to_csv('/Users/Alex/Downloads/Pre-procesado_completo.csv', index=False)

# %%
df3.iloc[:,[-3,1,2,3,4,5,6]]
# Out:
#         PRI_jet_subleading_phi  DER_mass_transverse_met_lep  DER_mass_vis  \
# 0                       -2.475                       51.655        97.827
# 1                     -999.000                       68.768       103.235
# 2                     -999.000                      162.172       125.953
# 3                     -999.000                       81.417        80.943
# 4                     -999.000                       16.915       134.805
# ...                        ...                          ...           ...
# 818233                  -1.090                       46.443        60.048
# 818234                   2.893                       30.097        62.713
# 818235                -999.000                        9.837        65.149
# 818236                -999.000                       20.006        66.942
# 818237                -999.000                       80.109        77.619
#
#         DER_pt_h  DER_deltaeta_jet_jet  DER_mass_jet_jet  DER_prodeta_jet_jet
# ...

# %%
df.iloc[:,[-3,1,2,3,4,5,6]]
# Out:
#        Label  DER_mass_MMC  DER_mass_transverse_met_lep  DER_mass_vis  \
# 0          s       138.470                       51.655        97.827
# 1          b       160.937                       68.768       103.235
# 2          b      -999.000                      162.172       125.953
# 3          b       143.905                       81.417        80.943
# 4          b       175.864                       16.915       134.805
# ...      ...           ...                          ...           ...
# 818233     s       105.668                       46.443        60.048
# 818234     s        99.294                       30.097        62.713
# 818235     b       108.497                        9.837        65.149
# 818236     b        96.711                       20.006        66.942
# 818237     b        92.373                       80.109        77.619
#
#         DER_pt_h  DER_deltaeta_jet_jet  DER_mass_jet_jet
# 0         27.980                 0.910           124.711
# ...

# %%
invalidos = 0
valores=0
for i in df['DER_mass_jet_jet']: #dentro del df se cambia las variables para hacer el promedio
    if(i>=-998.000):
        valores = i + valores
promedio = valores/818238
print(promedio)
df3.loc[df3.DER_mass_jet_jet<(-998.000),'DER_mass_jet_jet']=promedio
df3.head()
# Out:
# 13.21682334724112
#     index  EventId  DER_mass_MMC  DER_mass_transverse_met_lep  DER_mass_vis  \
# 0  138682   238682        85.123                        5.111        45.454
# 1  271291   371291        70.751                       16.532        47.178
# 2  489566   589566      -999.000                       79.211        77.286
# 3  377268   477268        74.959                       58.796        58.484
# 4  323429   423429      -999.000                       82.701       109.640
#
#    DER_pt_h  DER_deltaeta_jet_jet  DER_mass_jet_jet  DER_prodeta_jet_jet  \
# 0   139.856              -999.000         13.216823             -999.000
# 1   107.916                 4.446        442.881000               -4.514
# 2     0.998              -999.000         13.216823             -999.000
# 3    24.962              -999.000         13.216823             -999.000
# 4     2.044              -999.000         13.216823             -999.000
#
# ...
