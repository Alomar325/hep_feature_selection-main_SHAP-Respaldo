# %% [markdown]
# # Random Forest
#
# ### Clasificación de eventos usando Random Forest como seleccionador de características.

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------
#
# Alex Toro, Raquel Pezoa

# %% [markdown]
# ## Librerias necesarias.
# -------------------------------------------------------------------------------------------------------------------------------

# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import SelectFromModel
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error

# %%
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
import numpy as np
from scipy.stats import randint

# %%
import xgboost as xgb

# %%
from sklearn.metrics import confusion_matrix, f1_score, precision_score, recall_score, accuracy_score, classification_report, roc_curve, auc, roc_auc_score, ConfusionMatrixDisplay

# %%
import winsound

# %% [markdown]
# ## Lectura del set de datos reducido.
#
# - El set original proviene de https://www.kaggle.com/competitions/higgs-boson/data.
# - Separación de la variable Label de las demas variables.
# -------------------------------------------------------------------------------------------------------------------------------

# %%
df = pd.read_csv("/Users/Alex/Downloads/Pre-procesado.csv")

# %%
X = df.drop(labels=['Label'], axis=1)
Y = df['Label']

# %% [markdown]
# ### Entrenamiento y testeo del set de datos.
# -------------------------------------------------------------------------------------------------------------------------------

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    Y,
    test_size=0.2,
    random_state=0)

# %%
params = {
    'max_depth': [3, None],
    'max_features': randint(1,11),
    'min_samples_split': randint(2,11),
    'bootstrap': [True, False],
    'criterion': ['gini', 'entropy']
}

# %%
classifier=RandomForestClassifier(n_estimators = 100)

# %%
random_search=RandomizedSearchCV(classifier,param_distributions=params,n_iter=5,scoring='roc_auc',n_jobs=-1,cv=5,verbose=3)

# %%
random_search.fit(X_train,y_train) # el de 5 iteraciones
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# RandomizedSearchCV(cv=5, estimator=RandomForestClassifier(), n_iter=5,
#                    n_jobs=-1,
#                    param_distributions={'bootstrap': [True, False],
#                                         'criterion': ['gini', 'entropy'],
#                                         'max_depth': [3, None],
#                                         'max_features': <scipy.stats._distn_infrastructure.rv_frozen object at 0x000001F374765820>,
#                                         'min_samples_split': <scipy.stats._distn_infrastructure.rv_frozen object at 0x000001F3747711C0>},
#                    scoring='roc_auc', verbose=3)

# %%
frequency = 2500  # Set Frequency To 2500 Hertz
duration = 1000  # Set Duration To 1000 ms == 1 second
winsound.Beep(frequency, duration)

# %%
print(random_search.best_estimator_) # 5 iteraciones
# Out:
# RandomForestClassifier(bootstrap=False, criterion='entropy', max_features=10,
#                        min_samples_split=9)

# %%
random_search.best_params_ # 5 iteraciones
# Out:
# {'bootstrap': False,
#  'criterion': 'entropy',
#  'max_depth': None,
#  'max_features': 10,
#  'min_samples_split': 9}

# %%
n_top=3
results = random_search.cv_results_
for i in range(1, n_top + 1):
        candidates = np.flatnonzero(results['rank_test_score'] == i)
        for candidate in candidates:
            print('Model with rank: {0}'.format(i))
            print('Mean validation score: {0:.3f}(std: {1:.3f})'.format(
                results['mean_test_score'][candidate],
                results['std_test_score'][candidate]))
            print('Parameters: {0}'.format(results['params'][candidate]))
# Out:
# Model with rank: 1
# Mean validation score: 0.915(std: 0.001)
# Parameters: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': None, 'max_features': 10, 'min_samples_split': 9}
# Model with rank: 2
# Mean validation score: 0.912(std: 0.001)
# Parameters: {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 9, 'min_samples_split': 5}
# Model with rank: 3
# Mean validation score: 0.904(std: 0.001)
# Parameters: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': None, 'max_features': 1, 'min_samples_split': 9}

# %%
rf1 = RandomForestClassifier(n_estimators = 100, bootstrap = False, criterion = 'entropy', max_depth = None, max_features = 1, min_samples_split = 3)
rf1.fit(X_train, y_train)
# hiperparametros antiguos
# Out:
# RandomForestClassifier(bootstrap=False, criterion='entropy', max_features=1,
#                        min_samples_split=3)

# %%
print(rf1.feature_importances_) #buscar feature_importance en selectfromModel
# Out:
# [0.09549952 0.06412228 0.06289983 0.03634691 0.01579276 0.01616013
#  0.01341635 0.05471252 0.03394398 0.04170525 0.04956286 0.04968814
#  0.01442577 0.05501579 0.03203015 0.03016646 0.03709096 0.03395019
#  0.0306198  0.04459101 0.03051717 0.03455092 0.00727869 0.02243115
#  0.02312174 0.01909337 0.00990632 0.0097354  0.00924167 0.0223829 ]

# %% [markdown]
# ### Convertir los datos a  una lista de duplas
#
# - Se convierte la matriz entregada por random forest junto a las columnas del dataframe en una lista de duplas.
# - Se realizan las duplas para así poder reordenar las variables de la más relevante a la menos relevante.
# - Se Reordena la duplas de mayor a menor.
# - Se separan las duplas en listas separadas y transformar las 10 primeras en arreglos de numpy.
# -------------------------------------------------------------------------------------------------------------------------------

# %%
l = []
for feature in zip(rf1.feature_importances_,X_train.columns):
    l.append(feature)
    print(feature)
# Out:
# (0.0954995244152823, 'DER_mass_MMC')
# (0.06412227704839256, 'DER_mass_transverse_met_lep')
# (0.06289982934819163, 'DER_mass_vis')
# (0.036346913967075165, 'DER_pt_h')
# (0.01579276250824943, 'DER_deltaeta_jet_jet')
# (0.016160130166373778, 'DER_mass_jet_jet')
# (0.013416346338076987, 'DER_prodeta_jet_jet')
# (0.05471252285584041, 'DER_deltar_tau_lep')
# (0.03394398152941655, 'DER_pt_tot')
# (0.04170524637280481, 'DER_sum_pt')
# (0.049562862355699136, 'DER_pt_ratio_lep_tau')
# (0.04968814374263328, 'DER_met_phi_centrality')
# (0.014425774921134124, 'DER_lep_eta_centrality')
# (0.05501578808148979, 'PRI_tau_pt')
# (0.03203015182442583, 'PRI_tau_eta')
# (0.030166459895721233, 'PRI_tau_phi')
# (0.0370909643679592, 'PRI_lep_pt')
# (0.03395018810118221, 'PRI_lep_eta')
# (0.030619798244363144, 'PRI_lep_phi')
# (0.044591013205984936, 'PRI_met')
# (0.030517170307146835, 'PRI_met_phi')
# (0.03455091865927812, 'PRI_met_sumet')
# (0.007278685109959044, 'PRI_jet_num')
# (0.022431150163789187, 'PRI_jet_leading_pt')
# (0.023121741273361925, 'PRI_jet_leading_eta')
# (0.019093370366386295, 'PRI_jet_leading_phi')
# (0.009906320094892231, 'PRI_jet_subleading_pt')
# (0.009735396725390016, 'PRI_jet_subleading_eta')
# (0.009241669332018566, 'PRI_jet_subleading_phi')
# (0.02238289867748124, 'PRI_jet_all_pt')

# %%
l.sort(reverse=True)

# %%
l
# Out:
# [(0.0954995244152823, 'DER_mass_MMC'),
#  (0.06412227704839256, 'DER_mass_transverse_met_lep'),
#  (0.06289982934819163, 'DER_mass_vis'),
#  (0.05501578808148979, 'PRI_tau_pt'),
#  (0.05471252285584041, 'DER_deltar_tau_lep'),
#  (0.04968814374263328, 'DER_met_phi_centrality'),
#  (0.049562862355699136, 'DER_pt_ratio_lep_tau'),
#  (0.044591013205984936, 'PRI_met'),
#  (0.04170524637280481, 'DER_sum_pt'),
#  (0.0370909643679592, 'PRI_lep_pt'),
#  (0.036346913967075165, 'DER_pt_h'),
#  (0.03455091865927812, 'PRI_met_sumet'),
#  (0.03395018810118221, 'PRI_lep_eta'),
#  (0.03394398152941655, 'DER_pt_tot'),
#  (0.03203015182442583, 'PRI_tau_eta'),
#  (0.030619798244363144, 'PRI_lep_phi'),
#  (0.030517170307146835, 'PRI_met_phi'),
#  (0.030166459895721233, 'PRI_tau_phi'),
#  (0.023121741273361925, 'PRI_jet_leading_eta'),
#  (0.022431150163789187, 'PRI_jet_leading_pt'),
#  (0.02238289867748124, 'PRI_jet_all_pt'),
#  (0.019093370366386295, 'PRI_jet_leading_phi'),
#  (0.016160130166373778, 'DER_mass_jet_jet'),
#  (0.01579276250824943, 'DER_deltaeta_jet_jet'),
#  (0.014425774921134124, 'DER_lep_eta_centrality'),
#  (0.013416346338076987, 'DER_prodeta_jet_jet'),
#  (0.009906320094892231, 'PRI_jet_subleading_pt'),
#  (0.009735396725390016, 'PRI_jet_subleading_eta'),
#  (0.009241669332018566, 'PRI_jet_subleading_phi'),
#  (0.007278685109959044, 'PRI_jet_num')]

# %%
l_i = []
l_v = []
for importance in range(len(l)):
    for var in range(len(l[importance])):
        if(var == 0):
            l_i.append(l[importance][var])
        else:
            l_v.append(l[importance][var])

# %%
import matplotlib.pyplot as plt
import numpy as np
y = np.array(l_i[0:10])
x = np.array(l_v[0:10])
x
# Out:
# array(['DER_mass_MMC', 'DER_mass_transverse_met_lep', 'DER_mass_vis',
#        'PRI_tau_pt', 'DER_deltar_tau_lep', 'DER_met_phi_centrality',
#        'DER_pt_ratio_lep_tau', 'PRI_met', 'DER_sum_pt', 'PRI_lep_pt'],
#       dtype='<U27')

# %% [markdown]
# ### Graficación de las variables más importantes.
#
# -------------------------------------------------------------------------------------------------------------------------------

# %%
import matplotlib
font = {'size'   : 16}
matplotlib.rc('font', **font)
fig = plt.figure(figsize = (20, 3))


# creating the bar plot
plt.ylabel("Importancia")
plt.bar(x, y, color ='green',
        width = 0.9)
plt.xticks(rotation=45, ha='right')
plt.title("Ranking Top 10 de variables usando Random forest")
plt.show()

# %%
X_train[x].head()
# Out:
#        DER_mass_MMC  DER_mass_transverse_met_lep  DER_mass_vis  PRI_tau_pt  \
# 10382        93.006                       10.659        62.099      33.106
# 73171       200.846                       71.571       136.744      33.480
# 30938       132.315                       64.473        96.538      68.190
# 99310       162.959                       36.183       119.743      39.265
# 58959       120.253                       30.144        82.176      39.923
#
#        DER_deltar_tau_lep  DER_pt_ratio_lep_tau  PRI_met  \
# 10382               0.801                 5.688  148.161
# 73171               3.534                 1.614   23.698
# 30938               2.572                 0.540   28.908
# 99310               3.470                 1.130    8.812
# 58959               2.551                 1.017   11.126
#
#        DER_met_phi_centrality  DER_sum_pt  DER_pt_h
# 10382                   1.097     633.979   362.070
# 73171                  -0.955      87.521    10.720
# 30938                  -1.297     158.490    55.634
# 99310                  -1.411      83.637     0.542
# 58959                   1.400     243.103    38.736

# %% [markdown]
# ### Entrenamiento, testeo y optimizacion de parametros de DMatrix de XGBoost con las variables entregadas por XGBoost.
# -------------------------------------------------------------------------------------------------------------------------------

# %%
X_BestFeature = X[x] 
X_train2, X_test2, y_train2, y_test2 = train_test_split(X_BestFeature, Y, test_size=0.2, random_state=0)

# %%
dtrain = xgb.DMatrix(X_train2, label=y_train2)
dtest = xgb.DMatrix(X_test2, label=y_test2)

# %%
params = {
    # Parameters that we are going to tune.
    'max_depth':6,
    'min_child_weight': 1,
    'eta':.3,
    'subsample': 1,
    'colsample_bytree': 1,
    # Other parameters
    'objective':'reg:linear',
}
params['eval_metric'] = "mae"
num_boost_round = 999

# %%
modelo = xgb.train( 
    params, 
    dtrain, 
    num_boost_round=num_boost_round, 
    evals=[(dtest, "Test")], 
    early_stopping_rounds=10 
)
# Out:
# [10:47:48] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	Test-mae:0.42984
# [1]	Test-mae:0.37938
# [2]	Test-mae:0.34352
# [3]	Test-mae:0.31679
# [4]	Test-mae:0.29681
# [5]	Test-mae:0.28322
# [6]	Test-mae:0.27271
# [7]	Test-mae:0.26478
# [8]	Test-mae:0.25946
# [9]	Test-mae:0.25542
# [10]	Test-mae:0.25219
# [11]	Test-mae:0.25057
# [12]	Test-mae:0.24862
# [13]	Test-mae:0.24797
# [14]	Test-mae:0.24735
# [15]	Test-mae:0.24690
# [16]	Test-mae:0.24673
# [17]	Test-mae:0.24649
# [18]	Test-mae:0.24602
# [19]	Test-mae:0.24550
# [20]	Test-mae:0.24543
# [21]	Test-mae:0.24543
# [22]	Test-mae:0.24536
# [23]	Test-mae:0.24540
# [24]	Test-mae:0.24525
# [25]	Test-mae:0.24519
# [26]	Test-mae:0.24506
# [27]	Test-mae:0.24479
# [28]	Test-mae:0.24460
# [29]	Test-mae:0.24433
# [30]	Test-mae:0.24432
# [31]	Test-mae:0.24442
# [32]	Test-mae:0.24421
# [33]	Test-mae:0.24426
# [34]	Test-mae:0.24416
# [35]	Test-mae:0.24416
# [36]	Test-mae:0.24406
# [37]	Test-mae:0.24403
# [38]	Test-mae:0.24402
# [39]	Test-mae:0.24412
# [40]	Test-mae:0.24406
# [41]	Test-mae:0.24362
# [42]	Test-mae:0.24353
# [43]	Test-mae:0.24341
# [44]	Test-mae:0.24339
# [45]	Test-mae:0.24350
# [46]	Test-mae:0.24357
# [47]	Test-mae:0.24357
# [48]	Test-mae:0.24362
# [49]	Test-mae:0.24371
# [50]	Test-mae:0.24372
# [51]	Test-mae:0.24378
# [52]	Test-mae:0.24380
# [53]	Test-mae:0.24378
# [54]	Test-mae:0.24376

# %%
print("Best MAE: {:.2f} with {} rounds".format(
                 modelo.best_score,
                 modelo.best_iteration+1))
# Out:
# Best MAE: 0.24 with 45 rounds

# %%
cv_results = xgb.cv( 
    params, 
    dtrain, 
    num_boost_round=num_boost_round, 
    seed=42, 
    nfold=5, 
    metrics={'mae'}, 
    early_stopping_rounds=10 
)
cv_results
# Out:
# [10:47:50] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:47:50] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:47:50] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:47:50] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:47:50] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
#     train-mae-mean  train-mae-std  test-mae-mean  test-mae-std
# 0         0.428908       0.000375       0.429864      0.000375
# 1         0.378095       0.000415       0.379803      0.000878
# 2         0.341319       0.000451       0.343775      0.001277
# 3         0.314272       0.000665       0.317372      0.001132
# 4         0.294485       0.000981       0.298258      0.001091
# ..             ...            ...            ...           ...
# 75        0.218667       0.000729       0.245052      0.002008
# 76        0.218511       0.000729       0.245073      0.001992
# 77        0.218270       0.000674       0.245059      0.001974
# 78        0.217995       0.000612       0.245038      0.002011
# 79        0.217710       0.000703       0.245010      0.001987
#
# [80 rows x 4 columns]

# %%
cv_results['test-mae-mean'].min()
# Out:
# 0.24500984330760928

# %%
gridsearch_params = [
    (max_depth, min_child_weight)
    for max_depth in range(9,12)
    for min_child_weight in range(5,8)
]

# %%
min_mae = float("Inf")
best_params = None
for max_depth, min_child_weight in gridsearch_params:
    print("CV with max_depth={}, min_child_weight={}".format(
                             max_depth,
                             min_child_weight))
    # Update our parameters
    params['max_depth'] = max_depth
    params['min_child_weight'] = min_child_weight
    # Run CV
    cv_results = xgb.cv(
        params,
        dtrain,
        num_boost_round=num_boost_round,
        seed=42,
        nfold=5,
        metrics={'mae'},
        early_stopping_rounds=10
    )
    # Update best MAE
    mean_mae = cv_results['test-mae-mean'].min()
    boost_rounds = cv_results['test-mae-mean'].argmin()
    print("\tMAE {} for {} rounds".format(mean_mae, boost_rounds))
    if mean_mae < min_mae:
        min_mae = mean_mae
        best_params = (max_depth,min_child_weight)
print("Best params: {}, {}, MAE: {}".format(best_params[0], best_params[1], min_mae))
frequency = 2500  # Set Frequency To 2500 Hertz
duration = 1000  # Set Duration To 1000 ms == 1 second
winsound.Beep(frequency, duration)
# Out:
# CV with max_depth=9, min_child_weight=5
# [10:48:04] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:48:04] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:48:04] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:48:04] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:48:04] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.24102446295498678 for 35 rounds
# CV with max_depth=9, min_child_weight=6
# [10:48:15] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:48:15] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:48:15] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:48:15] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:48:15] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.24226525531291268 for 24 rounds
# CV with max_depth=9, min_child_weight=7
# [10:48:23] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:48:23] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:48:23] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:48:23] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:48:23] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.24173097845833075 for 29 rounds
# CV with max_depth=10, min_child_weight=5
# [10:48:34] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:48:34] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:48:34] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:48:34] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:48:34] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.24072996699571764 for 28 rounds
# CV with max_depth=10, min_child_weight=6
# [10:48:44] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:48:45] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:48:45] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:48:45] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:48:45] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.2404792435464138 for 27 rounds
# CV with max_depth=10, min_child_weight=7
# [10:48:56] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:48:56] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:48:56] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:48:56] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:48:56] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.24047613713759466 for 26 rounds
# CV with max_depth=11, min_child_weight=5
# [10:49:06] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:49:06] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:49:07] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:49:07] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:49:07] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.23967963092853767 for 33 rounds
# CV with max_depth=11, min_child_weight=6
# [10:49:19] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:49:19] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:49:19] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:49:20] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:49:20] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.2395406022562144 for 28 rounds
# CV with max_depth=11, min_child_weight=7
# [10:49:31] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:49:31] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:49:31] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:49:31] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:49:31] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.23927067428016993 for 22 rounds
# Best params: 11, 7, MAE: 0.23927067428016993

# %%
params['max_depth'] = 11
params['min_child_weight'] = 7

# %%
gridsearch_params = [
    (subsample, colsample)
    for subsample in [i/10. for i in range(7,11)]
    for colsample in [i/10. for i in range(7,11)]
]

# %%
min_mae = float("Inf")
best_params = None
# We start by the largest values and go down to the smallest
for subsample, colsample in reversed(gridsearch_params):
    print("CV with subsample={}, colsample={}".format(
                             subsample,
                             colsample))
    # We update our parameters
    params['subsample'] = subsample
    params['colsample_bytree'] = colsample
    # Run CV
    cv_results = xgb.cv(
        params,
        dtrain,
        num_boost_round=num_boost_round,
        seed=42,
        nfold=5,
        metrics={'mae'},
        early_stopping_rounds=10
    )
    # Update best score
    mean_mae = cv_results['test-mae-mean'].min()
    boost_rounds = cv_results['test-mae-mean'].argmin()
    print("\tMAE {} for {} rounds".format(mean_mae, boost_rounds))
    if mean_mae < min_mae:
        min_mae = mean_mae
        best_params = (subsample,colsample)
print("Best params: {}, {}, MAE: {}".format(best_params[0], best_params[1], min_mae))
frequency = 2500  # Set Frequency To 2500 Hertz
duration = 1000  # Set Duration To 1000 ms == 1 second
winsound.Beep(frequency, duration)
# Out:
# CV with subsample=1.0, colsample=1.0
# [10:49:45] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:49:45] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:49:45] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:49:46] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:49:46] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.23927067428016993 for 22 rounds
# CV with subsample=1.0, colsample=0.9
# [10:49:55] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:49:55] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:49:55] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:49:55] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:49:55] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.24076591598473476 for 23 rounds
# CV with subsample=1.0, colsample=0.8
# [10:50:04] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:50:04] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:50:04] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:50:05] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:50:05] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.24261801966719876 for 25 rounds
# CV with subsample=1.0, colsample=0.7
# [10:50:14] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:50:14] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:50:14] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:50:14] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:50:14] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.24483939276367 for 30 rounds
# CV with subsample=0.9, colsample=1.0
# [10:50:23] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:50:23] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:50:23] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:50:24] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:50:24] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.24045803365992952 for 21 rounds
# CV with subsample=0.9, colsample=0.9
# [10:50:33] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:50:33] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:50:33] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:50:33] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:50:33] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.24162126439295517 for 20 rounds
# CV with subsample=0.9, colsample=0.8
# [10:50:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:50:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:50:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:50:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:50:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.24256076681027525 for 20 rounds
# CV with subsample=0.9, colsample=0.7
# [10:50:50] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:50:50] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:50:50] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:50:50] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:50:50] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.24464775244646883 for 20 rounds
# CV with subsample=0.8, colsample=1.0
# [10:50:57] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:50:57] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:50:57] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:50:57] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:50:57] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.24026630826661183 for 21 rounds
# CV with subsample=0.8, colsample=0.9
# [10:51:07] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:51:07] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:51:07] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:51:07] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:51:07] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.24201935710311479 for 21 rounds
# CV with subsample=0.8, colsample=0.8
# [10:51:15] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:51:15] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:51:15] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:51:15] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:51:15] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.24223602060480864 for 21 rounds
# CV with subsample=0.8, colsample=0.7
# [10:51:23] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:51:23] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:51:23] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:51:23] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:51:23] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.24489397086914194 for 22 rounds
# CV with subsample=0.7, colsample=1.0
# [10:51:31] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:51:31] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:51:31] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:51:31] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:51:31] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.2421459904623824 for 19 rounds
# CV with subsample=0.7, colsample=0.9
# [10:51:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:51:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:51:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:51:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:51:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.2442941835226211 for 20 rounds
# CV with subsample=0.7, colsample=0.8
# [10:51:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:51:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:51:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:51:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:51:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.24491859150648315 for 18 rounds
# CV with subsample=0.7, colsample=0.7
# [10:51:54] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:51:54] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:51:54] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:51:54] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:51:54] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.24675836507154672 for 17 rounds
# Best params: 1.0, 1.0, MAE: 0.23927067428016993

# %%
params['subsample'] = 1.
params['colsample_bytree'] = 1.

# %%
# This can take some time…
min_mae = float("Inf")
best_params = None
for eta in [.3, .2, .1, .05, .01, .005]:
    print("CV with eta={}".format(eta))
    # We update our parameters
    params['eta'] = eta
    # Run and time CV
    cv_results = xgb.cv(
            params,
            dtrain,
            num_boost_round=num_boost_round,
            seed=42,
            nfold=5,
            metrics=['mae'],
            early_stopping_rounds=10
          )
    # Update best score
    mean_mae = cv_results['test-mae-mean'].min()
    boost_rounds = cv_results['test-mae-mean'].argmin()
    print("\tMAE {} for {} rounds\n".format(mean_mae, boost_rounds))
    if mean_mae < min_mae:
        min_mae = mean_mae
        best_params = eta
print("Best params: {}, MAE: {}".format(best_params, min_mae))
frequency = 2500  # Set Frequency To 2500 Hertz
duration = 1000  # Set Duration To 1000 ms == 1 second
winsound.Beep(frequency, duration)
# Out:
# CV with eta=0.3
# [10:52:05] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:52:05] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:52:05] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:52:05] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:52:05] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.23927067428016993 for 22 rounds
#
# CV with eta=0.2
# [10:52:15] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:52:15] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:52:15] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:52:15] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:52:15] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.23864082399975955 for 47 rounds
#
# CV with eta=0.1
# [10:52:32] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:52:32] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:52:32] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:52:32] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:52:32] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.23618229749552072 for 215 rounds
#
# CV with eta=0.05
# [10:53:34] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:53:34] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:53:34] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:53:34] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:53:34] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.23521815294640716 for 558 rounds
#
# CV with eta=0.01
# [10:56:08] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:56:08] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:56:08] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:56:08] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [10:56:08] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.2368171965010492 for 998 rounds
#
# CV with eta=0.005
# [11:00:54] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:00:54] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:00:54] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:00:54] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:00:54] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.23951831660119197 for 998 rounds
#
# Best params: 0.05, MAE: 0.23521815294640716

# %%
params['eta'] = .05

# %%
params
# Out:
# {'max_depth': 11,
#  'min_child_weight': 7,
#  'eta': 0.05,
#  'subsample': 1.0,
#  'colsample_bytree': 1.0,
#  'objective': 'reg:linear',
#  'eval_metric': 'mae'}

# %%
model = xgb.train(
    params,
    dtrain,
    num_boost_round=num_boost_round,
    evals=[(dtest, "Test")],
    early_stopping_rounds=10
)
# Out:
# [11:44:54] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	Test-mae:0.48720
# [1]	Test-mae:0.47499
# [2]	Test-mae:0.46342
# [3]	Test-mae:0.45233
# [4]	Test-mae:0.44176
# [5]	Test-mae:0.43180
# [6]	Test-mae:0.42226
# [7]	Test-mae:0.41325
# [8]	Test-mae:0.40464
# [9]	Test-mae:0.39649
# [10]	Test-mae:0.38869
# [11]	Test-mae:0.38129
# [12]	Test-mae:0.37425
# [13]	Test-mae:0.36756
# [14]	Test-mae:0.36121
# [15]	Test-mae:0.35514
# [16]	Test-mae:0.34936
# [17]	Test-mae:0.34380
# [18]	Test-mae:0.33858
# [19]	Test-mae:0.33359
# [20]	Test-mae:0.32889
# [21]	Test-mae:0.32435
# [22]	Test-mae:0.32003
# [23]	Test-mae:0.31597
# [24]	Test-mae:0.31208
# [25]	Test-mae:0.30832
# [26]	Test-mae:0.30481
# [977]	Test-mae:0.23107
# [978]	Test-mae:0.23107
# [979]	Test-mae:0.23106
# [980]	Test-mae:0.23106
# [981]	Test-mae:0.23108
# [982]	Test-mae:0.23109
# [983]	Test-mae:0.23108
# [984]	Test-mae:0.23107
# [985]	Test-mae:0.23107
# [986]	Test-mae:0.23107
# [987]	Test-mae:0.23108
# [988]	Test-mae:0.23108
# [989]	Test-mae:0.23108
# [990]	Test-mae:0.23108
# [991]	Test-mae:0.23108
# [992]	Test-mae:0.23108
# [993]	Test-mae:0.23109
# [994]	Test-mae:0.23109
# [995]	Test-mae:0.23108
# [996]	Test-mae:0.23107
# [997]	Test-mae:0.23108
# [998]	Test-mae:0.23107

# %%
mean_absolute_error(best_model.predict(dtest), y_test2)
# Out:
# 0.2310726564485558

# %% [markdown]
# ### Guardado del modelo y predicciones.
# -------------------------------------------------------------------------------------------------------------------------------

# %%
best_model.save_model("Random_forest-20%.model")

# %%
loaded_model = xgb.Booster()
loaded_model.load_model("Random_forest-20%.model")
# And use it for predictions.
# Out:
# [11:46:20] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.

# %%
Prediccion = loaded_model.predict(dtest)

# %%
Prediccion.min()
# Out:
# -0.19185401

# %%
Prediccion.max()
# Out:
# 1.1886904

# %%
testing_list =[]
for i in  np.linspace(0.1,0.9,9):
    d = {}
    y_p = Prediccion >= i
    print("Threshold:",i)
    cm = confusion_matrix(y_test2,y_p)
    d["th"] = i
    d["F1"] = np.round(f1_score(y_test2,y_p),2)
    d["Prec"] = np.round(precision_score(y_test2,y_p),2)
    d["Rec"] = np.round(recall_score(y_test2,y_p),2)
    d["Acc"] = np.round(accuracy_score(y_test2,y_p),2)
    d["RocAuc"] = np.round(roc_auc_score(y_test2,y_p),2)
    testing_list.append(d)
# Out:
# Threshold: 0.1
# Threshold: 0.2
# Threshold: 0.30000000000000004
# Threshold: 0.4
# Threshold: 0.5
# Threshold: 0.6
# Threshold: 0.7000000000000001
# Threshold: 0.8
# Threshold: 0.9

# %% [markdown]
# # Metricas para cada umbral.
# - th: umbral
# -------------------------------------------------------------------------------------------------------------------------------

# %%
testing_metrics_pd = pd.DataFrame(testing_list)
testing_metrics_pd
# Out:
#     th    F1  Prec   Rec   Acc  RocAuc
# 0  0.1  0.67  0.52  0.96  0.68    0.75
# 1  0.2  0.72  0.60  0.91  0.77    0.80
# 2  0.3  0.75  0.67  0.86  0.81    0.82
# 3  0.4  0.76  0.72  0.80  0.83    0.82
# 4  0.5  0.75  0.77  0.73  0.84    0.81
# 5  0.6  0.73  0.82  0.65  0.83    0.79
# 6  0.7  0.68  0.86  0.56  0.82    0.75
# 7  0.8  0.59  0.89  0.44  0.79    0.71
# 8  0.9  0.41  0.92  0.26  0.74    0.63

# %%
print(testing_metrics_pd.to_latex(index=False))
# Out:
# \begin{tabular}{rrrrrr}
# \toprule
#  th &   F1 &  Prec &  Rec &  Acc &  RocAuc \\
# \midrule
# 0.1 & 0.67 &  0.52 & 0.96 & 0.68 &    0.75 \\
# 0.2 & 0.72 &  0.60 & 0.91 & 0.77 &    0.80 \\
# 0.3 & 0.75 &  0.67 & 0.86 & 0.81 &    0.82 \\
# 0.4 & 0.76 &  0.72 & 0.80 & 0.83 &    0.82 \\
# 0.5 & 0.75 &  0.77 & 0.73 & 0.84 &    0.81 \\
# 0.6 & 0.73 &  0.82 & 0.65 & 0.83 &    0.79 \\
# 0.7 & 0.68 &  0.86 & 0.56 & 0.82 &    0.75 \\
# 0.8 & 0.59 &  0.89 & 0.44 & 0.79 &    0.71 \\
# 0.9 & 0.41 &  0.92 & 0.26 & 0.74 &    0.63 \\
# \bottomrule
# \end{tabular}

# %%
fpr, tpr, ths = roc_curve(y_test2,  Prediccion)
auc_ = auc(fpr, tpr)
plt.plot(fpr,tpr, label='ROC curve (area = %.2f)' %auc_)
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.legend()
plt.grid()
plt.show()

# %%
for i in  np.linspace(0.1,0.9,9):
    print(i)
    y_p = Prediccion >= i
    print(classification_report(y_test2, y_p))
    f1 = f1_score(y_test2, y_p)
    prec = precision_score(y_test2, y_p)
    rec = recall_score(y_test2, y_p)
    acc = accuracy_score(y_test2, y_p)
    cm=confusion_matrix(y_test2, y_p)
    print("Matriz de confusión: ")
    print(cm)
    print("----------------------------------------------------------")
    print("F1: %.2f" %f1 , " -- prec: %.2f" %prec, " -- recall: %.2f" %rec, " -- acc: %.2f" %acc)
    print("----------------------------------------------------------")
# Out:
# 0.1
#               precision    recall  f1-score   support
#
#            0       0.96      0.54      0.70     13263
#            1       0.52      0.96      0.67      6737
#
#     accuracy                           0.68     20000
#    macro avg       0.74      0.75      0.68     20000
# weighted avg       0.81      0.68      0.69     20000
#
# Matriz de confusión:
# [[7226 6037]
#  [ 301 6436]]
# ----------------------------------------------------------
# F1: 0.67  -- prec: 0.52  -- recall: 0.96  -- acc: 0.68
# ----------------------------------------------------------
# 0.2
#               precision    recall  f1-score   support
#
#            0       0.94      0.70      0.80     13263
#            1       0.60      0.91      0.72      6737
#
#     accuracy                           0.77     20000
#    macro avg       0.77      0.80      0.76     20000
# weighted avg       0.82      0.77      0.77     20000
#
# Matriz de confusión:
# [[9239 4024]
#  [ 619 6118]]
# ----------------------------------------------------------
# F1: 0.72  -- prec: 0.60  -- recall: 0.91  -- acc: 0.77
# ----------------------------------------------------------
# 0.30000000000000004
#               precision    recall  f1-score   support
#
#            0       0.92      0.79      0.85     13263
#            1       0.67      0.86      0.75      6737
#
#     accuracy                           0.81     20000
#    macro avg       0.79      0.82      0.80     20000
# weighted avg       0.83      0.81      0.81     20000
#
# Matriz de confusión:
# [[10431  2832]
#  [  965  5772]]
# ----------------------------------------------------------
# F1: 0.75  -- prec: 0.67  -- recall: 0.86  -- acc: 0.81
# ----------------------------------------------------------
# 0.4
#               precision    recall  f1-score   support
#
#            0       0.89      0.84      0.87     13263
#            1       0.72      0.80      0.76      6737
#
#     accuracy                           0.83     20000
#    macro avg       0.81      0.82      0.81     20000
# weighted avg       0.84      0.83      0.83     20000
#
# Matriz de confusión:
# [[11201  2062]
#  [ 1342  5395]]
# ----------------------------------------------------------
# F1: 0.76  -- prec: 0.72  -- recall: 0.80  -- acc: 0.83
# ----------------------------------------------------------
# 0.5
#               precision    recall  f1-score   support
#
#            0       0.87      0.89      0.88     13263
#            1       0.77      0.73      0.75      6737
#
#     accuracy                           0.84     20000
#    macro avg       0.82      0.81      0.81     20000
# weighted avg       0.84      0.84      0.84     20000
#
# Matriz de confusión:
# [[11830  1433]
#  [ 1829  4908]]
# ----------------------------------------------------------
# F1: 0.75  -- prec: 0.77  -- recall: 0.73  -- acc: 0.84
# ----------------------------------------------------------
# 0.6
#               precision    recall  f1-score   support
#
#            0       0.84      0.93      0.88     13263
#            1       0.82      0.65      0.73      6737
#
#     accuracy                           0.83     20000
#    macro avg       0.83      0.79      0.80     20000
# weighted avg       0.83      0.83      0.83     20000
#
# Matriz de confusión:
# [[12308   955]
#  [ 2359  4378]]
# ----------------------------------------------------------
# F1: 0.73  -- prec: 0.82  -- recall: 0.65  -- acc: 0.83
# ----------------------------------------------------------
# 0.7000000000000001
#               precision    recall  f1-score   support
#
#            0       0.81      0.95      0.88     13263
#            1       0.86      0.56      0.68      6737
#
#     accuracy                           0.82     20000
#    macro avg       0.83      0.75      0.78     20000
# weighted avg       0.83      0.82      0.81     20000
#
# Matriz de confusión:
# [[12652   611]
#  [ 2993  3744]]
# ----------------------------------------------------------
# F1: 0.68  -- prec: 0.86  -- recall: 0.56  -- acc: 0.82
# ----------------------------------------------------------
# 0.8
#               precision    recall  f1-score   support
#
#            0       0.77      0.97      0.86     13263
#            1       0.89      0.44      0.59      6737
#
#     accuracy                           0.79     20000
#    macro avg       0.83      0.71      0.72     20000
# weighted avg       0.81      0.79      0.77     20000
#
# Matriz de confusión:
# [[12915   348]
#  [ 3794  2943]]
# ----------------------------------------------------------
# F1: 0.59  -- prec: 0.89  -- recall: 0.44  -- acc: 0.79
# ----------------------------------------------------------
# 0.9
#               precision    recall  f1-score   support
#
#            0       0.73      0.99      0.84     13263
#            1       0.92      0.26      0.41      6737
#
#     accuracy                           0.74     20000
#    macro avg       0.82      0.63      0.62     20000
# weighted avg       0.79      0.74      0.69     20000
#
# Matriz de confusión:
# [[13113   150]
#  [ 4966  1771]]
# ----------------------------------------------------------
# F1: 0.41  -- prec: 0.92  -- recall: 0.26  -- acc: 0.74
# ----------------------------------------------------------

# %%
umbral = 0.4

# %%
maskSignal=Prediccion>umbral

# %%
predicBin=[]
for i in maskSignal:
    if(i==True):
        predicBin.append(1)
    else:
        predicBin.append(0)

# %%
npPredict=np.array(predicBin)

# %%
cm=confusion_matrix(y_test2, npPredict)
cm
# Out:
# array([[11201,  2062],
#        [ 1342,  5395]], dtype=int64)

# %%
cm_display = ConfusionMatrixDisplay(cm).plot()

# %%
f1= f1_score(y_test2, npPredict)
f1
# Out:
# 0.7601803578977032

# %%
prec=precision_score(y_test2, npPredict)
prec
# Out:
# 0.7234501347708895

# %%
rec=recall_score(y_test2, npPredict)
rec
# Out:
# 0.7915847424302006

# %%
accu=accuracy_score(y_test2, npPredict)
accu
# Out:
# 0.8267333333333333

# %%
print(classification_report(y_test2, npPredict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.84      0.87     19828
#            1       0.72      0.79      0.76     10172
#
#     accuracy                           0.83     30000
#    macro avg       0.81      0.82      0.81     30000
# weighted avg       0.83      0.83      0.83     30000

# %%
print("F1: %.2f" %f1 , " -- prec: %.2f" %prec, " -- recall: %.2f" %rec, " -- acc: %.2f" %acc)
# Out:
# F1: 0.76  -- prec: 0.72  -- recall: 0.79  -- acc: 0.74
