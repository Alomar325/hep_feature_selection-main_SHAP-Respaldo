# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import random

# %%
df = pd.read_csv("/Users/Laboratorio/Downloads/atlas-higgs-challenge-2014-v2.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10340/3758338383.py in <module>
# ----> 1 df = pd.read_csv("/Users/Laboratorio/Downloads/atlas-higgs-challenge-2014-v2.csv")
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
df.head()

# %%
print(len(df))
# Out:
# 818238

# %%
labels = df["Label"].value_counts()

# %%
#calcular porcsentaje de cada uno s y b
s_total = labels[1]
b_total = labels[0]
porcentajeB= (b_total*100)/total
porcentajeS = (s_total*100)/total
porcentajeB = round(porcentajeB)
porcentajeS = round(porcentajeS)
print("b = ",porcentajeB)
print("s = ",porcentajeS)
s = porcentajeS*1000
b = porcentajeB*1000
# Out:
# b =  66
# s =  34

# %%
mask_sig =df["Label"] == 's'

# %%
mask_back =df["Label"] == 'b'

# %%
df_sig = df[mask_sig]

# %%
df_back = df[mask_back]

# %%
df_sig.head()
# Out:
#     EventId  DER_mass_MMC  DER_mass_transverse_met_lep  DER_mass_vis  \
# 0    100000       138.470                       51.655        97.827
# 6    100006       148.754                       28.862       107.782
# 7    100007       154.916                       10.418        94.714
# 9    100009       128.053                       88.941        69.272
# 15   100015       111.026                       32.096        75.271
#
#     DER_pt_h  DER_deltaeta_jet_jet  DER_mass_jet_jet  DER_prodeta_jet_jet  \
# 0     27.980                 0.910           124.711                2.666
# 6    106.130                 0.733           158.359                0.113
# 7     29.169              -999.000          -999.000             -999.000
# 9    193.392              -999.000          -999.000             -999.000
# 15    23.067              -999.000          -999.000             -999.000
#
#     DER_deltar_tau_lep  DER_pt_tot  ...  PRI_jet_leading_eta  \
# ...

# %%
random.seed(10)
x_sig = random.choices(range(0, s_total), k = s)

# %%
x_back = random.choices(range(0, b_total), k = b)

# %%
print(x_sig)
# Out:
# [159741, 119900, 161611, 57616, 227372, 230242, 182684, 44793, 145558, 91632, 69889, 266369, 278597, 12456, 240466, 168627, 106681, 79288, 188693, 127711, 191739, 185025, 37175, 214656, 274643, 271002, 171461, 12373, 1133, 37453, 263066, 84667, 102359, 251099, 87883, 153473, 121896, 18169, 163415, 235967, 43728, 62705, 115421, 10322, 138830, 228675, 183919, 149140, 239058, 41846, 158576, 104604, 168100, 31566, 216802, 27007, 46508, 225730, 264937, 121114, 115760, 68626, 76796, 172559, 49890, 33402, 127405, 46110, 181357, 229534, 217361, 134226, 97167, 121527, 1400, 199206, 92718, 89297, 22343, 125258, 162941, 109192, 243090, 188242, 67488, 146867, 254548, 145401, 168324, 17548, 136812, 129000, 112139, 117536, 163524, 150589, 136955, 46350, 123382, 270803, 116065, 9873, 791, 149681, 14138, 25927, 30403, 126942, 277515, 135602, 128217, 122030, 140090, 124987, 203020, 251028, 195096, 118340, 181582, 254271, 42948, 66351, 173078, 192063, 179645, 164529, 231873, 133893, 225769, 269036, 12
# ...

# %%
df_sigR = df_sig.iloc[x_sig]

# %%
df_backR = df_back.iloc[x_back]

# %%
df_reducido = pd.concat([df_sigR, df_backR])

# %%
print(df_reducido)
# Out:
#         EventId  DER_mass_MMC  DER_mass_transverse_met_lep  DER_mass_vis  \
# 467457   567457       119.953                       10.623        95.826
# 349823   449823       137.082                        5.303        86.135
# 473065   573065       149.097                       12.571       111.279
# 168293   268293       100.601                       44.207        76.478
# 665251   765251       130.566                        6.700        91.766
# ...         ...           ...                          ...           ...
# 82537    182537        58.810                       61.729        48.370
# 320493   420493       235.146                       88.258       123.687
# 548611   648611       201.797                       30.605       148.468
# 80595    180595       138.826                        8.490        78.300
# 688138   788138      -999.000                       74.903       118.913
#
#         DER_pt_h  DER_deltaeta_jet_jet  DER_mass_jet_jet  DER_prodeta_jet_jet  \
# ...

# %%
shuffle = df_reducido.sample(frac=1, random_state = 1).reset_index()

# %%
shuffle.head()
# Out:
#     index  EventId  DER_mass_MMC  DER_mass_transverse_met_lep  DER_mass_vis  \
# 0  138682   238682        85.123                        5.111        45.454
# 1  271291   371291        70.751                       16.532        47.178
# 2  489566   589566      -999.000                       79.211        77.286
# 3  377268   477268        74.959                       58.796        58.484
# 4  323429   423429      -999.000                       82.701       109.640
#
#    DER_pt_h  DER_deltaeta_jet_jet  DER_mass_jet_jet  DER_prodeta_jet_jet  \
# 0   139.856              -999.000          -999.000             -999.000
# 1   107.916                 4.446           442.881               -4.514
# 2     0.998              -999.000          -999.000             -999.000
# 3    24.962              -999.000          -999.000             -999.000
# 4     2.044              -999.000          -999.000             -999.000
#
# ...

# %%
print(shuffle)
# Out:
#         index  EventId  DER_mass_MMC  DER_mass_transverse_met_lep  \
# 0      138682   238682        85.123                        5.111
# 1      271291   371291        70.751                       16.532
# 2      489566   589566      -999.000                       79.211
# 3      377268   477268        74.959                       58.796
# 4      323429   423429      -999.000                       82.701
# ...       ...      ...           ...                          ...
# 99995  176894   276894        95.075                        9.736
# 99996  572671   672671       108.208                       20.509
# 99997  409655   509655        77.503                       20.791
# 99998  279185   379185        96.531                       12.773
# 99999  429106   529106      -999.000                       51.909
#
#        DER_mass_vis  DER_pt_h  DER_deltaeta_jet_jet  DER_mass_jet_jet  \
# 0            45.454   139.856              -999.000          -999.000
# ...

# %%
shuffle.to_csv('/Users/Alex/Downloads/higgs_reducido.csv', index=False)

# %%
#hacer un notebooke para cada metoo de seleccion de variable
#buscar los metodos en sklearn informacion mutua y ademas CHI2
#buscar XGBoost en python para clasificar y random forest
#buscar calculo de caracteristicas de la correlacion de pearson con python
#bascar shap en python
