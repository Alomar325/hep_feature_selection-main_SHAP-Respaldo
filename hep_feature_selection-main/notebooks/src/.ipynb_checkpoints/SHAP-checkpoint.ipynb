# %% [markdown]
# # SHAP
#
# ### Clasificación de eventos usando SHAP como seleccionador de características con los set de datos reducidos a 100000 eventos.

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------
#
# Alex Toro, Raquel Pezoa

# %% [markdown]
# ## Librerias necesarias-
# -------------------------------------------------------------------------------------------------------------------------------

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from xgboost import XGBClassifier
import shap
from sklearn.model_selection import train_test_split

# %%
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV

# %%
import xgboost as xgb

# %%
import winsound

# %%
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %% [markdown]
# ## Lectura del set de datos reducido.
#
# - El set original proviene de https://www.kaggle.com/competitions/higgs-boson/data.
# - Separación de la variable Label de las demas variables.
# -------------------------------------------------------------------------------------------------------------------------------

# %%
df = pd.read_csv("/Users/Alex/Downloads/Pre-procesado.csv")

# %%
X = df.drop(labels=['Label'], axis=1)
Y = df['Label']
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.01, random_state=0)

# %%
X_train.shape
# Out:
# (99000, 30)

# %%
params={
 "learning_rate"    : [0.05, 0.10, 0.15, 0.20, 0.25, 0.30 ] ,
 "max_depth"        : [ 3, 4, 5, 6, 8, 10, 12, 15],
 "min_child_weight" : [ 1, 3, 5, 7 ],
 "gamma"            : [ 0.0, 0.1, 0.2 , 0.3, 0.4 ],
 "colsample_bytree" : [ 0.3, 0.4, 0.5 , 0.7 ]
    
}

# %%
classifier=XGBClassifier()

# %%
random_search=RandomizedSearchCV(classifier,param_distributions=params,n_iter=5,scoring='roc_auc',n_jobs=-1,cv=5,verbose=3)

# %%
random_search.fit(X_train,y_train) # el de 5 iteraciones
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits

# %%
frequency = 2500  # Set Frequency To 2500 Hertz
duration = 1000  # Set Duration To 1000 ms == 1 second
winsound.Beep(frequency, duration)

# %%
print(random_search.best_estimator_) # 5 iteraciones
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=0.5,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0.3, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.3, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=15, max_leaves=0, min_child_weight=3,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, predictor='auto', random_state=0,
#               reg_alpha=0, reg_lambda=1, ...)

# %%
random_search.best_params_ # 5 iteraciones
# Out:
# {'min_child_weight': 3,
#  'max_depth': 15,
#  'learning_rate': 0.3,
#  'gamma': 0.3,
#  'colsample_bytree': 0.5}

# %% [markdown]
# ### Entrenamiento y testeo del set de datos con XGBoost.
#
# - Se entrena con XGBClassifier antes de usar SHAP, ya que SHAP necesita con aterioridad un modelo entrenado.
# -------------------------------------------------------------------------------------------------------------------------------

# %%
model = XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=0.5,
              early_stopping_rounds=None, enable_categorical=False,
              eval_metric=None, gamma=0.3, gpu_id=-1, grow_policy='depthwise',
              importance_type=None, interaction_constraints='',
              learning_rate=0.3, max_bin=256, max_cat_to_onehot=4,
              max_delta_step=0, max_depth=15, max_leaves=0, min_child_weight=3,
              missing=None, monotone_constraints='()', n_estimators=100,
              n_jobs=0, num_parallel_tree=1, predictor='auto', random_state=0,
              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None, silent=True,
       subsample=1)
model.get_params()
# Out:
# {'objective': 'binary:logistic',
#  'use_label_encoder': False,
#  'base_score': 0.5,
#  'booster': 'gbtree',
#  'callbacks': None,
#  'colsample_bylevel': 1,
#  'colsample_bynode': 1,
#  'colsample_bytree': 0.5,
#  'early_stopping_rounds': None,
#  'enable_categorical': False,
#  'eval_metric': None,
#  'gamma': 0.3,
#  'gpu_id': -1,
#  'grow_policy': 'depthwise',
#  'importance_type': None,
#  'interaction_constraints': '',
#  'learning_rate': 0.3,
#  'max_bin': 256,
#  'max_cat_to_onehot': 4,
#  'max_delta_step': 0,
#  'max_depth': 15,
#  'max_leaves': 0,
#  'min_child_weight': 3,
#  'missing': None,
#  'monotone_constraints': '()',
#  'n_estimators': 100,
#  'n_jobs': 0,
#  'num_parallel_tree': 1,
#  'predictor': 'auto',
#  'random_state': 0,
#  'reg_alpha': 0,
#  'reg_lambda': 1,
#  'sampling_method': None,
#  'scale_pos_weight': 1,
#  'subsample': 1,
#  'tree_method': None,
#  'validate_parameters': None,
#  'verbosity': None,
#  'seed': None,
#  'silent': True}

# %%
model.fit(X_train, y_train)
# Out:
# [13:13:17] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=0.5,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0.3, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.3, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=15, max_leaves=0, min_child_weight=3,
#               missing=None, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, predictor='auto', random_state=0,
#               reg_alpha=0, reg_lambda=1, ...)

# %% [markdown]
# ### SHAP seleccionado características.

# %%
# Fits the explainer
explainer = shap.TreeExplainer(model = model)
# Calculates the SHAP values - It takes some time

# %%
# Evaluate SHAP values
shap_values = explainer.shap_values(X_test)
# Out:
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %% [markdown]
# ### Waterfall plot
#
# - Esta gráfica muestra cómo las características contribuyen a impulsar la predicción del clasificador desde el valor base (la predicción promedio del modelo sobre el conjunto de datos de entrenamiento) hasta la salida del modelo, de una muestra de datos específica.
# - Las características que empujan la predicción más alta se muestran en rojo, las que empujan la predicción más baja están en azul.
# -------------------------------------------------------------------------------------------------------------------------------

# %%
i=4
shap.plots._waterfall.waterfall_legacy(explainer.expected_value, 
                                       shap_values[i],
                                       feature_names = X_train.columns, 
                                       show = True,
                                      max_display=10)
# el numero es lo que contribuye en el dato en la posicion 4 (un evento)

# %% [markdown]
# ### Summary Plots
# - Ranking de las mejore 20 características
# -------------------------------------------------------------------------------------------------------------------------------

# %%
shap.summary_plot(shap_values, X_test, plot_type="bar")

# %%
X_test
# Out:
#        DER_mass_MMC  DER_mass_transverse_met_lep  DER_mass_vis  DER_pt_h  \
# 3582       -999.000                       51.525        64.653    58.637
# 60498       153.541                       13.850        83.206    81.976
# 53227       138.446                        1.833        62.411   140.682
# 21333       137.621                       88.006        73.570     1.436
# 3885        137.341                       16.591       103.245   346.650
# ...             ...                          ...           ...       ...
# 3473        143.521                       13.500       101.689    84.005
# 17858       112.476                       39.406        60.475   266.916
# 97530       115.082                       12.998        77.616    42.343
# 14492      -999.000                       89.037        62.767   148.778
# 82863        83.985                       72.689        65.771    11.451
#
#        DER_deltaeta_jet_jet  DER_mass_jet_jet  DER_prodeta_jet_jet  \
# 3582               -999.000          -999.000             -999.000
# 60498                 4.211           719.978               -3.739
# 53227                 0.560           170.804                0.552
# 21333              -999.000          -999.000             -999.000
# 3885                  1.493           189.269                0.535
# ...                     ...               ...                  ...
# 3473                  4.149           543.506               -3.349
# 17858                 0.676            96.322               -0.108
# 97530              -999.000          -999.000             -999.000
# 14492                 3.900           805.680               -3.209
# 82863                 1.016           186.188                0.328
#
#        DER_deltar_tau_lep  DER_pt_tot  DER_sum_pt  ...  PRI_met_phi  \
# 3582                1.797      58.637      89.719  ...        2.340
# 60498               2.632      29.361     249.653  ...        2.108
# 53227               2.290      43.660     348.000  ...        2.223
# 21333               3.040       1.436      81.058  ...       -2.323
# 3885                1.212     177.422     625.424  ...        2.090
# ...                   ...         ...         ...  ...          ...
# 3473                2.052       4.398     278.690  ...        0.857
# 17858               0.880       0.947     414.802  ...        0.996
# 97530               2.229       2.214     139.428  ...       -0.046
# 14492               1.374      61.362     405.224  ...       -0.270
# 82863               1.992      16.616     230.995  ...       -0.407
#
#        PRI_met_sumet  PRI_jet_num  PRI_jet_leading_pt  PRI_jet_leading_eta  \
# 3582         221.042            0            -999.000             -999.000
# 60498        370.166            2             102.704               -1.272
# 53227        424.059            3             172.656               -0.514
# 21333        102.216            0            -999.000             -999.000
# 3885         736.536            3             112.596                1.791
# ...              ...          ...                 ...                  ...
# 3473         320.677            2             114.760               -3.052
# 17858        389.758            2             149.195                0.417
# 97530        156.579            1              44.405                0.966
# 14492        282.101            3             140.619               -1.180
# 82863        350.558            2              83.387               -0.257
#
#        PRI_jet_leading_phi  PRI_jet_subleading_pt  PRI_jet_subleading_eta  \
# 3582              -999.000               -999.000                -999.000
# 60498               -1.920                 72.803                   2.939
# 53227               -0.716                 69.112                  -1.074
# 21333             -999.000               -999.000                -999.000
# 3885                -1.492                109.589                   0.298
# ...                    ...                    ...                     ...
# 3473                -1.654                 39.349                   1.097
# 17858               -2.129                118.850                  -0.260
# 97530               -1.266               -999.000                -999.000
# 14492                2.439                 92.231                   2.720
# 82863                1.921                 79.026                  -1.274
#
#        PRI_jet_subleading_phi  PRI_jet_all_pt
# 3582                 -999.000           0.000
# 60498                   0.699         175.507
# 53227                  -2.313         282.655
# 21333                -999.000           0.000
# 3885                   -1.855         357.919
# ...                       ...             ...
# 3473                    0.965         154.109
# 17858                  -2.204         268.045
# 97530                -999.000          44.405
# 14492                   0.638         305.417
# 82863                  -1.260         162.413
#
# [1000 rows x 30 columns]

# %%
shap_values
# Out:
# array([[-9.4734830e-01, -2.4272093e-01, -4.0225396e-03, ...,
#          8.8844961e-03,  2.5923273e-03,  8.2852684e-02],
#        [ 1.4464211e+00,  6.0204762e-01,  6.5334827e-01, ...,
#          9.0377301e-02, -8.3209723e-03,  1.5608554e-01],
#        [ 1.8005736e+00,  7.5625920e-01,  2.9705349e-01, ...,
#          5.9214823e-02,  4.0350121e-02, -1.3907789e-01],
#        ...,
#        [ 5.7642978e-01,  7.0978910e-01,  3.4058746e-02, ...,
#          8.0249930e-04, -6.3488893e-03,  1.1441887e-01],
#        [-1.7497122e+00, -7.7626914e-01,  1.6108371e-01, ...,
#          1.4717773e-01,  3.2311212e-02,  2.3206300e-01],
#        [-1.2712586e+00, -1.0200047e+00,  1.2618798e-01, ...,
#         -2.7354607e-02,  1.1617308e-01, -4.1667450e-02]], dtype=float32)

# %% [markdown]
# ### Obteniendo la media de los valores absolutos de SHAP (|SHAP value|).
# -------------------------------------------------------------------------------------------------------------------------------

# %%
meanL = []
for valus in range(0,len(shap_values)):
    for singularidad in range(0,len(shap_values[valus])):
        if valus==0:
            meanL.append(abs(shap_values[valus][singularidad]))
        else:
            meanL[singularidad]=meanL[singularidad]+abs(shap_values[valus][singularidad])

# %% [markdown]
# ### Convertir los datos a  una lista de duplas.
#
# - Se convierte la media de los valores absolutos de SHAP junto a las columnas del dataframe en una lista de duplas.
# - Se realizan las duplas para así poder reordenar las variables de la más relevante a la menos relevante.
# - Se Reordena la duplas de mayor a menor.
# - Se separan las duplas en listas separadas y transformar las 20 primeras en arreglos de numpy.
# -------------------------------------------------------------------------------------------------------------------------------

# %%
meanL=list(map(lambda x: x / len(shap_values), meanL))
l=[]
for feature in zip(meanL,X_train.columns):
    l.append(feature)
    print(feature)
# Out:
# (0.9843228149414063, 'DER_mass_MMC')
# (0.680233154296875, 'DER_mass_transverse_met_lep')
# (0.4621041564941406, 'DER_mass_vis')
# (0.18086834716796876, 'DER_pt_h')
# (0.12185381317138672, 'DER_deltaeta_jet_jet')
# (0.12505496215820314, 'DER_mass_jet_jet')
# (0.06611882781982421, 'DER_prodeta_jet_jet')
# (0.3045588684082031, 'DER_deltar_tau_lep')
# (0.15101588439941407, 'DER_pt_tot')
# (0.2170457305908203, 'DER_sum_pt')
# (0.12409425354003906, 'DER_pt_ratio_lep_tau')
# (0.260050048828125, 'DER_met_phi_centrality')
# (0.17595753479003906, 'DER_lep_eta_centrality')
# (0.42626507568359373, 'PRI_tau_pt')
# (0.13177188110351562, 'PRI_tau_eta')
# (0.08982904052734375, 'PRI_tau_phi')
# (0.10767205810546875, 'PRI_lep_pt')
# (0.18275692749023437, 'PRI_lep_eta')
# (0.08820306396484374, 'PRI_lep_phi')
# (0.16441571044921874, 'PRI_met')
# (0.08231740570068359, 'PRI_met_phi')
# (0.12937078857421874, 'PRI_met_sumet')
# (0.038203067779541015, 'PRI_jet_num')
# (0.09563958740234375, 'PRI_jet_leading_pt')
# (0.3035323486328125, 'PRI_jet_leading_eta')
# (0.055381454467773435, 'PRI_jet_leading_phi')
# (0.04447932434082031, 'PRI_jet_subleading_pt')
# (0.032318111419677734, 'PRI_jet_subleading_eta')
# (0.02369476318359375, 'PRI_jet_subleading_phi')
# (0.09933645629882812, 'PRI_jet_all_pt')

# %%
l.sort(reverse=True)
l
# Out:
# [(0.9843228149414063, 'DER_mass_MMC'),
#  (0.680233154296875, 'DER_mass_transverse_met_lep'),
#  (0.4621041564941406, 'DER_mass_vis'),
#  (0.42626507568359373, 'PRI_tau_pt'),
#  (0.3045588684082031, 'DER_deltar_tau_lep'),
#  (0.3035323486328125, 'PRI_jet_leading_eta'),
#  (0.260050048828125, 'DER_met_phi_centrality'),
#  (0.2170457305908203, 'DER_sum_pt'),
#  (0.18275692749023437, 'PRI_lep_eta'),
#  (0.18086834716796876, 'DER_pt_h'),
#  (0.17595753479003906, 'DER_lep_eta_centrality'),
#  (0.16441571044921874, 'PRI_met'),
#  (0.15101588439941407, 'DER_pt_tot'),
#  (0.13177188110351562, 'PRI_tau_eta'),
#  (0.12937078857421874, 'PRI_met_sumet'),
#  (0.12505496215820314, 'DER_mass_jet_jet'),
#  (0.12409425354003906, 'DER_pt_ratio_lep_tau'),
#  (0.12185381317138672, 'DER_deltaeta_jet_jet'),
#  (0.10767205810546875, 'PRI_lep_pt'),
#  (0.09933645629882812, 'PRI_jet_all_pt'),
#  (0.09563958740234375, 'PRI_jet_leading_pt'),
#  (0.08982904052734375, 'PRI_tau_phi'),
#  (0.08820306396484374, 'PRI_lep_phi'),
#  (0.08231740570068359, 'PRI_met_phi'),
#  (0.06611882781982421, 'DER_prodeta_jet_jet'),
#  (0.055381454467773435, 'PRI_jet_leading_phi'),
#  (0.04447932434082031, 'PRI_jet_subleading_pt'),
#  (0.038203067779541015, 'PRI_jet_num'),
#  (0.032318111419677734, 'PRI_jet_subleading_eta'),
#  (0.02369476318359375, 'PRI_jet_subleading_phi')]

# %%
l_v = []
for importance in range(len(l)):
    for var in range(len(l[importance])):
        if(var == 1):
            l_v.append(l[importance][var])

# %%
x = np.array(l_v[0:20])
x
# Out:
# array(['DER_mass_MMC', 'DER_mass_transverse_met_lep', 'DER_mass_vis',
#        'PRI_tau_pt', 'DER_deltar_tau_lep', 'PRI_jet_leading_eta',
#        'DER_met_phi_centrality', 'DER_sum_pt', 'PRI_lep_eta', 'DER_pt_h',
#        'DER_lep_eta_centrality', 'PRI_met', 'DER_pt_tot', 'PRI_tau_eta',
#        'PRI_met_sumet', 'DER_mass_jet_jet', 'DER_pt_ratio_lep_tau',
#        'DER_deltaeta_jet_jet', 'PRI_lep_pt', 'PRI_jet_all_pt'],
#       dtype='<U27')

# %%
# Force_plot
shap.initjs()
shap.force_plot(explainer.expected_value, shap_values[102,:], X_test.iloc[102,:], link="logit")
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...
# <div id='i7E3XECV8JM618V3OAHNW'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": -0.9093014597892761, "outValue": 1.0813467502593994, "link": "logit", "featureNames": ["DER_mass_MMC", "DER_mass_transverse_met_lep", "DER_mass_vis", "DER_pt_h", "DER_deltaeta_jet_jet", "DER_mass_jet_jet", "DER_prodeta_jet_jet", "DER_deltar_tau_lep", "DER_pt_tot", "DER_sum_pt", "DER_pt_ratio_lep_tau", "DER_met_phi_centrality", "DER_lep_eta_centrality", "PRI_tau_pt", "PRI_tau_eta", "PRI_tau_phi", "PRI_lep_pt", "PRI_lep_eta", "PRI_lep_phi", "PRI_met", "PRI_met_phi", "PRI_met_sumet", "PRI_jet_num", "PRI_jet_leading_pt", "PRI_jet_leading_eta", "PRI_jet_leading_phi", "PRI_jet_subleading_pt", "PRI_jet_subleading_eta", "PRI_jet_subleading_phi", "PRI_jet_all_pt"],
# 99995     271.045        0.750   165.282                -999.000   56.776
# 99996     176.428       -0.037    56.085                   0.541   23.523
# 99997     156.158       -0.680    99.933                -999.000   51.494
# 99998     393.666        0.868   187.917                   0.826   68.280
# 99999     162.494       -1.167    30.074                -999.000  110.739
#
#        DER_pt_tot  PRI_tau_eta  PRI_met_sumet  DER_mass_jet_jet  \
# 0           6.593       -0.900        327.124          -999.000
# 1          49.749        2.286        326.261           442.881
# 2           0.998       -0.405        102.229          -999.000
# 3          24.962       -0.422         84.495          -999.000
# 4           2.044       -0.547        110.727          -999.000
# ...           ...          ...            ...               ...
# 99995      24.675       -0.216        338.910          -999.000
# 99996       4.378        1.520        221.148           246.437
# 99997       2.970        0.344        162.416          -999.000
# 99998      71.559       -0.050        428.033           169.441
# 99999      30.074       -0.160        172.318          -999.000
#
#        DER_pt_ratio_lep_tau  DER_deltaeta_jet_jet  PRI_lep_pt  PRI_jet_all_pt
# 0                     1.324              -999.000      38.174         145.787
# 1                     1.056                 4.446      37.440         137.049
# 2                     0.567              -999.000      33.416           0.000
# 3                     0.947              -999.000      27.921           0.000
# 4                     0.794              -999.000      27.586           0.000
# ...                     ...                   ...         ...             ...
# 99995                 0.612              -999.000      44.118         154.838
# 99996                 1.390                 2.810      34.470         117.155
# 99997                 1.824              -999.000      37.967          97.379
# 99998                 0.477                 1.139      39.626         270.979
# 99999                 0.248              -999.000      32.316           0.000
#
# [100000 rows x 20 columns]

# %% [markdown]
# ### Entrenamiento, testeo y optimizacion de parametros de DMatrix de XGBoost con las variables entregadas por SHAP.
# -------------------------------------------------------------------------------------------------------------------------------

# %%
X_train2, X_test2, y_train2, y_test2 = train_test_split(X_train2, Y, test_size=0.3, random_state=0)

# %%
dtrain = xgb.DMatrix(X_train2, label=y_train2)
dtest = xgb.DMatrix(X_test2, label=y_test2)

# %%
params = {
    # Parameters that we are going to tune.
    'max_depth':6,
    'min_child_weight': 1,
    'eta':.3,
    'subsample': 1,
    'colsample_bytree': 1,
    # Other parameters
    'objective':'reg:linear',
}
params['eval_metric'] = "mae"
params['base_score'] = np.mean(y_train)
num_boost_round = 999

# %%
modelo = xgb.train( 
    params, 
    dtrain, 
    num_boost_round=num_boost_round, 
    evals=[(dtest, "Test")], 
    early_stopping_rounds=10 
)
# Out:
# [13:13:36] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	Test-mae:0.39303
# [1]	Test-mae:0.35281
# [2]	Test-mae:0.32342
# [3]	Test-mae:0.30200
# [4]	Test-mae:0.28562
# [5]	Test-mae:0.27379
# [6]	Test-mae:0.26503
# [7]	Test-mae:0.25885
# [8]	Test-mae:0.25323
# [9]	Test-mae:0.24973
# [10]	Test-mae:0.24689
# [11]	Test-mae:0.24515
# [12]	Test-mae:0.24366
# [13]	Test-mae:0.24179
# [14]	Test-mae:0.24110
# [15]	Test-mae:0.24021
# [16]	Test-mae:0.23962
# [17]	Test-mae:0.23955
# [18]	Test-mae:0.23957
# [19]	Test-mae:0.23925
# [20]	Test-mae:0.23909
# [21]	Test-mae:0.23884
# [22]	Test-mae:0.23901
# [23]	Test-mae:0.23884
# [24]	Test-mae:0.23837
# [25]	Test-mae:0.23832
# [26]	Test-mae:0.23841
# [27]	Test-mae:0.23841
# [28]	Test-mae:0.23843
# [29]	Test-mae:0.23847
# [30]	Test-mae:0.23795
# [31]	Test-mae:0.23804
# [32]	Test-mae:0.23797
# [33]	Test-mae:0.23800
# [34]	Test-mae:0.23775
# [35]	Test-mae:0.23768
# [36]	Test-mae:0.23767
# [37]	Test-mae:0.23754
# [38]	Test-mae:0.23750
# [39]	Test-mae:0.23730
# [40]	Test-mae:0.23707
# [41]	Test-mae:0.23703
# [42]	Test-mae:0.23708
# [43]	Test-mae:0.23712
# [44]	Test-mae:0.23716
# [45]	Test-mae:0.23718
# [46]	Test-mae:0.23720
# [47]	Test-mae:0.23730
# [48]	Test-mae:0.23743
# [49]	Test-mae:0.23726
# [50]	Test-mae:0.23725

# %%
print("Best MAE: {:.2f} with {} rounds".format(
                 modelo.best_score,
                 modelo.best_iteration+1))
# Out:
# Best MAE: 0.24 with 42 rounds

# %%
cv_results = xgb.cv( 
    params, 
    dtrain, 
    num_boost_round=num_boost_round, 
    seed=42, 
    nfold=5, 
    metrics={'mae'}, 
    early_stopping_rounds=10 
)
cv_results
# Out:
# [13:13:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [13:13:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [13:13:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [13:13:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [13:13:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
#     train-mae-mean  train-mae-std  test-mae-mean  test-mae-std
# 0         0.392168       0.000271       0.393296      0.000693
# 1         0.350747       0.000427       0.352864      0.000692
# 2         0.320292       0.000555       0.323330      0.000921
# 3         0.297671       0.000546       0.301577      0.001195
# 4         0.280717       0.000549       0.285410      0.001617
# 5         0.268323       0.000328       0.273815      0.002089
# 6         0.258756       0.001091       0.265019      0.001862
# 7         0.250680       0.000934       0.257892      0.001465
# 8         0.244891       0.001104       0.252770      0.001793
# 9         0.240712       0.001083       0.249236      0.001357
# 10        0.237119       0.001199       0.246162      0.001201
# 11        0.234512       0.000488       0.244218      0.001951
# 12        0.232154       0.000832       0.242381      0.001970
# 13        0.230892       0.000854       0.241718      0.001767
# 14        0.229223       0.000861       0.240621      0.001591
# 15        0.227800       0.000957       0.239677      0.001638
# 16        0.226901       0.001111       0.239288      0.001599
# 17        0.226368       0.000967       0.239202      0.001578
# 18        0.225417       0.000942       0.238690      0.001571
# 19        0.224717       0.000913       0.238395      0.001636
# 20        0.224199       0.000819       0.238305      0.001725
# 21        0.223703       0.000840       0.238152      0.001771
# 22        0.223155       0.000811       0.238006      0.001787
# 23        0.222422       0.000838       0.237775      0.001658
# 24        0.221828       0.000956       0.237704      0.001596
# 25        0.221636       0.000915       0.237708      0.001535
# 26        0.221081       0.000725       0.237571      0.001555
# 27        0.220550       0.000736       0.237514      0.001492
# 28        0.220142       0.000832       0.237356      0.001487
# 29        0.219667       0.000804       0.237260      0.001539
# 30        0.219238       0.000915       0.237195      0.001620
# 31        0.218954       0.000955       0.237217      0.001709
# 32        0.218546       0.000802       0.237176      0.001725
# 33        0.218201       0.000920       0.237127      0.001631
# 34        0.217764       0.001015       0.237064      0.001609
# 35        0.217319       0.000931       0.236952      0.001633
# 36        0.216921       0.000856       0.236853      0.001589
# 37        0.216578       0.000851       0.236892      0.001605
# 38        0.216373       0.000747       0.236924      0.001582
# 39        0.216153       0.000730       0.236927      0.001603
# 40        0.215796       0.000623       0.236880      0.001626
# 41        0.215409       0.000562       0.236874      0.001693
# 42        0.214960       0.000426       0.236822      0.001702
# 43        0.214599       0.000461       0.236770      0.001629
# 44        0.214175       0.000292       0.236769      0.001622
# 45        0.213686       0.000384       0.236662      0.001624
# 46        0.213329       0.000345       0.236595      0.001623

# %%
cv_results['test-mae-mean'].min()
# Out:
# 0.23659505261961772

# %%
gridsearch_params = [
    (max_depth, min_child_weight)
    for max_depth in range(9,12)
    for min_child_weight in range(5,8)
]

# %%
min_mae = float("Inf")
best_params = None
for max_depth, min_child_weight in gridsearch_params:
    print("CV with max_depth={}, min_child_weight={}".format(
                             max_depth,
                             min_child_weight))
    # Update our parameters
    params['max_depth'] = max_depth
    params['min_child_weight'] = min_child_weight
    # Run CV
    cv_results = xgb.cv(
        params,
        dtrain,
        num_boost_round=num_boost_round,
        seed=42,
        nfold=5,
        metrics={'mae'},
        early_stopping_rounds=10
    )
    # Update best MAE
    mean_mae = cv_results['test-mae-mean'].min()
    boost_rounds = cv_results['test-mae-mean'].argmin()
    print("\tMAE {} for {} rounds".format(mean_mae, boost_rounds))
    if mean_mae < min_mae:
        min_mae = mean_mae
        best_params = (max_depth,min_child_weight)
print("Best params: {}, {}, MAE: {}".format(best_params[0], best_params[1], min_mae))
frequency = 2500  # Set Frequency To 2500 Hertz
duration = 1000  # Set Duration To 1000 ms == 1 second
winsound.Beep(frequency, duration)
# Out:
# CV with max_depth=9, min_child_weight=5
# [19:01:23] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:01:23] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:01:23] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:01:23] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:01:23] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.2322876886268003 for 19 rounds
# CV with max_depth=9, min_child_weight=6
# [19:01:33] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:01:33] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:01:33] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:01:33] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:01:33] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.2322669912037537 for 20 rounds
# CV with max_depth=9, min_child_weight=7
# [19:01:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:01:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:01:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:01:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:01:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.23194778457728504 for 22 rounds
# CV with max_depth=10, min_child_weight=5
# [19:01:54] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:01:54] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:01:54] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:01:54] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:01:54] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.23093091282055495 for 20 rounds
# CV with max_depth=10, min_child_weight=6
# [19:02:05] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:02:05] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:02:05] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:02:06] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:02:06] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.23120850469149862 for 17 rounds
# CV with max_depth=10, min_child_weight=7
# [19:02:16] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:02:16] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:02:16] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:02:16] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:02:16] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.2320316561041415 for 15 rounds
# CV with max_depth=11, min_child_weight=5
# [19:02:25] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:02:26] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:02:26] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:02:26] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:02:26] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.23038209418124836 for 15 rounds
# CV with max_depth=11, min_child_weight=6
# [19:02:36] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:02:37] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:02:37] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:02:37] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:02:37] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.2308969654553838 for 15 rounds
# CV with max_depth=11, min_child_weight=7
# [19:02:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:02:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:02:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:02:48] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:02:48] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.2310189284421785 for 15 rounds
# Best params: 11, 5, MAE: 0.23038209418124836

# %%
params['max_depth'] = 11
params['min_child_weight'] = 5

# %%
gridsearch_params = [
    (subsample, colsample)
    for subsample in [i/10. for i in range(7,11)]
    for colsample in [i/10. for i in range(7,11)]
]

# %%
min_mae = float("Inf")
best_params = None
# We start by the largest values and go down to the smallest
for subsample, colsample in reversed(gridsearch_params):
    print("CV with subsample={}, colsample={}".format(
                             subsample,
                             colsample))
    # We update our parameters
    params['subsample'] = subsample
    params['colsample_bytree'] = colsample
    # Run CV
    cv_results = xgb.cv(
        params,
        dtrain,
        num_boost_round=num_boost_round,
        seed=42,
        nfold=5,
        metrics={'mae'},
        early_stopping_rounds=10
    )
    # Update best score
    mean_mae = cv_results['test-mae-mean'].min()
    boost_rounds = cv_results['test-mae-mean'].argmin()
    print("\tMAE {} for {} rounds".format(mean_mae, boost_rounds))
    if mean_mae < min_mae:
        min_mae = mean_mae
        best_params = (subsample,colsample)
print("Best params: {}, {}, MAE: {}".format(best_params[0], best_params[1], min_mae))
frequency = 2500  # Set Frequency To 2500 Hertz
duration = 1000  # Set Duration To 1000 ms == 1 second
winsound.Beep(frequency, duration)
# Out:
# CV with subsample=1.0, colsample=1.0
# [19:03:06] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:03:06] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:03:06] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:03:06] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:03:06] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.23038209418124836 for 15 rounds
# CV with subsample=1.0, colsample=0.9
# [19:03:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:03:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:03:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:03:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:03:19] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.23251080188997228 for 15 rounds
# CV with subsample=1.0, colsample=0.8
# [19:03:29] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:03:29] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:03:29] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:03:29] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:03:29] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.23326923685277104 for 17 rounds
# CV with subsample=1.0, colsample=0.7
# [19:03:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:03:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:03:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:03:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:03:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.23543153164191474 for 19 rounds
# CV with subsample=0.9, colsample=1.0
# [19:03:48] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:03:48] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:03:48] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:03:48] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:03:48] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.23157872329503712 for 16 rounds
# CV with subsample=0.9, colsample=0.9
# [19:03:59] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:03:59] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:03:59] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:04:00] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:04:00] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.23392556409060616 for 16 rounds
# CV with subsample=0.9, colsample=0.8
# [19:04:10] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:04:10] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:04:10] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:04:10] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:04:10] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.23604222437439643 for 15 rounds
# CV with subsample=0.9, colsample=0.7
# [19:04:20] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:04:20] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:04:20] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:04:20] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:04:20] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.2380667623412127 for 17 rounds
# CV with subsample=0.8, colsample=1.0
# [19:04:31] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:04:31] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:04:31] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:04:31] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:04:31] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.23237218747621807 for 13 rounds
# CV with subsample=0.8, colsample=0.9
# [19:04:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:04:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:04:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:04:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:04:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.23512380623988283 for 15 rounds
# CV with subsample=0.8, colsample=0.8
# [19:04:55] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:04:55] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:04:55] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:04:55] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:04:55] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.23703513217176742 for 15 rounds
# CV with subsample=0.8, colsample=0.7
# [19:05:07] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:05:07] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:05:07] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:05:08] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:05:08] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.23891098623012033 for 17 rounds
# CV with subsample=0.7, colsample=1.0
# [19:05:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:05:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:05:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:05:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:05:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.23380389256840822 for 13 rounds
# CV with subsample=0.7, colsample=0.9
# [19:05:28] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:05:28] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:05:28] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:05:28] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:05:28] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.23616865812729157 for 15 rounds
# CV with subsample=0.7, colsample=0.8
# [19:05:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:05:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:05:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:05:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:05:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.23777164955614843 for 16 rounds
# CV with subsample=0.7, colsample=0.7
# [19:05:49] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:05:49] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:05:49] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:05:49] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:05:49] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.24018003025188667 for 15 rounds
# Best params: 1.0, 1.0, MAE: 0.23038209418124836

# %%
params['subsample'] = 1.
params['colsample_bytree'] = 1.

# %%
# This can take some time…
min_mae = float("Inf")
best_params = None
for eta in [.3, .2, .1, .05, .01, .005]:
    print("CV with eta={}".format(eta))
    # We update our parameters
    params['eta'] = eta
    # Run and time CV
    cv_results = xgb.cv(
            params,
            dtrain,
            num_boost_round=num_boost_round,
            seed=42,
            nfold=5,
            metrics=['mae'],
            early_stopping_rounds=10
          )
    # Update best score
    mean_mae = cv_results['test-mae-mean'].min()
    boost_rounds = cv_results['test-mae-mean'].argmin()
    print("\tMAE {} for {} rounds\n".format(mean_mae, boost_rounds))
    if mean_mae < min_mae:
        min_mae = mean_mae
        best_params = eta
print("Best params: {}, MAE: {}".format(best_params, min_mae))
frequency = 2500  # Set Frequency To 2500 Hertz
duration = 1000  # Set Duration To 1000 ms == 1 second
winsound.Beep(frequency, duration)
# Out:
# CV with eta=0.3
# [19:06:07] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:06:07] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:06:07] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:06:08] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:06:08] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.23038209418124836 for 15 rounds
#
# CV with eta=0.2
# [19:06:19] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:06:19] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:06:19] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:06:19] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:06:19] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.22740434340149057 for 36 rounds
#
# CV with eta=0.1
# [19:06:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:06:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:06:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:06:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:06:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.22603952828001456 for 146 rounds
#
# CV with eta=0.05
# [19:07:52] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:07:52] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:07:52] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:07:52] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:07:52] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.2245688348439669 for 390 rounds
#
# CV with eta=0.01
# [19:10:29] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:10:29] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:10:29] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:10:29] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:10:29] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.22468812211289343 for 998 rounds
#
# CV with eta=0.005
# [19:17:30] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:17:31] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:17:31] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:17:31] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [19:17:31] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.2268967687348597 for 998 rounds
#
# Best params: 0.05, MAE: 0.2245688348439669

# %%
params['eta'] = .05

# %%
params
# Out:
# {'max_depth': 11,
#  'min_child_weight': 5,
#  'eta': 0.05,
#  'subsample': 1.0,
#  'colsample_bytree': 1.0,
#  'objective': 'reg:linear',
#  'eval_metric': 'mae',
#  'base_score': 0.3401111111111111}

# %%
model = xgb.train(
    params,
    dtrain,
    num_boost_round=num_boost_round,
    evals=[(dtest, "Test")],
    early_stopping_rounds=10
)
# Out:
# [13:13:50] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	Test-mae:0
# [967]	Test-mae:0.21982
# [968]	Test-mae:0.21982
# [969]	Test-mae:0.21982
# [970]	Test-mae:0.21982
# [971]	Test-mae:0.21982
# [972]	Test-mae:0.21982
# [973]	Test-mae:0.21983
# [974]	Test-mae:0.21983
# [975]	Test-mae:0.21982
# [976]	Test-mae:0.21982
# [977]	Test-mae:0.21982
# [978]	Test-mae:0.21983
# [979]	Test-mae:0.21983
# [980]	Test-mae:0.21983
# [981]	Test-mae:0.21983
# [982]	Test-mae:0.21983
# [983]	Test-mae:0.21983
# [984]	Test-mae:0.21982
# [985]	Test-mae:0.21982
# [986]	Test-mae:0.21983
# [987]	Test-mae:0.21983
# [988]	Test-mae:0.21984
# [989]	Test-mae:0.21984
# [990]	Test-mae:0.21984
# [991]	Test-mae:0.21985
# [992]	Test-mae:0.21984
# [993]	Test-mae:0.21984
# [994]	Test-mae:0.21985
# [995]	Test-mae:0.21985
# [996]	Test-mae:0.21985
# [997]	Test-mae:0.21985
# [998]	Test-mae:0.21985

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(best_model.predict(dtest), y_test2)
# Out:
# 0.21984950855260044

# %% [markdown]
# ### Guardado del modelo y predicciones.
# -------------------------------------------------------------------------------------------------------------------------------

# %%
best_model.save_model("SHAP.model")

# %%
loaded_model = xgb.Booster()
loaded_model.load_model("SHAP.model")
# And use it for predictions.
# Out:
# [13:15:57] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.

# %%
Prediccion = loaded_model.predict(dtest)

# %%
Prediccion.min()
# Out:
# -0.2048758

# %%
Prediccion.max()
# Out:
# 1.2268773

# %%
from sklearn.metrics import confusion_matrix, f1_score, precision_score, recall_score, accuracy_score, classification_report, roc_curve, auc, roc_auc_score, ConfusionMatrixDisplay

# %%
testing_list =[]
for i in  np.linspace(0.1,0.9,9):
    d = {}
    y_p = Prediccion >= i
    print("Threshold:",i)
    cm = confusion_matrix(y_test2,y_p)
    d["th"] = i
    d["F1"] = np.round(f1_score(y_test2,y_p),2)
    d["Prec"] = np.round(precision_score(y_test2,y_p),2)
    d["Rec"] = np.round(recall_score(y_test2,y_p),2)
    d["Acc"] = np.round(accuracy_score(y_test2,y_p),2)
    d["RocAuc"] = np.round(roc_auc_score(y_test2,y_p),2)
    testing_list.append(d)
# Out:
# Threshold: 0.1
# Threshold: 0.2
# Threshold: 0.30000000000000004
# Threshold: 0.4
# Threshold: 0.5
# Threshold: 0.6
# Threshold: 0.7000000000000001
# Threshold: 0.8
# Threshold: 0.9

# %% [markdown]
# # Metricas para cada umbral.
# - th: umbral
# -------------------------------------------------------------------------------------------------------------------------------

# %%
testing_metrics_pd = pd.DataFrame(testing_list)
testing_metrics_pd
# Out:
#     th    F1  Prec   Rec   Acc  RocAuc
# 0  0.1  0.68  0.53  0.96  0.69    0.76
# 1  0.2  0.74  0.62  0.92  0.78    0.81
# 2  0.3  0.76  0.69  0.86  0.82    0.83
# 3  0.4  0.77  0.75  0.80  0.84    0.83
# 4  0.5  0.77  0.80  0.74  0.85    0.82
# 5  0.6  0.75  0.84  0.67  0.85    0.80
# 6  0.7  0.70  0.88  0.59  0.83    0.77
# 7  0.8  0.62  0.91  0.47  0.80    0.72
# 8  0.9  0.46  0.94  0.31  0.76    0.65

# %%
print(testing_metrics_pd.to_latex(index=False))
# Out:
# \begin{tabular}{rrrrrr}
# \toprule
#  th &   F1 &  Prec &  Rec &  Acc &  RocAuc \\
# \midrule
# 0.1 & 0.68 &  0.53 & 0.96 & 0.69 &    0.76 \\
# 0.2 & 0.74 &  0.62 & 0.92 & 0.78 &    0.81 \\
# 0.3 & 0.76 &  0.69 & 0.86 & 0.82 &    0.83 \\
# 0.4 & 0.77 &  0.75 & 0.80 & 0.84 &    0.83 \\
# 0.5 & 0.77 &  0.80 & 0.74 & 0.85 &    0.82 \\
# 0.6 & 0.75 &  0.84 & 0.67 & 0.85 &    0.80 \\
# 0.7 & 0.70 &  0.88 & 0.59 & 0.83 &    0.77 \\
# 0.8 & 0.62 &  0.91 & 0.47 & 0.80 &    0.72 \\
# 0.9 & 0.46 &  0.94 & 0.31 & 0.76 &    0.65 \\
# \bottomrule
# \end{tabular}

# %%
fpr, tpr, ths = roc_curve(y_test2,  Prediccion)
auc_ = auc(fpr, tpr)
plt.plot(fpr,tpr, label='ROC curve (area = %.2f)' %auc_)
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.legend()
plt.grid()
plt.show()

# %%
for i in  np.linspace(0.1,0.9,9):
    print(i)
    y_p = Prediccion >= i
    print(classification_report(y_test2, y_p))
    f1 = f1_score(y_test2, y_p)
    prec = precision_score(y_test2, y_p)
    rec = recall_score(y_test2, y_p)
    acc = accuracy_score(y_test2, y_p)
    cm=confusion_matrix(y_test2, y_p)
    print("Matriz de confusión: ")
    print(cm)
    print("----------------------------------------------------------")
    print("F1: %.2f" %f1 , " -- prec: %.2f" %prec, " -- recall: %.2f" %rec, " -- acc: %.2f" %acc)
    print("----------------------------------------------------------")
# Out:
# 0.1
#               precision    recall  f1-score   support
#
#            0       0.97      0.56      0.71     19828
#            1       0.53      0.96      0.68     10172
#
#     accuracy                           0.69     30000
#    macro avg       0.75      0.76      0.69     30000
# weighted avg       0.82      0.69      0.70     30000
#
# Matriz de confusión:
# [[11032  8796]
#  [  396  9776]]
# ----------------------------------------------------------
# F1: 0.68  -- prec: 0.53  -- recall: 0.96  -- acc: 0.69
# ----------------------------------------------------------
# 0.2
#               precision    recall  f1-score   support
#
#            0       0.94      0.71      0.81     19828
#            1       0.62      0.92      0.74     10172
#
#     accuracy                           0.78     30000
#    macro avg       0.78      0.81      0.77     30000
# weighted avg       0.83      0.78      0.79     30000
#
# Matriz de confusión:
# [[14093  5735]
#  [  847  9325]]
# ----------------------------------------------------------
# F1: 0.74  -- prec: 0.62  -- recall: 0.92  -- acc: 0.78
# ----------------------------------------------------------
# 0.30000000000000004
#               precision    recall  f1-score   support
#
#            0       0.92      0.80      0.85     19828
#            1       0.69      0.86      0.76     10172
#
#     accuracy                           0.82     30000
#    macro avg       0.80      0.83      0.81     30000
# weighted avg       0.84      0.82      0.82     30000
#
# Matriz de confusión:
# [[15823  4005]
#  [ 1393  8779]]
# ----------------------------------------------------------
# F1: 0.76  -- prec: 0.69  -- recall: 0.86  -- acc: 0.82
# ----------------------------------------------------------
# 0.4
#               precision    recall  f1-score   support
#
#            0       0.90      0.86      0.88     19828
#            1       0.75      0.80      0.77     10172
#
#     accuracy                           0.84     30000
#    macro avg       0.82      0.83      0.83     30000
# weighted avg       0.85      0.84      0.84     30000
#
# Matriz de confusión:
# [[17064  2764]
#  [ 1990  8182]]
# ----------------------------------------------------------
# F1: 0.77  -- prec: 0.75  -- recall: 0.80  -- acc: 0.84
# ----------------------------------------------------------
# 0.5
#               precision    recall  f1-score   support
#
#            0       0.87      0.90      0.89     19828
#            1       0.80      0.74      0.77     10172
#
#     accuracy                           0.85     30000
#    macro avg       0.83      0.82      0.83     30000
# weighted avg       0.85      0.85      0.85     30000
#
# Matriz de confusión:
# [[17911  1917]
#  [ 2631  7541]]
# ----------------------------------------------------------
# F1: 0.77  -- prec: 0.80  -- recall: 0.74  -- acc: 0.85
# ----------------------------------------------------------
# 0.6
#               precision    recall  f1-score   support
#
#            0       0.85      0.93      0.89     19828
#            1       0.84      0.67      0.75     10172
#
#     accuracy                           0.85     30000
#    macro avg       0.84      0.80      0.82     30000
# weighted avg       0.84      0.85      0.84     30000
#
# Matriz de confusión:
# [[18529  1299]
#  [ 3339  6833]]
# ----------------------------------------------------------
# F1: 0.75  -- prec: 0.84  -- recall: 0.67  -- acc: 0.85
# ----------------------------------------------------------
# 0.7000000000000001
#               precision    recall  f1-score   support
#
#            0       0.82      0.96      0.88     19828
#            1       0.88      0.59      0.70     10172
#
#     accuracy                           0.83     30000
#    macro avg       0.85      0.77      0.79     30000
# weighted avg       0.84      0.83      0.82     30000
#
# Matriz de confusión:
# [[19004   824]
#  [ 4205  5967]]
# ----------------------------------------------------------
# F1: 0.70  -- prec: 0.88  -- recall: 0.59  -- acc: 0.83
# ----------------------------------------------------------
# 0.8
#               precision    recall  f1-score   support
#
#            0       0.78      0.98      0.87     19828
#            1       0.91      0.47      0.62     10172
#
#     accuracy                           0.80     30000
#    macro avg       0.85      0.72      0.74     30000
# weighted avg       0.83      0.80      0.78     30000
#
# Matriz de confusión:
# [[19359   469]
#  [ 5385  4787]]
# ----------------------------------------------------------
# F1: 0.62  -- prec: 0.91  -- recall: 0.47  -- acc: 0.80
# ----------------------------------------------------------
# 0.9
#               precision    recall  f1-score   support
#
#            0       0.74      0.99      0.84     19828
#            1       0.94      0.31      0.46     10172
#
#     accuracy                           0.76     30000
#    macro avg       0.84      0.65      0.65     30000
# weighted avg       0.81      0.76      0.72     30000
#
# Matriz de confusión:
# [[19644   184]
#  [ 7037  3135]]
# ----------------------------------------------------------
# F1: 0.46  -- prec: 0.94  -- recall: 0.31  -- acc: 0.76
# ----------------------------------------------------------

# %%
umbral = 0.4

# %%
maskSignal=Prediccion>umbral

# %%
predicBin=[]
for i in maskSignal:
    if(i==True):
        predicBin.append(1)
    else:
        predicBin.append(0)

# %%
npPredict=np.array(predicBin)

# %%
cm=confusion_matrix(y_test2, npPredict)
cm
# Out:
# array([[17064,  2764],
#        [ 1990,  8182]], dtype=int64)

# %%
cm_display = ConfusionMatrixDisplay(cm).plot()

# %%
f1= f1_score(y_test2, npPredict)
f1
# Out:
# 0.7748839852258737

# %%
prec=precision_score(y_test2, npPredict)
prec
# Out:
# 0.7474876667275717

# %%
rec=recall_score(y_test2, npPredict)
rec
# Out:
# 0.8043649233189146

# %%
accu=accuracy_score(y_test2, npPredict)
accu
# Out:
# 0.8415333333333334

# %%
print(classification_report(y_test2, npPredict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.86      0.88     19828
#            1       0.75      0.80      0.77     10172
#
#     accuracy                           0.84     30000
#    macro avg       0.82      0.83      0.83     30000
# weighted avg       0.85      0.84      0.84     30000

# %%
print("F1: %.2f" %f1 , " -- prec: %.2f" %prec, " -- recall: %.2f" %rec, " -- acc: %.2f" %acc)
# Out:
# F1: 0.77  -- prec: 0.75  -- recall: 0.80  -- acc: 0.76
