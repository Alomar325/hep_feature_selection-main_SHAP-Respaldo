# %% [markdown]
# # SHAP
#
# ### Clasificación de eventos usando SHAP como seleccionador de características con la totalidad de los datos.

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------
#
# Alex Toro, Raquel Pezoa

# %% [markdown]
# ## Librerias necesarias-
# -------------------------------------------------------------------------------------------------------------------------------

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from xgboost import XGBClassifier
import shap
from sklearn.model_selection import train_test_split

# %%
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV

# %%
import xgboost as xgb

# %%
import winsound

# %%
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %% [markdown]
# ## Lectura del set de datos reducido.
#
# - El set original proviene de https://www.kaggle.com/competitions/higgs-boson/data.
# - Separación de la variable Label de las demas variables.
# -------------------------------------------------------------------------------------------------------------------------------

# %%
df = pd.read_csv("/Users/Alex/Downloads/Pre-procesado_completo.csv")
# Este con el set de datos completo

# %%
X = df.drop(labels=['Label'], axis=1)
Y = df['Label']
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=0)

# %%
#guardar X_test e y_test
#cargar esos test para usar el  modelo generado en SHAP-Reducido-20%
#tomar en X_test lo que me entrega SHAP reducido
#predecir usando el modelo de SHAP-Reducido-20%
X_test.to_csv('X_testSHAP.csv', header=False, index=False)
y_test.to_csv('y_testSHAP.csv', header=False, index=False)

# %%
X_test.shape
# Out:
# (163648, 30)

# %%
params={
 "learning_rate"    : [0.05, 0.10, 0.15, 0.20, 0.25, 0.30 ] ,
 "max_depth"        : [ 3, 4, 5, 6, 8, 10, 12, 15],
 "min_child_weight" : [ 1, 3, 5, 7 ],
 "gamma"            : [ 0.0, 0.1, 0.2 , 0.3, 0.4 ],
 "colsample_bytree" : [ 0.3, 0.4, 0.5 , 0.7 ]
    
}

# %%
classifier=XGBClassifier()

# %%
random_search=RandomizedSearchCV(classifier,param_distributions=params,n_iter=5,scoring='roc_auc',n_jobs=-1,cv=5,verbose=3)

# %%
random_search.fit(X_train,y_train) # el de 5 iteraciones
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits

# %%
frequency = 2500  # Set Frequency To 2500 Hertz
duration = 1000  # Set Duration To 1000 ms == 1 second
winsound.Beep(frequency, duration)

# %%
print(random_search.best_estimator_) # 5 iteraciones
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=0.5,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0.3, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.3, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=15, max_leaves=0, min_child_weight=3,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, predictor='auto', random_state=0,
#               reg_alpha=0, reg_lambda=1, ...)

# %%
random_search.best_params_ # 5 iteraciones
# Out:
# {'min_child_weight': 3,
#  'max_depth': 15,
#  'learning_rate': 0.3,
#  'gamma': 0.3,
#  'colsample_bytree': 0.5}

# %% [markdown]
# ### Entrenamiento y testeo del set de datos con XGBoost.
#
# - Se entrena con XGBClassifier antes de usar SHAP, ya que SHAP necesita con aterioridad un modelo entrenado.
# -------------------------------------------------------------------------------------------------------------------------------

# %%
model = XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=0.3,
              early_stopping_rounds=None, enable_categorical=False,
              eval_metric=None, gamma=0.1, gpu_id=-1, grow_policy='depthwise',
              importance_type=None, interaction_constraints='',
              learning_rate=0.2, max_bin=256, max_cat_to_onehot=4,
              max_delta_step=0, max_depth=15, max_leaves=0, min_child_weight=5,
              missing=None, monotone_constraints='()', n_estimators=100,
              n_jobs=0, num_parallel_tree=1, predictor='auto', random_state=0,
              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None, silent=True,
       subsample=1)
model.get_params()
#con el mejor parametro del SHAp 20%
# Out:
# {'objective': 'binary:logistic',
#  'use_label_encoder': False,
#  'base_score': 0.5,
#  'booster': 'gbtree',
#  'callbacks': None,
#  'colsample_bylevel': 1,
#  'colsample_bynode': 1,
#  'colsample_bytree': 0.5,
#  'early_stopping_rounds': None,
#  'enable_categorical': False,
#  'eval_metric': None,
#  'gamma': 0.3,
#  'gpu_id': -1,
#  'grow_policy': 'depthwise',
#  'importance_type': None,
#  'interaction_constraints': '',
#  'learning_rate': 0.3,
#  'max_bin': 256,
#  'max_cat_to_onehot': 4,
#  'max_delta_step': 0,
#  'max_depth': 15,
#  'max_leaves': 0,
#  'min_child_weight': 3,
#  'missing': None,
#  'monotone_constraints': '()',
#  'n_estimators': 100,
#  'n_jobs': 0,
#  'num_parallel_tree': 1,
#  'predictor': 'auto',
#  'random_state': 0,
#  'reg_alpha': 0,
#  'reg_lambda': 1,
#  'sampling_method': None,
#  'scale_pos_weight': 1,
#  'subsample': 1,
#  'tree_method': None,
#  'validate_parameters': None,
#  'verbosity': None,
#  'seed': None,
#  'silent': True}

# %%
model.fit(X_train, y_train)
# Out:
# [14:53:32] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=0.5,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0.3, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.3, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=15, max_leaves=0, min_child_weight=3,
#               missing=None, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, predictor='auto', random_state=0,
#               reg_alpha=0, reg_lambda=1, ...)

# %% [markdown]
# ### SHAP seleccionado características.

# %%
# Fits the explainer
explainer = shap.TreeExplainer(model = model)
# Calculates the SHAP values - It takes some time

# %%
# Evaluate SHAP values
shap_values = explainer.shap_values(X_test)
# Out:
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %% [markdown]
# ### Waterfall plot
#
# - Esta gráfica muestra cómo las características contribuyen a impulsar la predicción del clasificador desde el valor base (la predicción promedio del modelo sobre el conjunto de datos de entrenamiento) hasta la salida del modelo, de una muestra de datos específica.
# - Las características que empujan la predicción más alta se muestran en rojo, las que empujan la predicción más baja están en azul.
# -------------------------------------------------------------------------------------------------------------------------------

# %%
i=4
shap.plots._waterfall.waterfall_legacy(explainer.expected_value, 
                                       shap_values[i],
                                       feature_names = X_train.columns, 
                                       show = True,
                                      max_display=10)
# el numero es lo que contribuye en el dato en la posicion 4 (un evento)

# %% [markdown]
# ### Summary Plots
# - Ranking de las mejore 20 características
# -------------------------------------------------------------------------------------------------------------------------------

# %%
shap.summary_plot(shap_values, X_test, plot_type="bar")

# %%
X_test
# Out:
#         DER_mass_MMC  DER_mass_transverse_met_lep  DER_mass_vis  DER_pt_h  \
# 59024        106.530                       65.749        63.599   144.152
# 136820        87.263                       31.403        69.194   112.327
# 746100       111.784                       24.642        86.294    92.428
# 434878       148.929                       42.176       102.889   159.921
# 616295       138.258                       67.402        58.106    65.591
# ...              ...                          ...           ...       ...
# 120426        85.372                       57.512        65.516    28.594
# 797028        77.955                        5.029        49.793   121.087
# 110306       247.910                       70.673       212.696    23.340
# 589217      -999.000                       68.899        38.434     2.129
# 407918       262.336                       53.106       176.039    70.847
#
#         DER_deltaeta_jet_jet  DER_mass_jet_jet  DER_prodeta_jet_jet  \
# 59024               -999.000          -999.000             -999.000
# 136820                 3.578           256.089               -2.175
# 746100              -999.000          -999.000             -999.000
# 434878              -999.000          -999.000             -999.000
# 616295              -999.000          -999.000             -999.000
# ...                      ...               ...                  ...
# 120426              -999.000          -999.000             -999.000
# 797028                 2.638           277.648               -1.624
# 110306              -999.000          -999.000             -999.000
# 589217              -999.000          -999.000             -999.000
# 407918              -999.000          -999.000             -999.000
#
#         DER_deltar_tau_lep  DER_pt_tot  DER_sum_pt  ...  PRI_met_phi  \
# 59024                1.596       0.786     224.347  ...       -2.988
# 136820               1.215      37.815     196.755  ...        2.326
# 746100               2.341       2.483     204.372  ...       -2.420
# 434878               1.670      26.665     277.078  ...        1.379
# 616295               2.534       0.655     128.326  ...       -1.313
# ...                    ...         ...         ...  ...          ...
# 120426               2.950      28.594      63.421  ...       -0.511
# 797028               1.266      24.668     232.336  ...       -1.321
# 110306               3.750      23.340      85.456  ...       -0.764
# 589217               1.300       2.129      63.857  ...       -2.728
# 407918               3.363      28.298     201.045  ...        2.731
#
#         PRI_met_sumet  PRI_jet_num  PRI_jet_leading_pt  PRI_jet_leading_eta  \
# 59024         240.991            1             143.764               -1.086
# 136820        270.068            2              49.912               -2.802
# 746100        241.046            1              93.925               -0.622
# 434878        262.156            1             141.307                1.747
# 616295        100.902            1              66.229                1.246
# ...               ...          ...                 ...                  ...
# 120426        155.133            0            -999.000             -999.000
# 797028        245.209            2             104.058               -1.658
# 110306        118.230            0            -999.000             -999.000
# 589217        112.763            0            -999.000             -999.000
# 407918        261.732            1              86.735                2.975
#
#         PRI_jet_leading_phi  PRI_jet_subleading_pt  PRI_jet_subleading_eta  \
# 59024                 0.417               -999.000                -999.000
# 136820               -2.667                 37.705                   0.776
# 746100                1.108               -999.000                -999.000
# 434878               -1.500               -999.000                -999.000
# 616295                1.501               -999.000                -999.000
# ...                     ...                    ...                     ...
# 120426             -999.000               -999.000                -999.000
# 797028                1.479                 49.517                   0.980
# 110306             -999.000               -999.000                -999.000
# 589217             -999.000               -999.000                -999.000
# 407918                0.121               -999.000                -999.000
#
#         PRI_jet_subleading_phi  PRI_jet_all_pt
# 59024                 -999.000         143.764
# 136820                  -1.745          87.616
# 746100                -999.000          93.925
# 434878                -999.000         141.307
# 616295                -999.000          66.229
# ...                        ...             ...
# 120426                -999.000           0.000
# 797028                  -2.837         153.576
# 110306                -999.000          -0.000
# 589217                -999.000          -0.000
# 407918                -999.000          86.735
#
# [8183 rows x 30 columns]

# %%
shap_values
# Out:
# array([[ 2.59135604e-01, -3.78609836e-01,  2.49288738e-01, ...,
#          3.62614207e-02,  7.12494552e-03,  4.80583310e-02],
#        [-1.41904283e+00,  2.07198888e-01, -2.10177470e-02, ...,
#         -1.25535503e-01,  7.80970091e-04,  1.44523710e-01],
#        [ 2.65217602e-01,  6.41976297e-01,  4.70750511e-01, ...,
#          9.95663833e-03, -2.06492692e-02,  8.75622928e-02],
#        ...,
#        [-6.83732331e-01, -8.61938715e-01, -2.23578668e+00, ...,
#          1.88725553e-02,  5.18741691e-03, -3.87721695e-02],
#        [-1.25985324e+00, -5.51973939e-01, -2.35264137e-01, ...,
#          1.53149245e-02,  2.15979246e-03, -3.44533361e-02],
#        [-9.41749752e-01, -2.19555601e-01, -1.81504452e+00, ...,
#         -5.07983891e-03,  1.27137424e-02,  6.94387704e-02]], dtype=float32)

# %% [markdown]
# ### Obteniendo la media de los valores absolutos de SHAP (|SHAP value|).
# -------------------------------------------------------------------------------------------------------------------------------

# %%
meanL = []
for valus in range(0,len(shap_values)):
    for singularidad in range(0,len(shap_values[valus])):
        if valus==0:
            meanL.append(abs(shap_values[valus][singularidad]))
        else:
            meanL[singularidad]=meanL[singularidad]+abs(shap_values[valus][singularidad])

# %% [markdown]
# ### Convertir los datos a  una lista de duplas.
#
# - Se convierte la media de los valores absolutos de SHAP junto a las columnas del dataframe en una lista de duplas.
# - Se realizan las duplas para así poder reordenar las variables de la más relevante a la menos relevante.
# - Se Reordena la duplas de mayor a menor.
# - Se separan las duplas en listas separadas y transformar las 20 primeras en arreglos de numpy.
# -------------------------------------------------------------------------------------------------------------------------------

# %%
meanL=list(map(lambda x: x / len(shap_values), meanL))
l=[]
for feature in zip(meanL,X_train.columns):
    l.append(feature)
    print(feature)
# Out:
# (0.7952142589820359, 'DER_mass_MMC')
# (0.548031945515856, 'DER_mass_transverse_met_lep')
# (0.3938058393735488, 'DER_mass_vis')
# (0.14872751209156942, 'DER_pt_h')
# (0.0921292081812141, 'DER_deltaeta_jet_jet')
# (0.10647752694944931, 'DER_mass_jet_jet')
# (0.051488024876983916, 'DER_prodeta_jet_jet')
# (0.27211106127986373, 'DER_deltar_tau_lep')
# (0.11465957941817258, 'DER_pt_tot')
# (0.22978506376118935, 'DER_sum_pt')
# (0.10813923014939508, 'DER_pt_ratio_lep_tau')
# (0.2153270786233655, 'DER_met_phi_centrality')
# (0.15540019192323262, 'DER_lep_eta_centrality')
# (0.36137460808612365, 'PRI_tau_pt')
# (0.11503723211660226, 'PRI_tau_eta')
# (0.052722832545607126, 'PRI_tau_phi')
# (0.06041199051196077, 'PRI_lep_pt')
# (0.1541513692162868, 'PRI_lep_eta')
# (0.04705614008152381, 'PRI_lep_phi')
# (0.14328253171590494, 'PRI_met')
# (0.05030395179626398, 'PRI_met_phi')
# (0.1016967206570596, 'PRI_met_sumet')
# (0.03847436812837972, 'PRI_jet_num')
# (0.10222610721637083, 'PRI_jet_leading_pt')
# (0.2624788290128926, 'PRI_jet_leading_eta')
# (0.0383178718396275, 'PRI_jet_leading_phi')
# (0.03929166340469571, 'PRI_jet_subleading_pt')
# (0.040164336356384805, 'PRI_jet_subleading_eta')
# (0.018409069834661035, 'PRI_jet_subleading_phi')
# (0.0645035910720014, 'PRI_jet_all_pt')

# %%
l.sort(reverse=True)
l
# Out:
# [(0.7952142589820359, 'DER_mass_MMC'),
#  (0.548031945515856, 'DER_mass_transverse_met_lep'),
#  (0.3938058393735488, 'DER_mass_vis'),
#  (0.36137460808612365, 'PRI_tau_pt'),
#  (0.27211106127986373, 'DER_deltar_tau_lep'),
#  (0.2624788290128926, 'PRI_jet_leading_eta'),
#  (0.22978506376118935, 'DER_sum_pt'),
#  (0.2153270786233655, 'DER_met_phi_centrality'),
#  (0.15540019192323262, 'DER_lep_eta_centrality'),
#  (0.1541513692162868, 'PRI_lep_eta'),
#  (0.14872751209156942, 'DER_pt_h'),
#  (0.14328253171590494, 'PRI_met'),
#  (0.11503723211660226, 'PRI_tau_eta'),
#  (0.11465957941817258, 'DER_pt_tot'),
#  (0.10813923014939508, 'DER_pt_ratio_lep_tau'),
#  (0.10647752694944931, 'DER_mass_jet_jet'),
#  (0.10222610721637083, 'PRI_jet_leading_pt'),
#  (0.1016967206570596, 'PRI_met_sumet'),
#  (0.0921292081812141, 'DER_deltaeta_jet_jet'),
#  (0.0645035910720014, 'PRI_jet_all_pt'),
#  (0.06041199051196077, 'PRI_lep_pt'),
#  (0.052722832545607126, 'PRI_tau_phi'),
#  (0.051488024876983916, 'DER_prodeta_jet_jet'),
#  (0.05030395179626398, 'PRI_met_phi'),
#  (0.04705614008152381, 'PRI_lep_phi'),
#  (0.040164336356384805, 'PRI_jet_subleading_eta'),
#  (0.03929166340469571, 'PRI_jet_subleading_pt'),
#  (0.03847436812837972, 'PRI_jet_num'),
#  (0.0383178718396275, 'PRI_jet_leading_phi'),
#  (0.018409069834661035, 'PRI_jet_subleading_phi')]

# %%
l_v = []
for importance in range(len(l)):
    for var in range(len(l[importance])):
        if(var == 1):
            l_v.append(l[importance][var])

# %%
x = np.array(l_v[0:20])
x
# Out:
# array(['DER_mass_MMC', 'DER_mass_transverse_met_lep', 'DER_mass_vis',
#        'PRI_tau_pt', 'DER_deltar_tau_lep', 'PRI_jet_leading_eta',
#        'DER_sum_pt', 'DER_met_phi_centrality', 'DER_lep_eta_centrality',
#        'PRI_lep_eta', 'DER_pt_h', 'PRI_met', 'PRI_tau_eta', 'DER_pt_tot',
#        'DER_pt_ratio_lep_tau', 'DER_mass_jet_jet', 'PRI_jet_leading_pt',
#        'PRI_met_sumet', 'DER_deltaeta_jet_jet', 'PRI_jet_all_pt'],
#       dtype='<U27')

# %%
# Force_plot
shap.initjs()
shap.force_plot(explainer.expected_value, shap_values[102,:], X_test.iloc[102,:], link="logit")
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...
# <div id='iOM6UDMZOC1A6E6GB008X'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": -0
# 818236               2.479                1.460     101.676
# 818237               2.486             -999.000      77.348
#
#         DER_met_phi_centrality  DER_lep_eta_centrality  PRI_lep_eta  DER_pt_h  \
# 0                        1.396                   0.200        2.273    27.980
# 1                        1.414                -999.000        0.501    48.146
# 2                        1.414                -999.000       -0.953    35.635
# 3                       -1.285                -999.000       -0.522     0.414
# 4                       -1.385                -999.000        0.798    16.405
# ...                        ...                     ...          ...       ...
# 818233                   1.343                   0.000        2.098   156.191
# 818234                   1.398                   0.586       -1.573    65.861
# 818235                  -0.836                -999.000        1.087    18.006
# 818236                   1.410                -999.000       -1.216    29.761
# 818237                  -1.346                -999.000        0.846     3.984
#
#         PRI_met  PRI_tau_eta  DER_pt_tot  DER_pt_ratio_lep_tau  \
# 0        16.824        1.017      41.928                 1.582
# 1        44.704        2.039       2.078                 0.879
# 2        54.283       -0.705       9.336                 3.776
# 3        31.082       -1.655       0.414                 2.354
# 4         2.723       -2.197      16.405                 1.056
# ...         ...          ...         ...                   ...
# 818233   72.892        2.074       6.133                 0.659
# 818234   34.940       -1.724       2.889                 1.429
# 818235   30.463        1.057      18.006                 0.642
# 818236    6.647       -1.249       2.739                 0.936
# 818237   35.463        1.800       3.984                 1.683
#
#         DER_mass_jet_jet  PRI_jet_leading_pt  PRI_met_sumet  \
# 0                124.711              67.435        258.733
# 1               -999.000              46.226        164.546
# 2               -999.000              44.251        260.414
# 3               -999.000            -999.000         86.062
# 4               -999.000            -999.000         53.131
# ...                  ...                 ...            ...
# 818233            47.746             112.264        303.668
# 818234           471.319             108.698        266.919
# 818235          -999.000            -999.000        188.648
# 818236          -999.000              30.863        212.565
# 818237          -999.000            -999.000         97.379
#
#         DER_deltaeta_jet_jet  PRI_jet_all_pt
# 0                      0.910         113.497
# 1                   -999.000          46.226
# 2                   -999.000          44.251
# 3                   -999.000          -0.000
# 4                   -999.000           0.000
# ...                      ...             ...
# 818233                 0.403         154.056
# 818234                 3.312         178.856
# 818235              -999.000          -0.000
# 818236              -999.000          30.863
# 818237              -999.000          -0.000
#
# [818238 rows x 20 columns]

# %% [markdown]
# ### Entrenamiento, testeo y optimizacion de parametros de DMatrix de XGBoost con las variables entregadas por SHAP.
# -------------------------------------------------------------------------------------------------------------------------------

# %%
X_train2, X_test2, y_train2, y_test2 = train_test_split(X_train2, Y, test_size=0.2, random_state=0)

# %%
dtrain = xgb.DMatrix(X_train2, label=y_train2)
dtest = xgb.DMatrix(X_test2, label=y_test2) # este dtest contiene las 20 variables obtenidas mediante SHAP

# %%
params = {
    # Parameters that we are going to tune.
    'max_depth':6,
    'min_child_weight': 1,
    'eta':.3,
    'subsample': 1,
    'colsample_bytree': 1,
    # Other parameters
    'objective':'reg:linear',
}
params['eval_metric'] = "mae"
params['base_score'] = np.mean(y_train)
num_boost_round = 999

# %%
modelo = xgb.train( 
    params, 
    dtrain, 
    num_boost_round=num_boost_round, 
    evals=[(dtest, "Test")], 
    early_stopping_rounds=10 
)
# Out:
# [14:57:23] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	Test-mae:0.39424
# [1]	Test-mae:0.35400
# [2]	Test-mae:0.32499
# [3]	Test-mae:0.30325
# [4]	Test-mae:0.28733
# [5]	Test-mae:0.27545
# [6]	Test-mae:0.26617
# [7]	Test-mae:0.25993
# [8]	Test-mae:0.25526
# [9]	Test-mae:0.25176
# [10]	Test-mae:0.24835
# [11]	Test-mae:0.24660
# [12]	Test-mae:0.24411
# [13]	Test-mae:0.24256
-mae-mean  train-mae-std  test-mae-mean  test-mae-std
# 0          0.394443       0.000088       0.394702      0.000234
# 1          0.354300       0.000195       0.354773      0.000520
# 2          0.325129       0.000141       0.325794      0.000479
# 3          0.303120       0.000358       0.303963      0.000442
# 4          0.286830       0.000267       0.287810      0.000597
# ..              ...            ...            ...           ...
# 119        0.222552       0.000266       0.231174      0.000658
# 120        0.222508       0.000282       0.231175      0.000650
# 121        0.222455       0.000288       0.231178      0.000646
# 122        0.222386       0.000273       0.231165      0.000641
# 123        0.222327       0.000270       0.231165      0.000626
#
# [124 rows x 4 columns]

# %%
cv_results['test-mae-mean'].min()
# Out:
# 0.2311652446146249

# %%
gridsearch_params = [
    (max_depth, min_child_weight)
    for max_depth in range(9,12)
    for min_child_weight in range(5,8)
]

# %%
min_mae = float("Inf")
best_params = None
for max_depth, min_child_weight in gridsearch_params:
    print("CV with max_depth={}, min_child_weight={}".format(
                             max_depth,
                             min_child_weight))
    # Update our parameters
    params['max_depth'] = max_depth
    params['min_child_weight'] = min_child_weight
    # Run CV
    cv_results = xgb.cv(
        params,
        dtrain,
        num_boost_round=num_boost_round,
        seed=42,
        nfold=5,
        metrics={'mae'},
        early_stopping_rounds=10
    )
    # Update best MAE
    mean_mae = cv_results['test-mae-mean'].min()
    boost_rounds = cv_results['test-mae-mean'].argmin()
    print("\tMAE {} for {} rounds".format(mean_mae, boost_rounds))
    if mean_mae < min_mae:
        min_mae = mean_mae
        best_params = (max_depth,min_child_weight)
print("Best params: {}, {}, MAE: {}".format(best_params[0], best_params[1], min_mae))
frequency = 2500  # Set Frequency To 2500 Hertz
duration = 1000  # Set Duration To 1000 ms == 1 second
winsound.Beep(frequency, duration)
# Out:
# CV with max_depth=9, min_child_weight=5
# [15:00:55] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:00:56] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:00:57] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:00:57] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:00:58] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.2274950214685522 for 37 rounds
# CV with max_depth=9, min_child_weight=6
# [15:02:50] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:02:51] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:02:51] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:02:52] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:02:53] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.22774205839601622 for 36 rounds
# CV with max_depth=9, min_child_weight=7
# [15:04:41] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:04:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:04:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:04:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:04:44] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.22774386654997042 for 30 rounds
# CV with max_depth=10, min_child_weight=5
# [15:06:23] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:06:24] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:06:25] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:06:26] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:06:27] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.22693663117451585 for 25 rounds
# CV with max_depth=10, min_child_weight=6
# [15:08:12] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:08:13] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:08:14] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:08:15] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:08:16] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.22690353482954703 for 21 rounds
# CV with max_depth=10, min_child_weight=7
# [15:09:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:09:48] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:09:48] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:09:49] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:09:50] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.22696253439542446 for 26 rounds
# CV with max_depth=11, min_child_weight=5
# [15:11:30] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:11:31] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:11:32] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:11:33] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:11:34] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.22661037967834372 for 23 rounds
# CV with max_depth=11, min_child_weight=6
# [15:13:14] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:13:15] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:13:16] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:13:17] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:13:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.22650256174161698 for 21 rounds
# CV with max_depth=11, min_child_weight=7
# [15:14:58] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:14:59] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:15:00] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:15:01] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:15:02] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.2266539424126532 for 22 rounds
# Best params: 11, 6, MAE: 0.22650256174161698

# %%
params['max_depth'] = 11
params['min_child_weight'] = 6

# %%
gridsearch_params = [
    (subsample, colsample)
    for subsample in [i/10. for i in range(7,11)]
    for colsample in [i/10. for i in range(7,11)]
]

# %%
min_mae = float("Inf")
best_params = None
# We start by the largest values and go down to the smallest
for subsample, colsample in reversed(gridsearch_params):
    print("CV with subsample={}, colsample={}".format(
                             subsample,
                             colsample))
    # We update our parameters
    params['subsample'] = subsample
    params['colsample_bytree'] = colsample
    # Run CV
    cv_results = xgb.cv(
        params,
        dtrain,
        num_boost_round=num_boost_round,
        seed=42,
        nfold=5,
        metrics={'mae'},
        early_stopping_rounds=10
    )
    # Update best score
    mean_mae = cv_results['test-mae-mean'].min()
    boost_rounds = cv_results['test-mae-mean'].argmin()
    print("\tMAE {} for {} rounds".format(mean_mae, boost_rounds))
    if mean_mae < min_mae:
        min_mae = mean_mae
        best_params = (subsample,colsample)
print("Best params: {}, {}, MAE: {}".format(best_params[0], best_params[1], min_mae))
frequency = 2500  # Set Frequency To 2500 Hertz
duration = 1000  # Set Duration To 1000 ms == 1 second
winsound.Beep(frequency, duration)
# Out:
# CV with subsample=1.0, colsample=1.0
# [15:17:15] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:17:16] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:17:17] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:17:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:17:19] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.22650256174161698 for 21 rounds
# CV with subsample=1.0, colsample=0.9
# [15:18:57] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:18:58] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:18:59] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:19:00] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:19:01] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.22786052960419467 for 20 rounds
# CV with subsample=1.0, colsample=0.8
# [15:20:31] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:20:32] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:20:33] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:20:33] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:20:34] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.22846022148186823 for 23 rounds
# CV with subsample=1.0, colsample=0.7
# [15:22:03] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:22:04] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:22:05] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:22:05] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:22:06] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.22962701829863205 for 23 rounds
# CV with subsample=0.9, colsample=1.0
# [15:23:27] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:23:28] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:23:28] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:23:29] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:23:30] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.22682873162263045 for 22 rounds
# CV with subsample=0.9, colsample=0.9
# [15:25:14] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:25:15] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:25:15] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:25:16] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:25:17] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.22787682913360033 for 22 rounds
# CV with subsample=0.9, colsample=0.8
# [15:26:50] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:26:51] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:26:52] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:26:52] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:26:53] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.2288114335653096 for 22 rounds
# CV with subsample=0.9, colsample=0.7
# [15:28:16] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:28:17] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:28:17] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:28:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:28:19] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.23015295000857053 for 21 rounds
# CV with subsample=0.8, colsample=1.0
# [15:29:41] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:29:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:29:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:29:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:29:44] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.22696422279222067 for 20 rounds
# CV with subsample=0.8, colsample=0.9
# [15:31:20] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:31:21] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:31:21] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:31:22] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:31:23] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.22837550997099046 for 19 rounds
# CV with subsample=0.8, colsample=0.8
# [15:32:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:32:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:32:48] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:32:49] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:32:49] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.2290736101219913 for 19 rounds
# CV with subsample=0.8, colsample=0.7
# [15:34:07] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:34:08] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:34:09] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:34:09] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:34:10] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.23064292926334704 for 20 rounds
# CV with subsample=0.7, colsample=1.0
# [15:35:23] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:35:24] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:35:25] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:35:26] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:35:26] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.
# [969]	Test-mae:0.22304
# [970]	Test-mae:0.22304
# [971]	Test-mae:0.22304
# [972]	Test-mae:0.22303
# [973]	Test-mae:0.22303
# [974]	Test-mae:0.22303
# [975]	Test-mae:0.22303
# [976]	Test-mae:0.22303
# [977]	Test-mae:0.22303
# [978]	Test-mae:0.22303
# [979]	Test-mae:0.22302
# [980]	Test-mae:0.22302
# [981]	Test-mae:0.22302
# [982]	Test-mae:0.22302
# [983]	Test-mae:0.22302
# [984]	Test-mae:0.22302
# [985]	Test-mae:0.22302
# [986]	Test-mae:0.22302
# [987]	Test-mae:0.22302
# [988]	Test-mae:0.22302
# [989]	Test-mae:0.22302
# [990]	Test-mae:0.22302
# [991]	Test-mae:0.22301
# [992]	Test-mae:0.22301
# [993]	Test-mae:0.22301
# [994]	Test-mae:0.22301
# [995]	Test-mae:0.22301
# [996]	Test-mae:0.22301
# [997]	Test-mae:0.22301
# [998]	Test-mae:0.22300

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(best_model.predict(dtest), y_test2)
# Out:
# 0.22300490977195883

# %% [markdown]
# ### Guardado del modelo y predicciones.
# -------------------------------------------------------------------------------------------------------------------------------

# %%
best_model.save_model("SHAP_Totalidad de datos.model")

# %%
loaded_model = xgb.Booster()
loaded_model.load_model("SHAP_Totalidad de datos.model")
# And use it for predictions.
# Out:
# [18:17:27] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.

# %%
Prediccion = loaded_model.predict(dtest)

# %%
Prediccion.min()
# Out:
# -0.1765218

# %%
Prediccion.max()
# Out:
# 1.1752567

# %%
from sklearn.metrics import confusion_matrix, f1_score, precision_score, recall_score, accuracy_score, classification_report, roc_curve, auc, roc_auc_score, ConfusionMatrixDisplay

# %%
testing_list =[]
for i in  np.linspace(0.1,0.9,9):
    d = {}
    y_p = Prediccion >= i
    print("Threshold:",i)
    cm = confusion_matrix(y_test2,y_p)
    d["th"] = i
    d["F1"] = np.round(f1_score(y_test2,y_p),2)
    d["Prec"] = np.round(precision_score(y_test2,y_p),2)
    d["Rec"] = np.round(recall_score(y_test2,y_p),2)
    d["Acc"] = np.round(accuracy_score(y_test2,y_p),2)
    d["RocAuc"] = np.round(roc_auc_score(y_test2,y_p),2)
    testing_list.append(d)
# Out:
# Threshold: 0.1
# Threshold: 0.2
# Threshold: 0.30000000000000004
# Threshold: 0.4
# Threshold: 0.5
# Threshold: 0.6
# Threshold: 0.7000000000000001
# Threshold: 0.8
# Threshold: 0.9

# %% [markdown]
# # Metricas para cada umbral.
# - th: umbral
# -------------------------------------------------------------------------------------------------------------------------------

# %%
testing_metrics_pd = pd.DataFrame(testing_list)
testing_metrics_pd
# Out:
#     th    F1  Prec   Rec   Acc  RocAuc
# 0  0.1  0.68  0.53  0.96  0.69    0.76
# 1  0.2  0.74  0.62  0.92  0.78    0.81
# 2  0.3  0.76  0.69  0.86  0.82    0.83
# 3  0.4  0.77  0.75  0.80  0.84    0.83
# 4  0.5  0.76  0.80  0.73  0.84    0.82
# 5  0.6  0.73  0.84  0.65  0.84    0.79
# 6  0.7  0.69  0.88  0.56  0.82    0.76
# 7  0.8  0.60  0.92  0.44  0.80    0.71
# 8  0.9  0.43  0.96  0.27  0.75    0.63

# %%
print(testing_metrics_pd.to_latex(index=False))
# Out:
# \begin{tabular}{rrrrrr}
# \toprule
#  th &   F1 &  Prec &  Rec &  Acc &  RocAuc \\
# \midrule
# 0.1 & 0.68 &  0.53 & 0.96 & 0.69 &    0.76 \\
# 0.2 & 0.74 &  0.62 & 0.92 & 0.78 &    0.81 \\
# 0.3 & 0.76 &  0.69 & 0.86 & 0.82 &    0.83 \\
# 0.4 & 0.77 &  0.75 & 0.80 & 0.84 &    0.83 \\
# 0.5 & 0.76 &  0.80 & 0.73 & 0.84 &    0.82 \\
# 0.6 & 0.73 &  0.84 & 0.65 & 0.84 &    0.79 \\
# 0.7 & 0.69 &  0.88 & 0.56 & 0.82 &    0.76 \\
# 0.8 & 0.60 &  0.92 & 0.44 & 0.80 &    0.71 \\
# 0.9 & 0.43 &  0.96 & 0.27 & 0.75 &    0.63 \\
# \bottomrule
# \end{tabular}

# %%
fpr, tpr, ths = roc_curve(y_test2,  Prediccion)
auc_ = auc(fpr, tpr)
plt.plot(fpr,tpr, label='ROC curve (area = %.2f)' %auc_)
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.legend()
plt.grid()
plt.show()

# %%
for i in  np.linspace(0.1,0.9,9):
    print(i)
    y_p = Prediccion >= i
    print(classification_report(y_test2, y_p))
    f1 = f1_score(y_test2, y_p)
    prec = precision_score(y_test2, y_p)
    rec = recall_score(y_test2, y_p)
    acc = accuracy_score(y_test2, y_p)
    cm=confusion_matrix(y_test2, y_p)
    print("Matriz de confusión: ")
    print(cm)
    print("----------------------------------------------------------")
    print("F1: %.2f" %f1 , " -- prec: %.2f" %prec, " -- recall: %.2f" %rec, " -- acc: %.2f" %acc)
    print("----------------------------------------------------------")
# Out:
# 0.1
#               precision    recall  f1-score   support
#
#            0       0.97      0.55      0.70    161781
#            1       0.53      0.96      0.68     83691
#
#     accuracy                           0.69    245472
#    macro avg       0.75      0.76      0.69    245472
# weighted avg       0.82      0.69      0.70    245472
#
# Matriz de confusión:
# [[89537 72244]
#  [ 3080 80611]]
# ----------------------------------------------------------
# F1: 0.68  -- prec: 0.53  -- recall: 0.96  -- acc: 0.69
# ----------------------------------------------------------
# 0.2
#               precision    recall  f1-score   support
#
#            0       0.94      0.71      0.81    161781
#            1       0.62      0.92      0.74     83691
#
#     accuracy                           0.78    245472
#    macro avg       0.78      0.81      0.77    245472
# weighted avg       0.83      0.78      0.78    245472
#
# Matriz de confusión:
# [[114471  47310]
#  [  7065  76626]]
# ----------------------------------------------------------
# F1: 0.74  -- prec: 0.62  -- recall: 0.92  -- acc: 0.78
# ----------------------------------------------------------
# 0.30000000000000004
#               precision    recall  f1-score   support
#
#            0       0.92      0.80      0.85    161781
#            1       0.69      0.86      0.76     83691
#
#     accuracy                           0.82    245472
#    macro avg       0.80      0.83      0.81    245472
# weighted avg       0.84      0.82      0.82    245472
#
# Matriz de confusión:
# [[129145  32636]
#  [ 11741  71950]]
# ----------------------------------------------------------
# F1: 0.76  -- prec: 0.69  -- recall: 0.86  -- acc: 0.82
# ----------------------------------------------------------
# 0.4
#               precision    recall  f1-score   support
#
#            0       0.89      0.86      0.88    161781
#            1       0.75      0.80      0.77     83691
#
#     accuracy                           0.84    245472
#    macro avg       0.82      0.83      0.82    245472
# weighted avg       0.84      0.84      0.84    245472
#
# Matriz de confusión:
# [[139051  22730]
#  [ 16887  66804]]
# ----------------------------------------------------------
# F1: 0.77  -- prec: 0.75  -- recall: 0.80  -- acc: 0.84
# ----------------------------------------------------------
# 0.5
#               precision    recall  f1-score   support
#
#            0       0.87      0.90      0.88    161781
#            1       0.80      0.73      0.76     83691
#
#     accuracy                           0.84    245472
#    macro avg       0.83      0.82      0.82    245472
# weighted avg       0.84      0.84      0.84    245472
#
# Matriz de confusión:
# [[146168  15613]
#  [ 22680  61011]]
# ----------------------------------------------------------
# F1: 0.76  -- prec: 0.80  -- recall: 0.73  -- acc: 0.84
# ----------------------------------------------------------
# 0.6
#               precision    recall  f1-score   support
#
#            0       0.84      0.94      0.88    161781
#            1       0.84      0.65      0.73     83691
#
#     accuracy                           0.84    245472
#    macro avg       0.84      0.79      0.81    245472
# weighted avg       0.84      0.84      0.83    245472
#
# Matriz de confusión:
# [[151362  10419]
#  [ 29086  54605]]
# ----------------------------------------------------------
# F1: 0.73  -- prec: 0.84  -- recall: 0.65  -- acc: 0.84
# ----------------------------------------------------------
# 0.7000000000000001
#               precision    recall  f1-score   support
#
#            0       0.81      0.96      0.88    161781
#            1       0.88      0.56      0.69     83691
#
#     accuracy                           0.82    245472
#    macro avg       0.84      0.76      0.78    245472
# weighted avg       0.83      0.82      0.81    245472
#
# Matriz de confusión:
# [[155433   6348]
#  [ 36722  46969]]
# ----------------------------------------------------------
# F1: 0.69  -- prec: 0.88  -- recall: 0.56  -- acc: 0.82
# ----------------------------------------------------------
# 0.8
#               precision    recall  f1-score   support
#
#            0       0.77      0.98      0.86    161781
#            1       0.92      0.44      0.60     83691
#
#     accuracy                           0.80    245472
#    macro avg       0.85      0.71      0.73    245472
# weighted avg       0.82      0.80      0.77    245472
#
# Matriz de confusión:
# [[158591   3190]
#  [ 46767  36924]]
# ----------------------------------------------------------
# F1: 0.60  -- prec: 0.92  -- recall: 0.44  -- acc: 0.80
# ----------------------------------------------------------
# 0.9
#               precision    recall  f1-score   support
#
#            0       0.73      0.99      0.84    161781
#            1       0.96      0.27      0.43     83691
#
#     accuracy                           0.75    245472
#    macro avg       0.84      0.63      0.63    245472
# weighted avg       0.81      0.75      0.70    245472
#
# Matriz de confusión:
# [[160794    987]
#  [ 60811  22880]]
# ----------------------------------------------------------
# F1: 0.43  -- prec: 0.96  -- recall: 0.27  -- acc: 0.75
# ----------------------------------------------------------

# %%
umbral = 0.4

# %%
maskSignal=Prediccion>umbral

# %%
predicBin=[]
for i in maskSignal:
    if(i==True):
        predicBin.append(1)
    else:
        predicBin.append(0)

# %%
npPredict=np.array(predicBin)

# %%
cm=confusion_matrix(y_test2, npPredict)
cm
# Out:
# array([[139051,  22730],
#        [ 16887,  66804]], dtype=int64)

# %%
cm_display = ConfusionMatrixDisplay(cm).plot()

# %%
f1= f1_score(y_test2, npPredict)
f1
# Out:
# 0.7712974455188338

# %%
prec=precision_score(y_test2, npPredict)
prec
# Out:
# 0.7461299618022204

# %%
rec=recall_score(y_test2, npPredict)
rec
# Out:
# 0.7982220310427645

# %%
accu=accuracy_score(y_test2, npPredict)
accu
# Out:
# 0.8386088841089819

# %%
print(classification_report(y_test2, npPredict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.86      0.88    161781
#            1       0.75      0.80      0.77     83691
#
#     accuracy                           0.84    245472
#    macro avg       0.82      0.83      0.82    245472
# weighted avg       0.84      0.84      0.84    245472

# %%
print("F1: %.2f" %f1 , " -- prec: %.2f" %prec, " -- recall: %.2f" %rec, " -- acc: %.2f" %acc)
# Out:
# F1: 0.77  -- prec: 0.75  -- recall: 0.80  -- acc: 0.75
