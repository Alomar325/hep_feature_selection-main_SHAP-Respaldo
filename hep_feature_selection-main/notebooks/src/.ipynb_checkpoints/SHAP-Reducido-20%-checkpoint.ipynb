# %% [markdown]
# # SHAP
#
# ### Clasificación de eventos usando SHAP como seleccionador de características con los set de datos reducidos a 100000 eventos.

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------
#
# Alex Toro, Raquel Pezoa

# %% [markdown]
# ## Librerias necesarias-
# -------------------------------------------------------------------------------------------------------------------------------

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from xgboost import XGBClassifier
import shap
from sklearn.model_selection import train_test_split

# %%
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV

# %%
import xgboost as xgb

# %%
import winsound

# %%
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %% [markdown]
# ## Lectura del set de datos reducido.
#
# - El set original proviene de https://www.kaggle.com/competitions/higgs-boson/data.
# - Separación de la variable Label de las demas variables.
# -------------------------------------------------------------------------------------------------------------------------------

# %%
df = pd.read_csv("/Users/Alex/Downloads/Pre-procesado.csv")

# %%
X = df.drop(labels=['Label'], axis=1)
Y = df['Label']
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=0)

# %%
X_train.shape
# Out:
# (80000, 30)

# %%
params={
 "learning_rate"    : [0.05, 0.10, 0.15, 0.20, 0.25, 0.30 ] ,
 "max_depth"        : [ 3, 4, 5, 6, 8, 10, 12, 15],
 "min_child_weight" : [ 1, 3, 5, 7 ],
 "gamma"            : [ 0.0, 0.1, 0.2 , 0.3, 0.4 ],
 "colsample_bytree" : [ 0.3, 0.4, 0.5 , 0.7 ]
    
}

# %%
classifier=XGBClassifier()

# %%
random_search=RandomizedSearchCV(classifier,param_distributions=params,n_iter=5,scoring='roc_auc',n_jobs=-1,cv=5,verbose=3)

# %%
random_search.fit(X_train,y_train) # el de 5 iteraciones
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# RandomizedSearchCV(cv=5,
#                    estimator=XGBClassifier(base_score=None, booster=None,
#                                            callbacks=None,
#                                            colsample_bylevel=None,
#                                            colsample_bynode=None,
#                                            colsample_bytree=None,
#                                            early_stopping_rounds=None,
#                                            enable_categorical=False,
#                                            eval_metric=None, gamma=None,
#                                            gpu_id=None, grow_policy=None,
#                                            importance_type=None,
#                                            interaction_constraints=None,
#                                            learning_rate=None, max_bin=None,...
#                                            n_estimators=100, n_jobs=None,
#                                            num_parallel_tree=None,
#                                            predictor=None, random_state=None,
#                                            reg_alpha=None, reg_lambda=None, ...),
#                    n_iter=5, n_jobs=-1,
#                    param_distributions={'colsample_bytree': [0.3, 0.4, 0.5,
#                                                              0.7],
#                                         'gamma': [0.0, 0.1, 0.2, 0.3, 0.4],
#                                         'learning_rate': [0.05, 0.1, 0.15, 0.2,
#                                                           0.25, 0.3],
#                                         'max_depth': [3, 4, 5, 6, 8, 10, 12,
#                                                       15],
#                                         'min_child_weight': [1, 3, 5, 7]},
#                    scoring='roc_auc', verbose=3)

# %%
frequency = 2500  # Set Frequency To 2500 Hertz
duration = 1000  # Set Duration To 1000 ms == 1 second
winsound.Beep(frequency, duration)

# %%
print(random_search.best_estimator_) # 5 iteraciones
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=0.3,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0.1, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.2, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=15, max_leaves=0, min_child_weight=5,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, predictor='auto', random_state=0,
#               reg_alpha=0, reg_lambda=1, ...)

# %%
random_search.best_params_ # 5 iteraciones
# Out:
# {'min_child_weight': 5,
#  'max_depth': 15,
#  'learning_rate': 0.2,
#  'gamma': 0.1,
#  'colsample_bytree': 0.3}

# %% [markdown]
# ### Entrenamiento y testeo del set de datos con XGBoost.
#
# - Se entrena con XGBClassifier antes de usar SHAP, ya que SHAP necesita con aterioridad un modelo entrenado.
# -------------------------------------------------------------------------------------------------------------------------------

# %%
model = XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=0.3,
              early_stopping_rounds=None, enable_categorical=False,
              eval_metric=None, gamma=0.1, gpu_id=-1, grow_policy='depthwise',
              importance_type=None, interaction_constraints='',
              learning_rate=0.2, max_bin=256, max_cat_to_onehot=4,
              max_delta_step=0, max_depth=15, max_leaves=0, min_child_weight=5,
              missing=None, monotone_constraints='()', n_estimators=100,
              n_jobs=0, num_parallel_tree=1, predictor='auto', random_state=0,
              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None, silent=True,
       subsample=1)
model.get_params()
# nuevos hiperparametros
# Out:
# {'objective': 'binary:logistic',
#  'use_label_encoder': False,
#  'base_score': 0.5,
#  'booster': 'gbtree',
#  'callbacks': None,
#  'colsample_bylevel': 1,
#  'colsample_bynode': 1,
#  'colsample_bytree': 0.3,
#  'early_stopping_rounds': None,
#  'enable_categorical': False,
#  'eval_metric': None,
#  'gamma': 0.1,
#  'gpu_id': -1,
#  'grow_policy': 'depthwise',
#  'importance_type': None,
#  'interaction_constraints': '',
#  'learning_rate': 0.2,
#  'max_bin': 256,
#  'max_cat_to_onehot': 4,
#  'max_delta_step': 0,
#  'max_depth': 15,
#  'max_leaves': 0,
#  'min_child_weight': 5,
#  'missing': None,
#  'monotone_constraints': '()',
#  'n_estimators': 100,
#  'n_jobs': 0,
#  'num_parallel_tree': 1,
#  'predictor': 'auto',
#  'random_state': 0,
#  'reg_alpha': 0,
#  'reg_lambda': 1,
#  'sampling_method': None,
#  'scale_pos_weight': 1,
#  'subsample': 1,
#  'tree_method': None,
#  'validate_parameters': None,
#  'verbosity': None,
#  'seed': None,
#  'silent': True}

# %%
model.fit(X_train, y_train)
# Out:
# [16:50:01] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=0.3,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0.1, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.2, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=15, max_leaves=0, min_child_weight=5,
#               missing=None, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, predictor='auto', random_state=0,
#               reg_alpha=0, reg_lambda=1, ...)

# %%
model.save_model("SHAP-XGBoostClassifier.model")

# %% [markdown]
# ### SHAP seleccionado características.

# %%
# Fits the explainer
explainer = shap.TreeExplainer(model = model)
# Calculates the SHAP values - It takes some time

# %%
# Evaluate SHAP values
shap_values = explainer.shap_values(X_test)
# Out:
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %% [markdown]
# ### Waterfall plot
#
# - Esta gráfica muestra cómo las características contribuyen a impulsar la predicción del clasificador desde el valor base (la predicción promedio del modelo sobre el conjunto de datos de entrenamiento) hasta la salida del modelo, de una muestra de datos específica.
# - Las características que empujan la predicción más alta se muestran en rojo, las que empujan la predicción más baja están en azul.
# -------------------------------------------------------------------------------------------------------------------------------

# %%
i=4
shap.plots._waterfall.waterfall_legacy(explainer.expected_value, 
                                       shap_values[i],
                                       feature_names = X_train.columns, 
                                       show = True,
                                      max_display=10)
# el numero es lo que contribuye en el dato en la posicion 4 (un evento)

# %% [markdown]
# ### Summary Plots
# - Ranking de las mejore 20 características
# -------------------------------------------------------------------------------------------------------------------------------

# %%
shap.summary_plot(shap_values, X_test, plot_type="bar")

# %%
X_test
# Out:
#        DER_mass_MMC  DER_mass_transverse_met_lep  DER_mass_vis  DER_pt_h  \
# 3582       -999.000                       51.525        64.653    58.637
# 60498       153.541                       13.850        83.206    81.976
# 53227       138.446                        1.833        62.411   140.682
# 21333       137.621                       88.006        73.570     1.436
# 3885        137.341                       16.591       103.245   346.650
# ...             ...                          ...           ...       ...
# 60116      -999.000                       74.312        49.597    34.237
# 2415        129.729                       59.415        36.534   239.330
# 43763       124.421                       61.185        61.912   114.465
# 71345        74.761                       15.304        39.035   122.816
# 77687       102.673                      112.785        69.019   131.959
#
#        DER_deltaeta_jet_jet  DER_mass_jet_jet  DER_prodeta_jet_jet  \
# 3582               -999.000          -999.000             -999.000
# 60498                 4.211           719.978               -3.739
# 53227                 0.560           170.804                0.552
# 21333              -999.000          -999.000             -999.000
# 3885                  1.493           189.269                0.535
# ...                     ...               ...                  ...
# 60116              -999.000          -999.000             -999.000
# 2415                  2.328           223.783               -1.351
# 43763                 1.478           132.847                0.345
# 71345              -999.000          -999.000             -999.000
# 77687                 4.796          1406.461               -5.524
#
#        DER_deltar_tau_lep  DER_pt_tot  DER_sum_pt  ...  PRI_met_phi  \
# 3582                1.797      58.637      89.719  ...        2.340
# 60498               2.632      29.361     249.653  ...        2.108
# 53227               2.290      43.660     348.000  ...        2.223
# 21333               3.040       1.436      81.058  ...       -2.323
# 3885                1.212     177.422     625.424  ...        2.090
# ...                   ...         ...         ...  ...          ...
# 60116               1.593       2.563     100.839  ...        3.103
# 2415                1.135      53.748     298.555  ...        0.471
# 43763               1.927      23.801     218.586  ...       -1.936
# 71345               1.180      28.062     172.760  ...        2.430
# 77687               1.580       1.151     352.638  ...        2.047
#
#        PRI_met_sumet  PRI_jet_num  PRI_jet_leading_pt  PRI_jet_leading_eta  \
# 3582         221.042            0            -999.000             -999.000
# 60498        370.166            2             102.704               -1.272
# 53227        424.059            3             172.656               -0.514
# 21333        102.216            0            -999.000             -999.000
# 3885         736.536            3             112.596                1.791
# ...              ...          ...                 ...                  ...
# 60116        147.340            1              31.825               -0.521
# 2415         308.579            3             156.969                1.231
# 43763        270.194            2              70.661               -0.205
# 71345        201.181            1             102.368               -2.306
# 77687        369.024            2             135.787                2.874
#
#        PRI_jet_leading_phi  PRI_jet_subleading_pt  PRI_jet_subleading_eta  \
# 3582              -999.000               -999.000                -999.000
# 60498               -1.920                 72.803                   2.939
# 53227               -0.716                 69.112                  -1.074
# 21333             -999.000               -999.000                -999.000
# 3885                -1.492                109.589                   0.298
# ...                    ...                    ...                     ...
# 60116               -0.624               -999.000                -999.000
# 2415                -2.784                 37.134                  -1.097
# 43763                1.182                 60.564                  -1.683
# 71345               -1.037               -999.000                -999.000
# 77687               -2.537                119.349                  -1.922
#
#        PRI_jet_subleading_phi  PRI_jet_all_pt
# 3582                 -999.000           0.000
# 60498                   0.699         175.507
# 53227                  -2.313         282.655
# 21333                -999.000           0.000
# 3885                   -1.855         357.919
# ...                       ...             ...
# 60116                -999.000          31.825
# 2415                   -2.377         227.006
# 43763                  -0.056         131.225
# 71345                -999.000         102.368
# 77687                  -0.486         255.136
#
# [20000 rows x 30 columns]

# %%
shap_values
# Out:
# array([[-8.0016756e-01,  3.6272649e-03, -5.8537640e-05, ...,
#          2.0019617e-02,  1.8028660e-02, -4.9981318e-02],
#        [ 1.0094316e+00,  3.5742235e-01,  3.7790209e-01, ...,
#          7.7972688e-02,  4.7023829e-02,  1.5257981e-01],
#        [ 1.4875022e+00,  4.6042955e-01,  2.7193127e-02, ...,
#          3.9251661e-03,  2.7871896e-02,  1.8339518e-01],
#        ...,
#        [ 9.2198735e-01, -3.2092986e-01, -7.0628583e-02, ...,
#         -4.5441907e-02,  3.3100937e-02,  2.7057236e-01],
#        [-1.7879181e+00,  1.7528585e-01, -7.5028974e-01, ...,
#          1.5211729e-03, -3.5245273e-02,  6.5278053e-02],
#        [-1.3051468e-01, -7.5098294e-01, -2.2990271e-02, ...,
#         -5.1338132e-03,  2.3545972e-03,  9.9505857e-02]], dtype=float32)

# %% [markdown]
# ### Obteniendo la media de los valores absolutos de SHAP (|SHAP value|).
# -------------------------------------------------------------------------------------------------------------------------------

# %%
meanL = []
for valus in range(0,len(shap_values)):
    for singularidad in range(0,len(shap_values[valus])):
        if valus==0:
            meanL.append(abs(shap_values[valus][singularidad]))
        else:
            meanL[singularidad]=meanL[singularidad]+abs(shap_values[valus][singularidad])

# %% [markdown]
# ### Convertir los datos a  una lista de duplas.
#
# - Se convierte la media de los valores absolutos de SHAP junto a las columnas del dataframe en una lista de duplas.
# - Se realizan las duplas para así poder reordenar las variables de la más relevante a la menos relevante.
# - Se Reordena la duplas de mayor a menor.
# - Se separan las duplas en listas separadas y transformar las 20 primeras en arreglos de numpy.
# -------------------------------------------------------------------------------------------------------------------------------

# %%
meanL=list(map(lambda x: x / len(shap_values), meanL))
l=[]
for feature in zip(meanL,X_train.columns):
    l.append(feature)
    print(feature)
# Out:
# (0.7856869140625, 'DER_mass_MMC')
# (0.418486669921875, 'DER_mass_transverse_met_lep')
# (0.4071599609375, 'DER_mass_vis')
# (0.14145767822265626, 'DER_pt_h')
# (0.06396580200195312, 'DER_deltaeta_jet_jet')
# (0.08244983520507812, 'DER_mass_jet_jet')
# (0.066743310546875, 'DER_prodeta_jet_jet')
# (0.2352564208984375, 'DER_deltar_tau_lep')
# (0.1077657470703125, 'DER_pt_tot')
# (0.1238309326171875, 'DER_sum_pt')
# (0.1813708740234375, 'DER_pt_ratio_lep_tau')
# (0.217916796875, 'DER_met_phi_centrality')
# (0.18709271240234376, 'DER_lep_eta_centrality')
# (0.35090068359375, 'PRI_tau_pt')
# (0.1089707763671875, 'PRI_tau_eta')
# (0.07331231079101562, 'PRI_tau_phi')
# (0.08499188232421875, 'PRI_lep_pt')
# (0.15213663330078125, 'PRI_lep_eta')
# (0.06937512817382813, 'PRI_lep_phi')
# (0.19979140625, 'PRI_met')
# (0.06721130981445313, 'PRI_met_phi')
# (0.09953596801757812, 'PRI_met_sumet')
# (0.03373025817871094, 'PRI_jet_num')
# (0.1197289794921875, 'PRI_jet_leading_pt')
# (0.2143789794921875, 'PRI_jet_leading_eta')
# (0.04233533630371094, 'PRI_jet_leading_phi')
# (0.03633001708984375, 'PRI_jet_subleading_pt')
# (0.04345494995117188, 'PRI_jet_subleading_eta')
# (0.01957129821777344, 'PRI_jet_subleading_phi')
# (0.12023797607421875, 'PRI_jet_all_pt')

# %%
l.sort(reverse=True)
l
# Out:
# [(0.7856869140625, 'DER_mass_MMC'),
#  (0.418486669921875, 'DER_mass_transverse_met_lep'),
#  (0.4071599609375, 'DER_mass_vis'),
#  (0.35090068359375, 'PRI_tau_pt'),
#  (0.2352564208984375, 'DER_deltar_tau_lep'),
#  (0.217916796875, 'DER_met_phi_centrality'),
#  (0.2143789794921875, 'PRI_jet_leading_eta'),
#  (0.19979140625, 'PRI_met'),
#  (0.18709271240234376, 'DER_lep_eta_centrality'),
#  (0.1813708740234375, 'DER_pt_ratio_lep_tau'),
#  (0.15213663330078125, 'PRI_lep_eta'),
#  (0.14145767822265626, 'DER_pt_h'),
#  (0.1238309326171875, 'DER_sum_pt'),
#  (0.12023797607421875, 'PRI_jet_all_pt'),
#  (0.1197289794921875, 'PRI_jet_leading_pt'),
#  (0.1089707763671875, 'PRI_tau_eta'),
#  (0.1077657470703125, 'DER_pt_tot'),
#  (0.09953596801757812, 'PRI_met_sumet'),
#  (0.08499188232421875, 'PRI_lep_pt'),
#  (0.08244983520507812, 'DER_mass_jet_jet'),
#  (0.07331231079101562, 'PRI_tau_phi'),
#  (0.06937512817382813, 'PRI_lep_phi'),
#  (0.06721130981445313, 'PRI_met_phi'),
#  (0.066743310546875, 'DER_prodeta_jet_jet'),
#  (0.06396580200195312, 'DER_deltaeta_jet_jet'),
#  (0.04345494995117188, 'PRI_jet_subleading_eta'),
#  (0.04233533630371094, 'PRI_jet_leading_phi'),
#  (0.03633001708984375, 'PRI_jet_subleading_pt'),
#  (0.03373025817871094, 'PRI_jet_num'),
#  (0.01957129821777344, 'PRI_jet_subleading_phi')]

# %%
l_v = []
for importance in range(len(l)):
    for var in range(len(l[importance])):
        if(var == 1):
            l_v.append(l[importance][var])

# %%
x = np.array(l_v[0:20])
x
# Out:
# array(['DER_mass_MMC', 'DER_mass_transverse_met_lep', 'DER_mass_vis',
#        'PRI_tau_pt', 'DER_deltar_tau_lep', 'DER_met_phi_centrality',
#        'PRI_jet_leading_eta', 'PRI_met', 'DER_lep_eta_centrality',
#        'DER_pt_ratio_lep_tau', 'PRI_lep_eta', 'DER_pt_h', 'DER_sum_pt',
#        'PRI_jet_all_pt', 'PRI_jet_leading_pt', 'PRI_tau_eta',
#        'DER_pt_tot', 'PRI_met_sumet', 'PRI_lep_pt', 'DER_mass_jet_jet'],
#       dtype='<U27')

# %%
# Force_plot
shap.initjs()
shap.force_plot(explainer.expected_value, shap_values[102,:], X_test.iloc[102,:], link="logit")
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...
# <div id='iUJQPGTYLUEZI485MXRYK'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": -0.8288472890853882, "outValue": 2.0483832359313965, "link": "logit", "featureNames": ["DER_mass_MMC", "DER_mass_transverse_met_lep", "DER_mass_vis", "DER_pt_h", "DER_deltaeta_jet_jet", "DER_mass_jet_jet", "DER_prodeta_jet_jet", "DER_deltar_tau_lep", "DER_pt_tot", "DER_sum_pt", "DER_pt_ratio_lep_tau", "DER_met_phi_centrality", "DER_lep_eta_centrality", "PRI_tau_pt", "PRI_tau_eta", "PRI_tau_phi", "P
#        PRI_met  DER_lep_eta_centrality  DER_pt_ratio_lep_tau  PRI_lep_eta  \
# 0       73.597                -999.000                 1.324        0.354
# 1       38.748                   0.545                 1.056        1.079
# 2       65.606                -999.000                 0.567       -1.316
# 3       33.185                -999.000                 0.947       -1.125
# 4       62.011                -999.000                 0.794        2.123
# ...        ...                     ...                   ...          ...
# 99995   56.776                -999.000                 0.612        0.750
# 99996   23.523                   0.541                 1.390       -0.037
# 99997   51.494                -999.000                 1.824       -0.680
# 99998   68.280                   0.826                 0.477        0.868
# 99999  110.739                -999.000                 0.248       -1.167
#
#        DER_pt_h  DER_sum_pt  PRI_jet_all_pt  PRI_jet_leading_pt  PRI_tau_eta  \
# 0       139.856     212.788         145.787             145.787       -0.900
# 1       107.916     209.956         137.049              58.119        2.286
# 2         0.998      92.329           0.000            -999.000       -0.405
# 3        24.962      57.390           0.000            -999.000       -0.422
# 4         2.044      62.347           0.000            -999.000       -0.547
# ...         ...         ...             ...                 ...          ...
# 99995   165.282     271.045         154.838             154.838       -0.216
# 99996    56.085     176.428         117.155              62.533        1.520
# 99997    99.933     156.158          97.379              97.379        0.344
# 99998   187.917     393.666         270.979             126.766       -0.050
# 99999    30.074     162.494           0.000            -999.000       -0.160
#
#        DER_pt_tot  PRI_met_sumet  PRI_lep_pt  DER_mass_jet_jet
# 0           6.593        327.124      38.174          -999.000
# 1          49.749        326.261      37.440           442.881
# 2           0.998        102.229      33.416          -999.000
# 3          24.962         84.495      27.921          -999.000
# 4           2.044        110.727      27.586          -999.000
# ...           ...            ...         ...               ...
# 99995      24.675        338.910      44.118          -999.000
# 99996       4.378        221.148      34.470           246.437
# 99997       2.970        162.416      37.967          -999.000
# 99998      71.559        428.033      39.626           169.441
# 99999      30.074        172.318      32.316          -999.000
#
# [100000 rows x 20 columns]

# %% [markdown]
# ### Entrenamiento, testeo y optimizacion de parametros de DMatrix de XGBoost con las variables entregadas por SHAP.
# -------------------------------------------------------------------------------------------------------------------------------

# %%
X_train2, X_test2, y_train2, y_test2 = train_test_split(X_BestFeature, Y, test_size=0.2, random_state=0)

# %%
dtrain = xgb.DMatrix(X_train2, label=y_train2)
dtest = xgb.DMatrix(X_test2, label=y_test2)

# %%
params = {
    # Parameters that we are going to tune.
    'max_depth':6,
    'min_child_weight': 1,
    'eta':.3,
    'subsample': 1,
    'colsample_bytree': 1,
    # Other parameters
    'objective':'reg:linear',
}
params['eval_metric'] = "mae"
params['base_score'] = np.mean(y_train)
num_boost_round = 999

# %%
modelo = xgb.train( 
    params, 
    dtrain, 
    num_boost_round=num_boost_round, 
    evals=[(dtest, "Test")], 
    early_stopping_rounds=10 
)
# Out:
# [12:21:59] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	Test-mae:0.39342
# [1]	Test-mae:0.35354
# [2]	Test-mae:0.32410
# [3]	Test-mae:0.30227
# [4]	Test-mae:0.28649
# [5]	Test-mae:0.27433
# [6]	Test-mae:0.26489
# [7]	Test-mae:0.25747
# [8]	Test-mae:0.25284
# [9]	Test-mae:0.24985
# [10]	Test-mae:0.24630
# [11]	Test-mae:0.24490
# [12]	Test-mae:0.24360
# [13]	Test-mae:0.24207
# [14]	Test-mae:0.24128
# [15]	Test-mae:0.24100
# [16]	Test-mae:0.24038
# [17]	Test-mae:0.23957
# [18]	Test-mae:0.23921
# [19]	Test-mae:0.23869
# [20]	Test-mae:0.23853
# [21]	Test-mae:0.23847
# [22]	Test-mae:0.23840
# [23]	Test-mae:0.23843
# [24]	Test-mae:0.23850
# [25]	Test-mae:0.23796
# [26]	Test-mae:0.23776
# [27]	Test-mae:0.23772
# [28]	Test-mae:0.23751
# [29]	Test-mae:0.23751
# [30]	Test-mae:0.23748
# [31]	Test-mae:0.23753
# [32]	Test-mae:0.23758
# [33]	Test-mae:0.23757
# [34]	Test-mae:0.23743
# [35]	Test-mae:0.23749
# [36]	Test-mae:0.23738
# [37]	Test-mae:0.23745
# [38]	Test-mae:0.23747
# [39]	Test-mae:0.23726
# [40]	Test-mae:0.23735
# [41]	Test-mae:0.23735
# [42]	Test-mae:0.23738
# [43]	Test-mae:0.23740
# [44]	Test-mae:0.23741
# [45]	Test-mae:0.23737
# [46]	Test-mae:0.23734
# [47]	Test-mae:0.23736
# [48]	Test-mae:0.23738
# [49]	Test-mae:0.23730

# %%
print("Best MAE: {:.2f} with {} rounds".format(
                 modelo.best_score,
                 modelo.best_iteration+1))
# Out:
# Best MAE: 0.24 with 40 rounds

# %%
cv_results = xgb.cv( 
    params, 
    dtrain, 
    num_boost_round=num_boost_round, 
    seed=42, 
    nfold=5, 
    metrics={'mae'}, 
    early_stopping_rounds=10 
)
cv_results
# Out:
# [12:22:02] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [12:22:02] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [12:22:02] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [12:22:02] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [12:22:02] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
#     train-mae-mean  train-mae-std  test-mae-mean  test-mae-std
# 0         0.392515       0.000248       0.393610      0.000697
# 1         0.351450       0.000568       0.353665      0.000533
# 2         0.321071       0.000636       0.324298      0.000855
# 3         0.298175       0.000545       0.302424      0.001221
# 4         0.281058       0.000590       0.286035      0.001423
# 5         0.268417       0.000422       0.274146      0.001842
# 6         0.258316       0.000628       0.264879      0.001785
# 7         0.250943       0.000750       0.258151      0.001781
# 8         0.245277       0.001108       0.253241      0.001405
# 9         0.240617       0.001141       0.249181      0.001305
# 10        0.237593       0.001242       0.246726      0.001282
# 11        0.235055       0.001049       0.244803      0.001295
# 12        0.232762       0.001046       0.243155      0.001378
# 13        0.231276       0.001233       0.242139      0.001108
# 14        0.229597       0.000951       0.240953      0.001351
# 15        0.228433       0.001144       0.240219      0.001147
# 16        0.227597       0.001173       0.239846      0.001175
# 17        0.226504       0.001061       0.239282      0.001235
# 18        0.225746       0.001017       0.239026      0.001413
# 19        0.225064       0.000845       0.238748      0.001562
# 20        0.224428       0.001100       0.238484      0.001374
# 21        0.223712       0.001207       0.238270      0.001283
# 22        0.223348       0.001135       0.238193      0.001286
# 23        0.222823       0.001172       0.238020      0.001329
# 24        0.222250       0.001151       0.237807      0.001435
# 25        0.221923       0.001211       0.237781      0.001434
# 26        0.221473       0.000914       0.237630      0.001597
# 27        0.221133       0.000805       0.237659      0.001654
# 28        0.220698       0.000665       0.237648      0.001698
# 29        0.220325       0.000753       0.237590      0.001610
# 30        0.219829       0.000815       0.237545      0.001557
# 31        0.219435       0.000831       0.237466      0.001547
# 32        0.219094       0.000901       0.237436      0.001574
# 33        0.218542       0.000947       0.237321      0.001574
# 34        0.218175       0.001036       0.237279      0.001596
# 35        0.217892       0.001092       0.237273      0.001577
# 36        0.217646       0.001024       0.237278      0.001595
# 37        0.217467       0.001008       0.237313      0.001597
# 38        0.217052       0.001053       0.237267      0.001761
# 39        0.216546       0.001139       0.237186      0.001770
# 40        0.216113       0.001086       0.237118      0.001690
# 41        0.215724       0.001155       0.237141      0.001634
# 42        0.215315       0.001126       0.237120      0.001693
# 43        0.214917       0.001248       0.237104      0.001646
# 44        0.214536       0.001032       0.237054      0.001714
# 45        0.214207       0.001011       0.237039      0.001637
# 46        0.213923       0.000976       0.236998      0.001644
# 47        0.213587       0.000911       0.236996      0.001639
# 48        0.213342       0.000846       0.237010      0.001659
# 49        0.212976       0.000871       0.237030      0.001634
# 50        0.212719       0.000954       0.237043      0.001658
# 51        0.212511       0.000883       0.237061      0.001654
# 52        0.212097       0.001012       0.237018      0.001546
# 53        0.211655       0.001065       0.236999      0.001556
# 54        0.211342       0.001244       0.237022      0.001494
# 55        0.210980       0.001217       0.236939      0.001525
# 56        0.210506       0.001263       0.236858      0.001478
# 57        0.210115       0.001271       0.236883      0.001404
# 58        0.209744       0.001158       0.236872      0.001396
# 59        0.209417       0.001054       0.236854      0.001434

# %%
cv_results['test-mae-mean'].min()
# Out:
# 0.23685350771274952

# %%
gridsearch_params = [
    (max_depth, min_child_weight)
    for max_depth in range(9,12)
    for min_child_weight in range(5,8)
]

# %%
min_mae = float("Inf")
best_params = None
for max_depth, min_child_weight in gridsearch_params:
    print("CV with max_depth={}, min_child_weight={}".format(
                             max_depth,
                             min_child_weight))
    # Update our parameters
    params['max_depth'] = max_depth
    params['min_child_weight'] = min_child_weight
    # Run CV
    cv_results = xgb.cv(
        params,
        dtrain,
        num_boost_round=num_boost_round,
        seed=42,
        nfold=5,
        metrics={'mae'},
        early_stopping_rounds=10
    )
    # Update best MAE
    mean_mae = cv_results['test-mae-mean'].min()
    boost_rounds = cv_results['test-mae-mean'].argmin()
    print("\tMAE {} for {} rounds".format(mean_mae, boost_rounds))
    if mean_mae < min_mae:
        min_mae = mean_mae
        best_params = (max_depth,min_child_weight)
print("Best params: {}, {}, MAE: {}".format(best_params[0], best_params[1], min_mae))
frequency = 2500  # Set Frequency To 2500 Hertz
duration = 1000  # Set Duration To 1000 ms == 1 second
winsound.Beep(frequency, duration)
# Out:
# CV with max_depth=9, min_child_weight=5
# [12:22:16] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [12:22:16] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [12:22:17] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [12:22:17] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [12:22:17] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.231939915636931 for 21 rounds
# CV with max_depth=9, min_child_weight=6
# [12:22:27] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [12:22:27] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [12:22:27] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [12:22:27] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [12:22:27] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.2324474814867484 for 17 rounds
# CV with max_depth=9, min_child_weight=7
# [12:22:37] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [12:22:37] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [12:22:37] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [12:22:37] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [12:22:37] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.23247130978977934 for 20 rounds
# CV with max_depth=10, min_child_weight=5
# [12:22:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [12:22:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [12:22:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [12:22:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [12:22:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.23102029344975503 for 20 rounds
# CV with max_depth=10, min_child_weight=6
# [12:22:59] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [12:22:59] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [12:22:59] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [12:23:00] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [12:23:00] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.2309321431394412 for 16 rounds
# CV with max_depth=10, min_child_weight=7
# [12:23:10] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [12:23:10] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [12:23:10] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [12:23:11] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [12:23:11] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.230831141903919 for 15 rounds
# CV with max_depth=11, min_child_weight=5
# [12:23:20] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [12:23:20] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [12:23:20] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [12:23:21] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [12:23:21] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.23038549941180442 for 15 rounds
# CV with max_depth=11, min_child_weight=6
# [12:23:31] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [12:23:32] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [12:23:32] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [12:23:32] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [12:23:32] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.2308769453918182 for 16 rounds
# CV with max_depth=11, min_child_weight=7
# [12:23:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [12:23:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [12:23:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [12:23:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [12:23:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.23123983972959375 for 15 rounds
# Best params: 11, 5, MAE: 0.23038549941180442

# %%
params['max_depth'] = 11
params['min_child_weight'] = 5

# %%
gridsearch_params = [
    (subsample, colsample)
    for subsample in [i/10. for i in range(7,11)]
    for colsample in [i/10. for i in range(7,11)]
]

# %%
min_mae = float("Inf")
best_params = None
# We start by the largest values and go down to the smallest
for subsample, colsample in reversed(gridsearch_params):
    print("CV with subsample={}, colsample={}".format(
                             subsample,
                             colsample))
    # We update our parameters
    params['subsample'] = subsample
    params['colsample_bytree'] = colsample
    # Run CV
    cv_results = xgb.cv(
        params,
        dtrain,
        num_boost_round=num_boost_round,
        seed=42,
        nfold=5,
        metrics={'mae'},
        early_stopping_rounds=10
    )
    # Update best score
    mean_mae = cv_results['test-mae-mean'].min()
    boost_rounds = cv_results['test-mae-mean'].argmin()
    print("\tMAE {} for {} rounds".format(mean_mae, boost_rounds))
    if mean_mae < min_mae:
        min_mae = mean_mae
        best_params = (subsample,colsample)
print("Best params: {}, {}, MAE: {}".format(best_params[0], best_params[1], min_mae))
frequency = 2500  # Set Frequency To 2500 Hertz
duration = 1000  # Set Duration To 1000 ms == 1 second
winsound.Beep(frequency, duration)
# Out:
# CV with subsample=1.0, colsample=1.0
# [11:52:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:52:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:52:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:52:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:52:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.23067715080663415 for 16 rounds
# CV with subsample=1.0, colsample=0.9
# [11:52:30] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:52:30] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:52:31] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:52:31] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:52:31] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.23247257023694212 for 14 rounds
# CV with subsample=1.0, colsample=0.8
# [11:52:41] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:52:41] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:52:41] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:52:41] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:52:41] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.2331723769890471 for 18 rounds
# CV with subsample=1.0, colsample=0.7
# [11:52:51] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:52:51] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:52:51] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:52:52] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:52:52] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.23433604654262147 for 18 rounds
# CV with subsample=0.9, colsample=1.0
# [11:53:01] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:53:01] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:53:01] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:53:02] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:53:02] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.23173918683119749 for 14 rounds
# CV with subsample=0.9, colsample=0.9
# [11:53:13] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:53:13] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:53:13] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:53:13] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:53:13] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.23356162607663594 for 15 rounds
# CV with subsample=0.9, colsample=0.8
# [11:53:23] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:53:23] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:53:23] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:53:24] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:53:24] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.23543990006792628 for 16 rounds
# CV with subsample=0.9, colsample=0.7
# [11:53:33] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:53:33] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:53:33] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:53:33] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:53:34] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.2363762943420528 for 15 rounds
# CV with subsample=0.8, colsample=1.0
# [11:53:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:53:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:53:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:53:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:53:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.23271989310043115 for 15 rounds
# CV with subsample=0.8, colsample=0.9
# [11:53:53] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:53:53] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:53:53] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:53:53] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:53:53] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.23404706470345849 for 15 rounds
# CV with subsample=0.8, colsample=0.8
# [11:54:03] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:54:03] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:54:03] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:54:03] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:54:03] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.23620870574153355 for 15 rounds
# CV with subsample=0.8, colsample=0.7
# [11:54:12] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:54:12] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:54:12] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:54:12] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:54:12] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.23848312864858534 for 17 rounds
# CV with subsample=0.7, colsample=1.0
# [11:54:21] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:54:21] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:54:21] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:54:21] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:54:22] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.2341393102981487 for 13 rounds
# CV with subsample=0.7, colsample=0.9
# [11:54:31] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:54:31] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:54:31] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:54:31] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:54:31] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.2360546013170476 for 13 rounds
# CV with subsample=0.7, colsample=0.8
# [11:54:40] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:54:40] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:54:40] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:54:40] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:54:41] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0
# [976]	Test-mae:0.21986
# [977]	Test-mae:0.21986
# [978]	Test-mae:0.21985
# [979]	Test-mae:0.21985
# [980]	Test-mae:0.21985
# [981]	Test-mae:0.21985
# [982]	Test-mae:0.21985
# [983]	Test-mae:0.21985
# [984]	Test-mae:0.21985
# [985]	Test-mae:0.21985
# [986]	Test-mae:0.21985
# [987]	Test-mae:0.21985
# [988]	Test-mae:0.21985
# [989]	Test-mae:0.21985
# [990]	Test-mae:0.21985
# [991]	Test-mae:0.21984
# [992]	Test-mae:0.21984
# [993]	Test-mae:0.21984
# [994]	Test-mae:0.21984
# [995]	Test-mae:0.21984
# [996]	Test-mae:0.21983
# [997]	Test-mae:0.21983
# [998]	Test-mae:0.21983

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(best_model.predict(dtest), y_test2)
# Out:
# 0.2198338498860375

# %% [markdown]
# ### Guardado del modelo y predicciones.
# -------------------------------------------------------------------------------------------------------------------------------

# %%
best_model.save_model("SHAP-20%.model")

# %%
loaded_model = xgb.Booster()
loaded_model.load_model("SHAP-20%.model")
# And use it for predictions.
# Out:
# [10:27:27] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.

# %%
Prediccion = loaded_model.predict(dtest)

# %%
Prediccion.min()
# Out:
# -0.1699762

# %%
Prediccion.max()
# Out:
# 1.1567774

# %%
from sklearn.metrics import confusion_matrix, f1_score, precision_score, recall_score, accuracy_score, classification_report, roc_curve, auc, roc_auc_score, ConfusionMatrixDisplay

# %%
testing_list =[]
for i in  np.linspace(0.1,0.9,9):
    d = {}
    y_p = Prediccion >= i
    print("Threshold:",i)
    cm = confusion_matrix(y_test2,y_p)
    d["th"] = i
    d["F1"] = np.round(f1_score(y_test2,y_p),2)
    d["Prec"] = np.round(precision_score(y_test2,y_p),2)
    d["Rec"] = np.round(recall_score(y_test2,y_p),2)
    d["Acc"] = np.round(accuracy_score(y_test2,y_p),2)
    d["RocAuc"] = np.round(roc_auc_score(y_test2,y_p),2)
    testing_list.append(d)
# Out:
# Threshold: 0.1
# Threshold: 0.2
# Threshold: 0.30000000000000004
# Threshold: 0.4
# Threshold: 0.5
# Threshold: 0.6
# Threshold: 0.7000000000000001
# Threshold: 0.8
# Threshold: 0.9

# %% [markdown]
# # Metricas para cada umbral.
# - th: umbral
# -------------------------------------------------------------------------------------------------------------------------------

# %%
testing_metrics_pd = pd.DataFrame(testing_list)
testing_metrics_pd
# Out:
#     th    F1  Prec   Rec   Acc  RocAuc
# 0  0.1  0.68  0.52  0.96  0.69    0.76
# 1  0.2  0.74  0.62  0.92  0.78    0.81
# 2  0.3  0.76  0.68  0.86  0.82    0.83
# 3  0.4  0.78  0.75  0.81  0.84    0.83
# 4  0.5  0.77  0.80  0.74  0.85    0.82
# 5  0.6  0.75  0.84  0.67  0.85    0.80
# 6  0.7  0.70  0.88  0.58  0.83    0.77
# 7  0.8  0.62  0.91  0.47  0.81    0.72
# 8  0.9  0.47  0.95  0.32  0.76    0.65

# %%
print(testing_metrics_pd.to_latex(index=False))
# Out:
# \begin{tabular}{rrrrrr}
# \toprule
#  th &   F1 &  Prec &  Rec &  Acc &  RocAuc \\
# \midrule
# 0.1 & 0.68 &  0.52 & 0.96 & 0.69 &    0.76 \\
# 0.2 & 0.74 &  0.62 & 0.92 & 0.78 &    0.81 \\
# 0.3 & 0.76 &  0.68 & 0.86 & 0.82 &    0.83 \\
# 0.4 & 0.78 &  0.75 & 0.81 & 0.84 &    0.83 \\
# 0.5 & 0.77 &  0.80 & 0.74 & 0.85 &    0.82 \\
# 0.6 & 0.75 &  0.84 & 0.67 & 0.85 &    0.80 \\
# 0.7 & 0.70 &  0.88 & 0.58 & 0.83 &    0.77 \\
# 0.8 & 0.62 &  0.91 & 0.47 & 0.81 &    0.72 \\
# 0.9 & 0.47 &  0.95 & 0.32 & 0.76 &    0.65 \\
# \bottomrule
# \end{tabular}

# %%
fpr, tpr, ths = roc_curve(y_test2,  Prediccion)
auc_ = auc(fpr, tpr)
plt.plot(fpr,tpr, label='ROC curve (area = %.2f)' %auc_)
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.legend()
plt.grid()
plt.show()

# %%
for i in  np.linspace(0.1,0.9,9):
    print(i)
    y_p = Prediccion >= i
    print(classification_report(y_test2, y_p))
    f1 = f1_score(y_test2, y_p)
    prec = precision_score(y_test2, y_p)
    rec = recall_score(y_test2, y_p)
    acc = accuracy_score(y_test2, y_p)
    cm=confusion_matrix(y_test2, y_p)
    print("Matriz de confusión: ")
    print(cm)
    print("----------------------------------------------------------")
    print("F1: %.2f" %f1 , " -- prec: %.2f" %prec, " -- recall: %.2f" %rec, " -- acc: %.2f" %acc)
    print("----------------------------------------------------------")
# Out:
# 0.1
#               precision    recall  f1-score   support
#
#            0       0.97      0.56      0.71     13263
#            1       0.52      0.96      0.68      6737
#
#     accuracy                           0.69     20000
#    macro avg       0.74      0.76      0.69     20000
# weighted avg       0.82      0.69      0.70     20000
#
# Matriz de confusión:
# [[7373 5890]
#  [ 264 6473]]
# ----------------------------------------------------------
# F1: 0.68  -- prec: 0.52  -- recall: 0.96  -- acc: 0.69
# ----------------------------------------------------------
# 0.2
#               precision    recall  f1-score   support
#
#            0       0.94      0.71      0.81     13263
#            1       0.62      0.92      0.74      6737
#
#     accuracy                           0.78     20000
#    macro avg       0.78      0.81      0.77     20000
# weighted avg       0.83      0.78      0.79     20000
#
# Matriz de confusión:
# [[9440 3823]
#  [ 572 6165]]
# ----------------------------------------------------------
# F1: 0.74  -- prec: 0.62  -- recall: 0.92  -- acc: 0.78
# ----------------------------------------------------------
# 0.30000000000000004
#               precision    recall  f1-score   support
#
#            0       0.92      0.80      0.85     13263
#            1       0.68      0.86      0.76      6737
#
#     accuracy                           0.82     20000
#    macro avg       0.80      0.83      0.81     20000
# weighted avg       0.84      0.82      0.82     20000
#
# Matriz de confusión:
# [[10582  2681]
#  [  921  5816]]
# ----------------------------------------------------------
# F1: 0.76  -- prec: 0.68  -- recall: 0.86  -- acc: 0.82
# ----------------------------------------------------------
# 0.4
#               precision    recall  f1-score   support
#
#            0       0.90      0.86      0.88     13263
#            1       0.75      0.81      0.78      6737
#
#     accuracy                           0.84     20000
#    macro avg       0.82      0.83      0.83     20000
# weighted avg       0.85      0.84      0.84     20000
#
# Matriz de confusión:
# [[11413  1850]
#  [ 1295  5442]]
# ----------------------------------------------------------
# F1: 0.78  -- prec: 0.75  -- recall: 0.81  -- acc: 0.84
# ----------------------------------------------------------
# 0.5
#               precision    recall  f1-score   support
#
#            0       0.87      0.91      0.89     13263
#            1       0.80      0.74      0.77      6737
#
#     accuracy                           0.85     20000
#    macro avg       0.84      0.82      0.83     20000
# weighted avg       0.85      0.85      0.85     20000
#
# Matriz de confusión:
# [[12024  1239]
#  [ 1730  5007]]
# ----------------------------------------------------------
# F1: 0.77  -- prec: 0.80  -- recall: 0.74  -- acc: 0.85
# ----------------------------------------------------------
# 0.6
#               precision    recall  f1-score   support
#
#            0       0.85      0.94      0.89     13263
#            1       0.84      0.67      0.75      6737
#
#     accuracy                           0.85     20000
#    macro avg       0.85      0.80      0.82     20000
# weighted avg       0.85      0.85      0.84     20000
#
# Matriz de confusión:
# [[12404   859]
#  [ 2201  4536]]
# ----------------------------------------------------------
# F1: 0.75  -- prec: 0.84  -- recall: 0.67  -- acc: 0.85
# ----------------------------------------------------------
# 0.7000000000000001
#               precision    recall  f1-score   support
#
#            0       0.82      0.96      0.88     13263
#            1       0.88      0.58      0.70      6737
#
#     accuracy                           0.83     20000
#    macro avg       0.85      0.77      0.79     20000
# weighted avg       0.84      0.83      0.82     20000
#
# Matriz de confusión:
# [[12717   546]
#  [ 2804  3933]]
# ----------------------------------------------------------
# F1: 0.70  -- prec: 0.88  -- recall: 0.58  -- acc: 0.83
# ----------------------------------------------------------
# 0.8
#               precision    recall  f1-score   support
#
#            0       0.78      0.98      0.87     13263
#            1       0.91      0.47      0.62      6737
#
#     accuracy                           0.81     20000
#    macro avg       0.85      0.72      0.75     20000
# weighted avg       0.83      0.81      0.79     20000
#
# Matriz de confusión:
# [[12954   309]
#  [ 3561  3176]]
# ----------------------------------------------------------
# F1: 0.62  -- prec: 0.91  -- recall: 0.47  -- acc: 0.81
# ----------------------------------------------------------
# 0.9
#               precision    recall  f1-score   support
#
#            0       0.74      0.99      0.85     13263
#            1       0.95      0.32      0.47      6737
#
#     accuracy                           0.76     20000
#    macro avg       0.84      0.65      0.66     20000
# weighted avg       0.81      0.76      0.72     20000
#
# Matriz de confusión:
# [[13147   116]
#  [ 4607  2130]]
# ----------------------------------------------------------
# F1: 0.47  -- prec: 0.95  -- recall: 0.32  -- acc: 0.76
# ----------------------------------------------------------

# %%
umbral = 0.4

# %%
maskSignal=Prediccion>umbral

# %%
predicBin=[]
for i in maskSignal:
    if(i==True):
        predicBin.append(1)
    else:
        predicBin.append(0)

# %%
npPredict=np.array(predicBin)

# %%
cm=confusion_matrix(y_test2, npPredict)
cm
# Out:
# array([[11413,  1850],
#        [ 1295,  5442]], dtype=int64)

# %%
cm_display = ConfusionMatrixDisplay(cm).plot()

# %%
f1= f1_score(y_test2, npPredict)
f1
# Out:
# 0.7758215125810821

# %%
prec=precision_score(y_test2, npPredict)
prec
# Out:
# 0.7462973121228744

# %%
rec=recall_score(y_test2, npPredict)
rec
# Out:
# 0.8077779427044679

# %%
accu=accuracy_score(y_test2, npPredict)
accu
# Out:
# 0.84275

# %%
print(classification_report(y_test2, npPredict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.86      0.88     13263
#            1       0.75      0.81      0.78      6737
#
#     accuracy                           0.84     20000
#    macro avg       0.82      0.83      0.83     20000
# weighted avg       0.85      0.84      0.84     20000

# %%
print("F1: %.2f" %f1 , " -- prec: %.2f" %prec, " -- recall: %.2f" %rec, " -- acc: %.2f" %acc)
# Out:
# F1: 0.78  -- prec: 0.75  -- recall: 0.81  -- acc: 0.76
