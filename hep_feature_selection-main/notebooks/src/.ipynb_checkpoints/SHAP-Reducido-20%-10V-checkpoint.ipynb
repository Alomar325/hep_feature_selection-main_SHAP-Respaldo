# %% [markdown]
# # SHAP
#
# ### Clasificación de eventos usando SHAP como seleccionador de características con los set de datos reducidos a 100000 eventos.

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------
#
# Alex Toro, Raquel Pezoa

# %% [markdown]
# ## Librerias necesarias-
# -------------------------------------------------------------------------------------------------------------------------------

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from xgboost import XGBClassifier
import shap
from sklearn.model_selection import train_test_split

# %%
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV

# %%
import xgboost as xgb

# %%
import winsound

# %%
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %% [markdown]
# ## Lectura del set de datos reducido.
#
# - El set original proviene de https://www.kaggle.com/competitions/higgs-boson/data.
# - Separación de la variable Label de las demas variables.
# -------------------------------------------------------------------------------------------------------------------------------

# %%
df = pd.read_csv("/Users/Alex/Downloads/Pre-procesado.csv")

# %%
X = df.drop(labels=['Label'], axis=1)
Y = df['Label']
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=0)

# %%
X_test
# Out:
#        DER_mass_MMC  DER_mass_transverse_met_lep  DER_mass_vis  DER_pt_h  \
# 3582       -999.000                       51.525        64.653    58.637
# 60498       153.541                       13.850        83.206    81.976
# 53227       138.446                        1.833        62.411   140.682
# 21333       137.621                       88.006        73.570     1.436
# 3885        137.341                       16.591       103.245   346.650
# ...             ...                          ...           ...       ...
# 60116      -999.000                       74.312        49.597    34.237
# 2415        129.729                       59.415        36.534   239.330
# 43763       124.421                       61.185        61.912   114.465
# 71345        74.761                       15.304        39.035   122.816
# 77687       102.673                      112.785        69.019   131.959
#
#        DER_deltaeta_jet_jet  DER_mass_jet_jet  DER_prodeta_jet_jet  \
# 3582               -999.000          -999.000             -999.000
# 60498                 4.211           719.978               -3.739
# 53227                 0.560           170.804                0.552
# 21333              -999.000          -999.000             -999.000
# 3885                  1.493           189.269                0.535
# ...                     ...               ...                  ...
# 60116              -999.000          -999.000             -999.000
# 2415                  2.328           223.783               -1.351
# 43763                 1.478           132.847                0.345
# 71345              -999.000          -999.000             -999.000
# 77687                 4.796          1406.461               -5.524
#
#        DER_deltar_tau_lep  DER_pt_tot  DER_sum_pt  ...  PRI_met_phi  \
# 3582                1.797      58.637      89.719  ...        2.340
# 60498               2.632      29.361     249.653  ...        2.108
# 53227               2.290      43.660     348.000  ...        2.223
# 21333               3.040       1.436      81.058  ...       -2.323
# 3885                1.212     177.422     625.424  ...        2.090
# ...                   ...         ...         ...  ...          ...
# 60116               1.593       2.563     100.839  ...        3.103
# 2415                1.135      53.748     298.555  ...        0.471
# 43763               1.927      23.801     218.586  ...       -1.936
# 71345               1.180      28.062     172.760  ...        2.430
# 77687               1.580       1.151     352.638  ...        2.047
#
#        PRI_met_sumet  PRI_jet_num  PRI_jet_leading_pt  PRI_jet_leading_eta  \
# 3582         221.042            0            -999.000             -999.000
# 60498        370.166            2             102.704               -1.272
# 53227        424.059            3             172.656               -0.514
# 21333        102.216            0            -999.000             -999.000
# 3885         736.536            3             112.596                1.791
# ...              ...          ...                 ...                  ...
# 60116        147.340            1              31.825               -0.521
# 2415         308.579            3             156.969                1.231
# 43763        270.194            2              70.661               -0.205
# 71345        201.181            1             102.368               -2.306
# 77687        369.024            2             135.787                2.874
#
#        PRI_jet_leading_phi  PRI_jet_subleading_pt  PRI_jet_subleading_eta  \
# 3582              -999.000               -999.000                -999.000
# 60498               -1.920                 72.803                   2.939
# 53227               -0.716                 69.112                  -1.074
# 21333             -999.000               -999.000                -999.000
# 3885                -1.492                109.589                   0.298
# ...                    ...                    ...                     ...
# 60116               -0.624               -999.000                -999.000
# 2415                -2.784                 37.134                  -1.097
# 43763                1.182                 60.564                  -1.683
# 71345               -1.037               -999.000                -999.000
# 77687               -2.537                119.349                  -1.922
#
#        PRI_jet_subleading_phi  PRI_jet_all_pt
# 3582                 -999.000           0.000
# 60498                   0.699         175.507
# 53227                  -2.313         282.655
# 21333                -999.000           0.000
# 3885                   -1.855         357.919
# ...                       ...             ...
# 60116                -999.000          31.825
# 2415                   -2.377         227.006
# 43763                  -0.056         131.225
# 71345                -999.000         102.368
# 77687                  -0.486         255.136
#
# [20000 rows x 30 columns]

# %%
params={
 "learning_rate"    : [0.05, 0.10, 0.15, 0.20, 0.25, 0.30 ] ,
 "max_depth"        : [ 3, 4, 5, 6, 8, 10, 12, 15],
 "min_child_weight" : [ 1, 3, 5, 7 ],
 "gamma"            : [ 0.0, 0.1, 0.2 , 0.3, 0.4 ],
 "colsample_bytree" : [ 0.3, 0.4, 0.5 , 0.7 ]
    
}

# %%
classifier=XGBClassifier()

# %%
random_search=RandomizedSearchCV(classifier,param_distributions=params,n_iter=5,scoring='roc_auc',n_jobs=-1,cv=5,verbose=3)

# %%
random_search.fit(X_train,y_train) # el de 5 iteraciones
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# RandomizedSearchCV(cv=5,
#                    estimator=XGBClassifier(base_score=None, booster=None,
#                                            callbacks=None,
#                                            colsample_bylevel=None,
#                                            colsample_bynode=None,
#                                            colsample_bytree=None,
#                                            early_stopping_rounds=None,
#                                            enable_categorical=False,
#                                            eval_metric=None, gamma=None,
#                                            gpu_id=None, grow_policy=None,
#                                            importance_type=None,
#                                            interaction_constraints=None,
#                                            learning_rate=None, max_bin=None,...
#                                            n_estimators=100, n_jobs=None,
#                                            num_parallel_tree=None,
#                                            predictor=None, random_state=None,
#                                            reg_alpha=None, reg_lambda=None, ...),
#                    n_iter=5, n_jobs=-1,
#                    param_distributions={'colsample_bytree': [0.3, 0.4, 0.5,
#                                                              0.7],
#                                         'gamma': [0.0, 0.1, 0.2, 0.3, 0.4],
#                                         'learning_rate': [0.05, 0.1, 0.15, 0.2,
#                                                           0.25, 0.3],
#                                         'max_depth': [3, 4, 5, 6, 8, 10, 12,
#                                                       15],
#                                         'min_child_weight': [1, 3, 5, 7]},
#                    scoring='roc_auc', verbose=3)

# %%
frequency = 2500  # Set Frequency To 2500 Hertz
duration = 1000  # Set Duration To 1000 ms == 1 second
winsound.Beep(frequency, duration)

# %%
print(random_search.best_estimator_) # 5 iteraciones
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=0.3,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0.1, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.2, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=15, max_leaves=0, min_child_weight=5,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, predictor='auto', random_state=0,
#               reg_alpha=0, reg_lambda=1, ...)

# %%
random_search.best_params_ # 5 iteraciones
# Out:
# {'min_child_weight': 5,
#  'max_depth': 15,
#  'learning_rate': 0.2,
#  'gamma': 0.1,
#  'colsample_bytree': 0.3}

# %% [markdown]
# ### Entrenamiento y testeo del set de datos con XGBoost.
#
# - Se entrena con XGBClassifier antes de usar SHAP, ya que SHAP necesita con aterioridad un modelo entrenado.
# -------------------------------------------------------------------------------------------------------------------------------

# %%
model = XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=0.3,
              early_stopping_rounds=None, enable_categorical=False,
              eval_metric=None, gamma=0.1, gpu_id=-1, grow_policy='depthwise',
              importance_type=None, interaction_constraints='',
              learning_rate=0.2, max_bin=256, max_cat_to_onehot=4,
              max_delta_step=0, max_depth=15, max_leaves=0, min_child_weight=5,
              missing=None, monotone_constraints='()', n_estimators=100,
              n_jobs=0, num_parallel_tree=1, predictor='auto', random_state=0,
              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None, silent=True,
       subsample=1)
model.get_params()
# nuevos hiperparametros
# Out:
# {'objective': 'binary:logistic',
#  'use_label_encoder': False,
#  'base_score': 0.5,
#  'booster': 'gbtree',
#  'callbacks': None,
#  'colsample_bylevel': 1,
#  'colsample_bynode': 1,
#  'colsample_bytree': 0.3,
#  'early_stopping_rounds': None,
#  'enable_categorical': False,
#  'eval_metric': None,
#  'gamma': 0.1,
#  'gpu_id': -1,
#  'grow_policy': 'depthwise',
#  'importance_type': None,
#  'interaction_constraints': '',
#  'learning_rate': 0.2,
#  'max_bin': 256,
#  'max_cat_to_onehot': 4,
#  'max_delta_step': 0,
#  'max_depth': 15,
#  'max_leaves': 0,
#  'min_child_weight': 5,
#  'missing': None,
#  'monotone_constraints': '()',
#  'n_estimators': 100,
#  'n_jobs': 0,
#  'num_parallel_tree': 1,
#  'predictor': 'auto',
#  'random_state': 0,
#  'reg_alpha': 0,
#  'reg_lambda': 1,
#  'sampling_method': None,
#  'scale_pos_weight': 1,
#  'subsample': 1,
#  'tree_method': None,
#  'validate_parameters': None,
#  'verbosity': None,
#  'seed': None,
#  'silent': True}

# %%
model.fit(X_train, y_train)
# Out:
# [16:54:34] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=0.3,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0.1, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.2, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=15, max_leaves=0, min_child_weight=5,
#               missing=None, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, predictor='auto', random_state=0,
#               reg_alpha=0, reg_lambda=1, ...)

# %% [markdown]
# ### SHAP seleccionado características.

# %%
# Fits the explainer
explainer = shap.TreeExplainer(model = model)
# Calculates the SHAP values - It takes some time

# %%
# Evaluate SHAP values
shap_values = explainer.shap_values(X_test)
# Out:
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %% [markdown]
# ### Waterfall plot
#
# - Esta gráfica muestra cómo las características contribuyen a impulsar la predicción del clasificador desde el valor base (la predicción promedio del modelo sobre el conjunto de datos de entrenamiento) hasta la salida del modelo, de una muestra de datos específica.
# - Las características que empujan la predicción más alta se muestran en rojo, las que empujan la predicción más baja están en azul.
# -------------------------------------------------------------------------------------------------------------------------------

# %%
i=4
shap.plots._waterfall.waterfall_legacy(explainer.expected_value, 
                                       shap_values[i],
                                       feature_names = X_train.columns, 
                                       show = True,
                                      max_display=10)
# el numero es lo que contribuye en el dato en la posicion 4 (un evento)

# %% [markdown]
# ### Summary Plots
# - Ranking de las mejore 20 características
# -------------------------------------------------------------------------------------------------------------------------------

# %%
shap.summary_plot(shap_values, X_test, plot_type="bar")

# %%
X_test
# Out:
#        DER_mass_MMC  DER_mass_transverse_met_lep  DER_mass_vis  DER_pt_h  \
# 3582       -999.000                       51.525        64.653    58.637
# 60498       153.541                       13.850        83.206    81.976
# 53227       138.446                        1.833        62.411   140.682
# 21333       137.621                       88.006        73.570     1.436
# 3885        137.341                       16.591       103.245   346.650
# ...             ...                          ...           ...       ...
# 60116      -999.000                       74.312        49.597    34.237
# 2415        129.729                       59.415        36.534   239.330
# 43763       124.421                       61.185        61.912   114.465
# 71345        74.761                       15.304        39.035   122.816
# 77687       102.673                      112.785        69.019   131.959
#
#        DER_deltaeta_jet_jet  DER_mass_jet_jet  DER_prodeta_jet_jet  \
# 3582               -999.000          -999.000             -999.000
# 60498                 4.211           719.978               -3.739
# 53227                 0.560           170.804                0.552
# 21333              -999.000          -999.000             -999.000
# 3885                  1.493           189.269                0.535
# ...                     ...               ...                  ...
# 60116              -999.000          -999.000             -999.000
# 2415                  2.328           223.783               -1.351
# 43763                 1.478           132.847                0.345
# 71345              -999.000          -999.000             -999.000
# 77687                 4.796          1406.461               -5.524
#
#        DER_deltar_tau_lep  DER_pt_tot  DER_sum_pt  ...  PRI_met_phi  \
# 3582                1.797      58.637      89.719  ...        2.340
# 60498               2.632      29.361     249.653  ...        2.108
# 53227               2.290      43.660     348.000  ...        2.223
# 21333               3.040       1.436      81.058  ...       -2.323
# 3885                1.212     177.422     625.424  ...        2.090
# ...                   ...         ...         ...  ...          ...
# 60116               1.593       2.563     100.839  ...        3.103
# 2415                1.135      53.748     298.555  ...        0.471
# 43763               1.927      23.801     218.586  ...       -1.936
# 71345               1.180      28.062     172.760  ...        2.430
# 77687               1.580       1.151     352.638  ...        2.047
#
#        PRI_met_sumet  PRI_jet_num  PRI_jet_leading_pt  PRI_jet_leading_eta  \
# 3582         221.042            0            -999.000             -999.000
# 60498        370.166            2             102.704               -1.272
# 53227        424.059            3             172.656               -0.514
# 21333        102.216            0            -999.000             -999.000
# 3885         736.536            3             112.596                1.791
# ...              ...          ...                 ...                  ...
# 60116        147.340            1              31.825               -0.521
# 2415         308.579            3             156.969                1.231
# 43763        270.194            2              70.661               -0.205
# 71345        201.181            1             102.368               -2.306
# 77687        369.024            2             135.787                2.874
#
#        PRI_jet_leading_phi  PRI_jet_subleading_pt  PRI_jet_subleading_eta  \
# 3582              -999.000               -999.000                -999.000
# 60498               -1.920                 72.803                   2.939
# 53227               -0.716                 69.112                  -1.074
# 21333             -999.000               -999.000                -999.000
# 3885                -1.492                109.589                   0.298
# ...                    ...                    ...                     ...
# 60116               -0.624               -999.000                -999.000
# 2415                -2.784                 37.134                  -1.097
# 43763                1.182                 60.564                  -1.683
# 71345               -1.037               -999.000                -999.000
# 77687               -2.537                119.349                  -1.922
#
#        PRI_jet_subleading_phi  PRI_jet_all_pt
# 3582                 -999.000           0.000
# 60498                   0.699         175.507
# 53227                  -2.313         282.655
# 21333                -999.000           0.000
# 3885                   -1.855         357.919
# ...                       ...             ...
# 60116                -999.000          31.825
# 2415                   -2.377         227.006
# 43763                  -0.056         131.225
# 71345                -999.000         102.368
# 77687                  -0.486         255.136
#
# [20000 rows x 30 columns]

# %%
shap_values
# Out:
# array([[-8.0016756e-01,  3.6272649e-03, -5.8537640e-05, ...,
#          2.0019617e-02,  1.8028660e-02, -4.9981318e-02],
#        [ 1.0094316e+00,  3.5742235e-01,  3.7790209e-01, ...,
#          7.7972688e-02,  4.7023829e-02,  1.5257981e-01],
#        [ 1.4875022e+00,  4.6042955e-01,  2.7193127e-02, ...,
#          3.9251661e-03,  2.7871896e-02,  1.8339518e-01],
#        ...,
#        [ 9.2198735e-01, -3.2092986e-01, -7.0628583e-02, ...,
#         -4.5441907e-02,  3.3100937e-02,  2.7057236e-01],
#        [-1.7879181e+00,  1.7528585e-01, -7.5028974e-01, ...,
#          1.5211729e-03, -3.5245273e-02,  6.5278053e-02],
#        [-1.3051468e-01, -7.5098294e-01, -2.2990271e-02, ...,
#         -5.1338132e-03,  2.3545972e-03,  9.9505857e-02]], dtype=float32)

# %% [markdown]
# ### Obteniendo la media de los valores absolutos de SHAP (|SHAP value|).
# -------------------------------------------------------------------------------------------------------------------------------

# %%
meanL = []
for valus in range(0,len(shap_values)):
    for singularidad in range(0,len(shap_values[valus])):
        if valus==0:
            meanL.append(abs(shap_values[valus][singularidad]))
        else:
            meanL[singularidad]=meanL[singularidad]+abs(shap_values[valus][singularidad])

# %% [markdown]
# ### Convertir los datos a  una lista de duplas.
#
# - Se convierte la media de los valores absolutos de SHAP junto a las columnas del dataframe en una lista de duplas.
# - Se realizan las duplas para así poder reordenar las variables de la más relevante a la menos relevante.
# - Se Reordena la duplas de mayor a menor.
# - Se separan las duplas en listas separadas y transformar las 20 primeras en arreglos de numpy.
# -------------------------------------------------------------------------------------------------------------------------------

# %%
meanL=list(map(lambda x: x / len(shap_values), meanL))
l=[]
for feature in zip(meanL,X_train.columns):
    l.append(feature)
    print(feature)
# Out:
# (0.7856869140625, 'DER_mass_MMC')
# (0.418486669921875, 'DER_mass_transverse_met_lep')
# (0.4071599609375, 'DER_mass_vis')
# (0.14145767822265626, 'DER_pt_h')
# (0.06396580200195312, 'DER_deltaeta_jet_jet')
# (0.08244983520507812, 'DER_mass_jet_jet')
# (0.066743310546875, 'DER_prodeta_jet_jet')
# (0.2352564208984375, 'DER_deltar_tau_lep')
# (0.1077657470703125, 'DER_pt_tot')
# (0.1238309326171875, 'DER_sum_pt')
# (0.1813708740234375, 'DER_pt_ratio_lep_tau')
# (0.217916796875, 'DER_met_phi_centrality')
# (0.18709271240234376, 'DER_lep_eta_centrality')
# (0.35090068359375, 'PRI_tau_pt')
# (0.1089707763671875, 'PRI_tau_eta')
# (0.07331231079101562, 'PRI_tau_phi')
# (0.08499188232421875, 'PRI_lep_pt')
# (0.15213663330078125, 'PRI_lep_eta')
# (0.06937512817382813, 'PRI_lep_phi')
# (0.19979140625, 'PRI_met')
# (0.06721130981445313, 'PRI_met_phi')
# (0.09953596801757812, 'PRI_met_sumet')
# (0.03373025817871094, 'PRI_jet_num')
# (0.1197289794921875, 'PRI_jet_leading_pt')
# (0.2143789794921875, 'PRI_jet_leading_eta')
# (0.04233533630371094, 'PRI_jet_leading_phi')
# (0.03633001708984375, 'PRI_jet_subleading_pt')
# (0.04345494995117188, 'PRI_jet_subleading_eta')
# (0.01957129821777344, 'PRI_jet_subleading_phi')
# (0.12023797607421875, 'PRI_jet_all_pt')

# %%
l.sort(reverse=True)
l
# Out:
# [(0.7856869140625, 'DER_mass_MMC'),
#  (0.418486669921875, 'DER_mass_transverse_met_lep'),
#  (0.4071599609375, 'DER_mass_vis'),
#  (0.35090068359375, 'PRI_tau_pt'),
#  (0.2352564208984375, 'DER_deltar_tau_lep'),
#  (0.217916796875, 'DER_met_phi_centrality'),
#  (0.2143789794921875, 'PRI_jet_leading_eta'),
#  (0.19979140625, 'PRI_met'),
#  (0.18709271240234376, 'DER_lep_eta_centrality'),
#  (0.1813708740234375, 'DER_pt_ratio_lep_tau'),
#  (0.15213663330078125, 'PRI_lep_eta'),
#  (0.14145767822265626, 'DER_pt_h'),
#  (0.1238309326171875, 'DER_sum_pt'),
#  (0.12023797607421875, 'PRI_jet_all_pt'),
#  (0.1197289794921875, 'PRI_jet_leading_pt'),
#  (0.1089707763671875, 'PRI_tau_eta'),
#  (0.1077657470703125, 'DER_pt_tot'),
#  (0.09953596801757812, 'PRI_met_sumet'),
#  (0.08499188232421875, 'PRI_lep_pt'),
#  (0.08244983520507812, 'DER_mass_jet_jet'),
#  (0.07331231079101562, 'PRI_tau_phi'),
#  (0.06937512817382813, 'PRI_lep_phi'),
#  (0.06721130981445313, 'PRI_met_phi'),
#  (0.066743310546875, 'DER_prodeta_jet_jet'),
#  (0.06396580200195312, 'DER_deltaeta_jet_jet'),
#  (0.04345494995117188, 'PRI_jet_subleading_eta'),
#  (0.04233533630371094, 'PRI_jet_leading_phi'),
#  (0.03633001708984375, 'PRI_jet_subleading_pt'),
#  (0.03373025817871094, 'PRI_jet_num'),
#  (0.01957129821777344, 'PRI_jet_subleading_phi')]

# %%
l_v = []
for importance in range(len(l)):
    for var in range(len(l[importance])):
        if(var == 1):
            l_v.append(l[importance][var])

# %%
x = np.array(l_v[0:10])
x
# Out:
# array(['DER_mass_MMC', 'DER_mass_transverse_met_lep', 'DER_mass_vis',
#        'PRI_tau_pt', 'DER_deltar_tau_lep', 'DER_met_phi_centrality',
#        'PRI_jet_leading_eta', 'PRI_met', 'DER_lep_eta_centrality',
#        'DER_pt_ratio_lep_tau'], dtype='<U27')

# %%
# Force_plot
shap.initjs()
shap.force_plot(explainer.expected_value, shap_values[102,:], X_test.iloc[102,:], link="logit")
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...
# <div id='i1JJU0VV7U6W52U64FV7D'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": -0.8288472890853882, "outValue": 2.0483832359313965, "link": "logit", "featureNames": ["DER_mass_MMC", "DER_mass_transverse_met_lep", "DER_mass_vis", "DER_pt_h", "DER_deltaeta_jet_jet", "DER_mass_jet_jet", "DER_prodeta_jet_jet", "DER_deltar_tau_lep", "DER_pt_tot", "DER_sum_pt", "DER_pt_ratio_lep_tau", "DER_met_phi_centrality", "DER_lep_eta_centrality", "PRI_tau_pt", "PRI_tau_eta", "PRI_tau_phi", "PRI_lep_pt", "PRI_lep_eta", "PRI_lep_phi", "PRI_met", "PRI_met_phi", "PRI_met_sumet", "PRI_jet_num", "PRI_jet_leading_pt", "PRI_jet_leading_eta", "PRI_jet_leading_phi", "PRI_jet_subleading_pt", "PRI_jet_subleading_eta", "PRI_jet_subleading_phi", "PRI_jet_all_pt"], "features": {"0": {"effect": 1.1531689167022705, "value": 128.143}, "1": {"effect": 0.564399242401123, "value": 19.691}, "2": {"effect": 0.5546637177467346, "value": 94.173}, "3": {"effect": 0.0550508089363575, "value": 89.704}, "4": {"effect": -0.16176065802574158, "value": 2.481}, "5": {"effect": -0.053633302450180054, "value": 161.63}, "6": {"effect": -0.15033848583698273, "value": -0.962}, "7": {"effect": 0.05283711478114128, "value": 2.004}, "8": {"effect": 0.0478048250079155, "value": 9.585}, "9": {"effect": 0.1310839056968689, "value": 213.369}, "10": {"effect": -0.0796322226524353, "value": 1.768}, "11": {"effect": -0.07661011070013046, "value": 0.379}, "12": {"effect": 0.6953386664390564, "value": 0.842}, "13": {"effect": 0.14631161093711853, "value": 40.052}, "14": {"effect": -0.046902403235435486, "value": -1.99}, "15": {"effect": 0.11202377080917358, "value": 2.687}, "16": {"effect": 0.13962168991565704, "value": 70.809}, "17": {"effect": -0.004139395896345377, "value": -1.274}, "18": {"effect": -0.025761660188436508, "value": 0.816}, "19": {"effect": -0.2202114760875702, "value": 29.697}, "20": {"effect": 0.025721753016114235, "value": 0.383}, "21": {"effect": -0.03200830891728401, "value": 334.749}, "22": {"effect": 0.04970962181687355, "value": 2.0}, "23": {"effect": 0.10971696674823761, "value": 69.852}, "24": {"effect": -0.07254289835691452, "value": -1.999}, "25": {"effect": 0.038233496248722076, "value": -1.792}, "26": {"effect": -0.043964751064777374, "value": 32.656}, "27": {"effect": -0.24198965728282928, "value": 0.481}, "28": {"effect": 0.06525691598653793, "value": -2.958}, "29": {"effect": 0.14578299224376678, "value": 102.508}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('i1JJU0VV7U6W52U64FV7D')
#   );
# </script>

# %%
shap.summary_plot(shap_values, X_test)

# %%
X_BestFeature = X[x]
X_BestFeature
# Out:
#        DER_mass_MMC  DER_mass_transverse_met_lep  DER_mass_vis  PRI_tau_pt  \
# 0            85.123                        5.111        45.454      28.827
# 1            70.751                       16.532        47.178      35.467
# 2          -999.000                       79.211        77.286      58.913
# 3            74.959                       58.796        58.484      29.469
# 4          -999.000                       82.701       109.640      34.761
# ...             ...                          ...           ...         ...
# 99995        95.075                        9.736        62.654      72.089
# 99996       108.208                       20.509        70.580      24.802
# 99997        77.503                       20.791        44.842      20.812
# 99998        96.531                       12.773        60.703      83.062
# 99999      -999.000                       51.909       143.266     130.178
#
#        DER_deltar_tau_lep  DER_met_phi_centrality  PRI_jet_leading_eta  \
# 0                   1.288                   1.335               -0.903
# 1                   1.221                   0.215               -2.876
# 2                   1.879                  -1.358             -999.000
# 3                   2.628                  -1.359             -999.000
# 4                   2.674                  -1.326             -999.000
# ...                   ...                     ...                  ...
# 99995               1.078                   0.659               -0.962
# 99996               2.551                   1.393               -0.341
# 99997               1.628                   1.382               -2.383
# 99998               1.031                   1.413                1.188
# 99999               2.847                  -1.348             -999.000
#
#        PRI_met  DER_lep_eta_centrality  DER_pt_ratio_lep_tau
# 0       73.597                -999.000                 1.324
# 1       38.748                   0.545                 1.056
# 2       65.606                -999.000                 0.567
# 3       33.185                -999.000                 0.947
# 4       62.011                -999.000                 0.794
# ...        ...                     ...                   ...
# 99995   56.776                -999.000                 0.612
# 99996   23.523                   0.541                 1.390
# 99997   51.494                -999.000                 1.824
# 99998   68.280                   0.826                 0.477
# 99999  110.739                -999.000                 0.248
#
# [100000 rows x 10 columns]

# %% [markdown]
# ### Entrenamiento, testeo y optimizacion de parametros de DMatrix de XGBoost con las variables entregadas por SHAP.
# -------------------------------------------------------------------------------------------------------------------------------

# %%
X_train2, X_test2, y_train2, y_test2 = train_test_split(X_BestFeature, Y, test_size=0.2, random_state=0)

# %%
dtrain = xgb.DMatrix(X_train2, label=y_train2)
dtest = xgb.DMatrix(X_test2, label=y_test2)

# %%
params = {
    # Parameters that we are going to tune.
    'max_depth':6,
    'min_child_weight': 1,
    'eta':.3,
    'subsample': 1,
    'colsample_bytree': 1,
    # Other parameters
    'objective':'reg:linear',
}
params['eval_metric'] = "mae"
params['base_score'] = np.mean(y_train)
num_boost_round = 999

# %%
modelo = xgb.train( 
    params, 
    dtrain, 
    num_boost_round=num_boost_round, 
    evals=[(dtest, "Test")], 
    early_stopping_rounds=10 
)
# Out:
# [17:00:35] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	Test-mae:0.39322
# [1]	Test-mae:0.35338
# [2]	Test-mae:0.32450
# [3]	Test-mae:0.30289
# [4]	Test-mae:0.28686
# [5]	Test-mae:0.27535
# [6]	Test-mae:0.26663
# [7]	Test-mae:0.25996
# [8]	Test-mae:0.25496
# [9]	Test-mae:0.25063
# [10]	Test-mae:0.24850
# [11]	Test-mae:0.24690
# [12]	Test-mae:0.24536
# [13]	Test-mae:0.24364
# [14]	Test-mae:0.24338
# [15]	Test-mae:0.24247
# [16]	Test-mae:0.24199
# [17]	Test-mae:0.24183
# [18]	Test-mae:0.24124
# [19]	Test-mae:0.24099
# [20]	Test-mae:0.24080
# [21]	Test-mae:0.24081
# [22]	Test-mae:0.24060
# [23]	Test-mae:0.24008
# [24]	Test-mae:0.23975
# [25]	Test-mae:0.23974
# [26]	Test-mae:0.23990
# [27]	Test-mae:0.23992
# [28]	Test-mae:0.23996
# [29]	Test-mae:0.23976
# [30]	Test-mae:0.23978
# [31]	Test-mae:0.23973
# [32]	Test-mae:0.23943
# [33]	Test-mae:0.23945
# [34]	Test-mae:0.23958
# [35]	Test-mae:0.23959
# [36]	Test-mae:0.23960
# [37]	Test-mae:0.23953
# [38]	Test-mae:0.23949
# [39]	Test-mae:0.23955
# [40]	Test-mae:0.23951
# [41]	Test-mae:0.23945
# [42]	Test-mae:0.23940
# [43]	Test-mae:0.23934
# [44]	Test-mae:0.23942
# [45]	Test-mae:0.23943
# [46]	Test-mae:0.23909
# [47]	Test-mae:0.23911
# [48]	Test-mae:0.23914
# [49]	Test-mae:0.23910
# [50]	Test-mae:0.23904
# [51]	Test-mae:0.23905
# [52]	Test-mae:0.23903
# [53]	Test-mae:0.23904
# [54]	Test-mae:0.23918
# [55]	Test-mae:0.23921
# [56]	Test-mae:0.23911
# [57]	Test-mae:0.23915
# [58]	Test-mae:0.23915
# [59]	Test-mae:0.23902
# [60]	Test-mae:0.23901
# [61]	Test-mae:0.23899
# [62]	Test-mae:0.23895
# [63]	Test-mae:0.23892
# [64]	Test-mae:0.23897
# [65]	Test-mae:0.23905
# [66]	Test-mae:0.23907
# [67]	Test-mae:0.23898
# [68]	Test-mae:0.23901
# [69]	Test-mae:0.23895
# [70]	Test-mae:0.23863
# [71]	Test-mae:0.23861
# [72]	Test-mae:0.23869
# [73]	Test-mae:0.23886
# [74]	Test-mae:0.23884
# [75]	Test-mae:0.23895
# [76]	Test-mae:0.23905
# [77]	Test-mae:0.23899
# [78]	Test-mae:0.23903
# [79]	Test-mae:0.23890
# [80]	Test-mae:0.23896
# [81]	Test-mae:0.23897

# %%
print("Best MAE: {:.2f} with {} rounds".format(
                 modelo.best_score,
                 modelo.best_iteration+1))
# Out:
# Best MAE: 0.24 with 72 rounds

# %%
cv_results = xgb.cv( 
    params, 
    dtrain, 
    num_boost_round=num_boost_round, 
    seed=42, 
    nfold=5, 
    metrics={'mae'}, 
    early_stopping_rounds=10 
)
cv_results
# Out:
# [17:00:38] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:00:38] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:00:38] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:00:38] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [17:00:38] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
#     train-mae-mean  train-mae-std  test-mae-mean  test-mae-std
# 0         0.393134       0.000478       0.394184      0.000974
# 1         0.352561       0.000492       0.354459      0.001013
# 2         0.322999       0.000535       0.325770      0.001175
# 3         0.300941       0.000671       0.304345      0.000954
# 4         0.284141       0.000585       0.288251      0.000912
# 5         0.271898       0.000616       0.276561      0.000849
# 6         0.262324       0.000590       0.267565      0.000971
# 7         0.254914       0.000501       0.260841      0.000980
# 8         0.249730       0.000716       0.256148      0.001225
# 9         0.245310       0.000373       0.252331      0.001013
# 10        0.241950       0.000828       0.249388      0.001304
# 11        0.239330       0.000434       0.247271      0.001310
# 12        0.237400       0.000663       0.245771      0.001497
# 13        0.236109       0.000536       0.244894      0.001587
# 14        0.234984       0.000651       0.244178      0.001565
# 15        0.233706       0.000699       0.243377      0.001557
# 16        0.232999       0.000547       0.243001      0.001435
# 17        0.232209       0.000543       0.242682      0.001492
# 18        0.231308       0.000397       0.242161      0.001313
# 19        0.230971       0.000488       0.242144      0.001467
# 20        0.230501       0.000417       0.242014      0.001529
# 21        0.229954       0.000379       0.241798      0.001649
# 22        0.229523       0.000428       0.241681      0.001492
# 23        0.229106       0.000368       0.241673      0.001505
# 24        0.228814       0.000201       0.241586      0.001413
# 25        0.228493       0.000302       0.241497      0.001447
# 26        0.228112       0.000283       0.241349      0.001451
# 27        0.227721       0.000450       0.241327      0.001415
# 28        0.227293       0.000477       0.241208      0.001381
# 29        0.226934       0.000445       0.241170      0.001359
# 30        0.226546       0.000645       0.241134      0.001380
# 31        0.226212       0.000653       0.241102      0.001378
# 32        0.225856       0.000631       0.241013      0.001400
# 33        0.225605       0.000561       0.241010      0.001377
# 34        0.225261       0.000655       0.240989      0.001297
# 35        0.224952       0.000619       0.240907      0.001287
# 36        0.224470       0.000623       0.240846      0.001319
# 37        0.224246       0.000508       0.240856      0.001375
# 38        0.223920       0.000556       0.240779      0.001362
# 39        0.223659       0.000501       0.240778      0.001362
# 40        0.223326       0.000533       0.240758      0.001317
# 41        0.222994       0.000429       0.240722      0.001303
# 42        0.222666       0.000513       0.240703      0.001307
# 43        0.222327       0.000502       0.240676      0.001402
# 44        0.222087       0.000486       0.240694      0.001310
# 45        0.221740       0.000470       0.240706      0.001447
# 46        0.221325       0.000481       0.240545      0.001379
# 47        0.221029       0.000592       0.240507      0.001311
# 48        0.220698       0.000675       0.240529      0.001319
# 49        0.220377       0.000669       0.240500      0.001449
# 50        0.220152       0.000699       0.240480      0.001396
# 51        0.219942       0.000701       0.240488      0.001362
# 52        0.219760       0.000700       0.240504      0.001409
# 53        0.219520       0.000766       0.240504      0.001376
# 54        0.219231       0.000817       0.240471      0.001365
# 55        0.218867       0.000881       0.240479      0.001306
# 56        0.218451       0.001043       0.240345      0.001338

# %%
cv_results['test-mae-mean'].min()
# Out:
# 0.24034472856695932

# %%
gridsearch_params = [
    (max_depth, min_child_weight)
    for max_depth in range(9,12)
    for min_child_weight in range(5,8)
]

# %%
min_mae = float("Inf")
best_params = None
for max_depth, min_child_weight in gridsearch_params:
    print("CV with max_depth={}, min_child_weight={}".format(
                             max_depth,
                             min_child_weight))
    # Update our parameters
    params['max_depth'] = max_depth
    params['min_child_weight'] = min_child_weight
    # Run CV
    cv_results = xgb.cv(
        params,
        dtrain,
        num_boost_round=num_boost_round,
        seed=42,
        nfold=5,
        metrics={'mae'},
        early_stopping_rounds=10
    )
    # Update best MAE
    mean_mae = cv_results['test-mae-mean'].min()
    boost_rounds = cv_results['test-mae-mean'].argmin()
    print("\tMAE {} for {} rounds".format(mean_mae, boost_rounds))
    if mean_mae < min_mae:
        min_mae = mean_mae
        best_params = (max_depth,min_child_weight)
print("Best params: {}, {}, MAE: {}".format(best_params[0], best_params[1], min_mae))
frequency = 2500  # Set Frequency To 2500 Hertz
duration = 1000  # Set Duration To 1000 ms == 1 second
winsound.Beep(frequency, duration)
# Out:
# CV with max_depth=9, min_child_weight=5
# [12:11:00] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [12:11:00] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [12:11:01] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [12:11:01] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [12:11:01] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.2362480424174481 for 23 rounds
# CV with max_depth=9, min_child_weight=6
# [12:11:07] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [12:11:07] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [12:11:07] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [12:11:07] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [12:11:07] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.23634887461618903 for 22 rounds
# CV with max_depth=9, min_child_weight=7
# [12:11:13] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [12:11:13] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [12:11:13] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [12:11:13] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [12:11:13] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.23705590953340047 for 21 rounds
# CV with max_depth=10, min_child_weight=5
# [12:11:19] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [12:11:19] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [12:11:19] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [12:11:19] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [12:11:19] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.2356633936249244 for 17 rounds
# CV with max_depth=10, min_child_weight=6
# [12:11:25] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [12:11:25] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [12:11:25] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [12:11:25] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [12:11:25] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.23600793223968553 for 21 rounds
# CV with max_depth=10, min_child_weight=7
# [12:11:31] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [12:11:31] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [12:11:31] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [12:11:31] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [12:11:31] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.23649443874505627 for 21 rounds
# CV with max_depth=11, min_child_weight=5
# [12:11:38] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [12:11:38] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [12:11:38] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [12:11:38] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [12:11:38] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.23518351189879705 for 20 rounds
# CV with max_depth=11, min_child_weight=6
# [12:11:45] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [12:11:45] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [12:11:45] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [12:11:45] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [12:11:45] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.23566213043237952 for 17 rounds
# CV with max_depth=11, min_child_weight=7
# [12:11:52] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [12:11:52] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [12:11:52] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [12:11:52] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [12:11:52] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.23596385156413993 for 18 rounds
# Best params: 11, 5, MAE: 0.23518351189879705

# %%
params['max_depth'] = 11
params['min_child_weight'] = 5

# %%
gridsearch_params = [
    (subsample, colsample)
    for subsample in [i/10. for i in range(7,11)]
    for colsample in [i/10. for i in range(7,11)]
]

# %%
min_mae = float("Inf")
best_params = None
# We start by the largest values and go down to the smallest
for subsample, colsample in reversed(gridsearch_params):
    print("CV with subsample={}, colsample={}".format(
                             subsample,
                             colsample))
    # We update our parameters
    params['subsample'] = subsample
    params['colsample_bytree'] = colsample
    # Run CV
    cv_results = xgb.cv(
        params,
        dtrain,
        num_boost_round=num_boost_round,
        seed=42,
        nfold=5,
        metrics={'mae'},
        early_stopping_rounds=10
    )
    # Update best score
    mean_mae = cv_results['test-mae-mean'].min()
    boost_rounds = cv_results['test-mae-mean'].argmin()
    print("\tMAE {} for {} rounds".format(mean_mae, boost_rounds))
    if mean_mae < min_mae:
        min_mae = mean_mae
        best_params = (subsample,colsample)
print("Best params: {}, {}, MAE: {}".format(best_params[0], best_params[1], min_mae))
frequency = 2500  # Set Frequency To 2500 Hertz
duration = 1000  # Set Duration To 1000 ms == 1 second
winsound.Beep(frequency, duration)
# Out:
# CV with subsample=1.0, colsample=1.0
# [11:52:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:52:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:52:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:52:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:52:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.23067715080663415 for 16 rounds
# CV with subsample=1.0, colsample=0.9
# [11:52:30] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:52:30] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:52:31] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:52:31] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:52:31] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.23247257023694212 for 14 rounds
# CV with subsample=1.0, colsample=0.8
# [11:52:41] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:52:41] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:52:41] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:52:41] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:52:41] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.2331723769890471 for 18 rounds
# CV with subsample=1.0, colsample=0.7
# [11:52:51] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:52:51] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:52:51] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:52:52] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:52:52] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.23433604654262147 for 18 rounds
# CV with subsample=0.9, colsample=1.0
# [11:53:01] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:53:01] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:53:01] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:53:02] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:53:02] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.23173918683119749 for 14 rounds
# CV with subsample=0.9, colsample=0.9
# [11:53:13] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:53:13] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:53:13] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:53:13] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:53:13] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.23356162607663594 for 15 rounds
# CV with subsample=0.9, colsample=0.8
# [11:53:23] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:53:23] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:53:23] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:53:24] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:53:24] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.23543990006792628 for 16 rounds
# CV with subsample=0.9, colsample=0.7
# [11:53:33] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:53:33] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:53:33] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:53:33] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:53:34] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.2363762943420528 for 15 rounds
# CV with subsample=0.8, colsample=1.0
# [11:53:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:53:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:53:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:53:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:53:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.23271989310043115 for 15 rounds
# CV with subsample=0.8, colsample=0.9
# [11:53:53] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:53:53] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:53:53] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:53:53] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:53:53] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.23404706470345849 for 15 rounds
# CV with subsample=0.8, colsample=0.8
# [11:54:03] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:54:03] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:54:03] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:54:03] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:54:03] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.23620870574153355 for 15 rounds
# CV with subsample=0.8, colsample=0.7
# [11:54:12] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:54:12] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:54:12] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:54:12] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:54:12] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.23848312864858534 for 17 rounds
# CV with subsample=0.7, colsample=1.0
# [11:54:21] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:54:21] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:54:21] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:54:21] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:54:22] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.2341393102981487 for 13 rounds
# CV with subsample=0.7, colsample=0.9
# [11:54:31] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:54:31] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:54:31] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:54:31] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:54:31] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.2360546013170476 for 13 rounds
# CV with subsample=0.7, colsample=0.8
# [11:54:40] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:54:40] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:54:40] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:54:40] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:54:41] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.2377932680292966 for 13 rounds
# CV with subsample=0.7, colsample=0.7
# [11:54:49] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:54:49] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:54:49] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:54:49] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:54:49] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.23941700171810623 for 14 rounds
# Best params: 1.0, 1.0, MAE: 0.23067715080663415

# %%
params['subsample'] = 1.
params['colsample_bytree'] = 1.

# %%
# This can take some time…
min_mae = float("Inf")
best_params = None
for eta in [.3, .2, .1, .05, .01, .005]:
    print("CV with eta={}".format(eta))
    # We update our parameters
    params['eta'] = eta
    # Run and time CV
    cv_results = xgb.cv(
            params,
            dtrain,
            num_boost_round=num_boost_round,
            seed=42,
            nfold=5,
            metrics=['mae'],
            early_stopping_rounds=10
          )
    # Update best score
    mean_mae = cv_results['test-mae-mean'].min()
    boost_rounds = cv_results['test-mae-mean'].argmin()
    print("\tMAE {} for {} rounds\n".format(mean_mae, boost_rounds))
    if mean_mae < min_mae:
        min_mae = mean_mae
        best_params = eta
print("Best params: {}, MAE: {}".format(best_params, min_mae))
frequency = 2500  # Set Frequency To 2500 Hertz
duration = 1000  # Set Duration To 1000 ms == 1 second
winsound.Beep(frequency, duration)
# Out:
# CV with eta=0.3
# [11:55:06] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:55:06] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:55:06] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:55:06] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:55:06] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.23067715080663415 for 16 rounds
#
# CV with eta=0.2
# [11:55:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:55:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:55:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:55:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:55:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.22861030140189156 for 39 rounds
#
# CV with eta=0.1
# [11:55:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:55:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:55:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:55:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:55:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.22548728482402774 for 136 rounds
#
# CV with eta=0.05
# [11:56:38] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:56:38] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:56:38] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:56:38] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:56:38] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.22399299545602364 for 460 rounds
#
# CV with eta=0.01
# [11:59:40] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:59:40] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:59:40] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:59:40] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [11:59:41] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.22450207215569873 for 998 rounds
#
# CV with eta=0.005
# [12:06:52] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [12:06:53] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [12:06:53] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [12:06:53] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [12:06:53] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.22689141279873465 for 998 rounds
#
# Best params: 0.05, MAE: 0.22399299545602364

# %%
params['eta'] = .05

# %%
params
# Out:
# {'max_depth': 11,
#  'min_child_weight': 5,
#  'eta': 0.05,
#  'subsample': 1.0,
#  'colsample_bytree': 1.0,
#  'objective': 'reg:linear',
#  'eval_metric': 'mae',
#  'base_score': 0.3407875}

# %%
model = xgb.train(
    params,
    dtrain,
    num_boost_round=num_boost_round,
    evals=[(dtest, "Test")],
    early_stopping_rounds=10
)
# Out:
# [17:00:48] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	Test-mae:0.43771
# [1]	Test-mae:0.42788
# [2]	Test-mae:0.41852
# [3]	Test-mae:0.40958
# [4]	Test-mae:0.40108
# [5]	Test-mae:0.39302
# [6]	Test-mae:0.38530
# [7]	Test-mae:0.37799
# [8]	Test-mae:0.37109
# [9]	Test-mae:0.36446
# [10]	Test-mae:0.35814
# [11]	Test-mae:0.35214
# [12]	Test-mae:0.34641
# [13]	Test-mae:0.34096
# [14]	Test-mae:0.33579
# [15]	Test-mae:0.33085
# [16]	Test-mae:0.32614
# [17]	Test-mae:0.32166
# [18]	Test-mae:0.31741
# [19]	Test-mae:0.31334
# [20]	Test-mae:0.30950
# [21]	Test-mae:0.30582
# [22]	Test-mae:0.30232
# [23]	Test-mae:0.29898
# [24]	Test-mae:0.29575
# [25]	Test-mae:0.29268
# [26]	Test-mae:0.28982
# [27]	Test-mae:0.28706
# [28]	Test-mae:0.28442
# [29]	Test-mae:0.28187
# [30]	Test-mae:0.27947
# [31]	Test-mae:0.27715
# [32]	Test-mae:0.27492
# [33]	Test-mae:0.27289
# [34]	Test-mae:0.27094
# [35]	Test-mae:0.26905
# [36]	Test-mae:0.26730
# [37]	Test-mae:0.26562
# [38]	Test-mae:0.26401
# [39]	Test-mae:0.26249
# [40]	Test-mae:0.26097
# [41]	Test-mae:0.25954
# [42]	Test-mae:0.25821
# [43]	Test-mae:0.25693
# [44]	Test-mae:0.25568
# [45]	Test-mae:0.25454
# [46]	Test-mae:0.25334
# [47]	Test-mae:0.25228
# [48]	Test-mae:0.25129
# [49]	Test-mae:0.25037
# [50]	Test-mae:0.24944
# [51]	Test-mae:0.24855
# [52]	Test-mae:0.24772
# [53]	Test-mae:0.24696
# [54]	Test-mae:0.24618
# [55]	Test-mae:0.24544
# [56]	Test-mae:0.24477
# [57]	Test-mae:0.24413
# [58]	Test-mae:0.24351
# [59]	Test-mae:0.24286
# [60]	Test-mae:0.24230
# [61]	Test-mae:0.24176
# [62]	Test-mae:0.24121
# [63]	Test-mae:0.24070
# [64]	Test-mae:0.24025
# [65]	Test-mae:0.23979
# [66]	Test-mae:0.23935
# [67]	Test-mae:0.23893
# [68]	Test-mae:0.23852
# [69]	Test-mae:0.23809
# [70]	Test-mae:0.23773
# [71]	Test-mae:0.23739
# [72]	Test-mae:0.23708
# [73]	Test-mae:0.23670
# [74]	Test-mae:0.23638
# [75]	Test-mae:0.23614
# [76]	Test-mae:0.23582
# [77]	Test-mae:0.23557
# [78]	Test-mae:0.23528
# [79]	Test-mae:0.23507
# [80]	Test-mae:0.23479
# [81]	Test-mae:0.23449
# [82]	Test-mae:0.23425
# [83]	Test-mae:0.23402
# [84]	Test-mae:0.23383
# [85]	Test-mae:0.23363
# [86]	Test-mae:0.23350
# [87]	Test-mae:0.23337
# [88]	Test-mae:0.23321
# [89]	Test-mae:0.23307
# [90]	Test-mae:0.23293
# [91]	Test-mae:0.23277
# [92]	Test-mae:0.23258
# [93]	Test-mae:0.23242
# [94]	Test-mae:0.23233
# [95]	Test-mae:0.23214
# [96]	Test-mae:0.23202
# [97]	Test-mae:0.23184
# [98]	Test-mae:0.23176
# [99]	Test-mae:0.23166
# [100]	Test-mae:0.23156
# [101]	Test-mae:0.23145
# [102]	Test-mae:0.23142
# [103]	Test-mae:0.23134
# [104]	Test-mae:0.23131
# [105]	Test-mae:0.23126
# [106]	Test-mae:0.23119
# [107]	Test-mae:0.23118
# [108]	Test-mae:0.23109
# [109]	Test-mae:0.23109
# [110]	Test-mae:0.23098
# [111]	Test-mae:0.23093
# [112]	Test-mae:0.23092
# [113]	Test-mae:0.23084
# [114]	Test-mae:0.23079
# [115]	Test-mae:0.23079
# [116]	Test-mae:0.23075
# [117]	Test-mae:0.23073
# [118]	Test-mae:0.23072
# [119]	Test-mae:0.23067
# [120]	Test-mae:0.23061
# [121]	Test-mae:0.23058
# [122]	Test-mae:0.23055
# [123]	Test-mae:0.23055
# [124]	Test-mae:0.23051
# [125]	Test-mae:0.23050
# [126]	Test-mae:0.23047
# [127]	Test-mae:0.23046
# [128]	Test-mae:0.23044
# [129]	Test-mae:0.23040
# [130]	Test-mae:0.23040
# [131]	Test-mae:0.23039
# [132]	Test-mae:0.23037
# [133]	Test-mae:0.23036
# [134]	Test-mae:0.23032
# [135]	Test-mae:0.23032
# [136]	Test-mae:0.23030
# [137]	Test-mae:0.23030
# [138]	Test-mae:0.23028
# [139]	Test-mae:0.23028
# [140]	Test-mae:0.23027
# [141]	Test-mae:0.23024
# [142]	Test-mae:0.23019
# [143]	Test-mae:0.23016
# [144]	Test-mae:0.23013
# [145]	Test-mae:0.23013
# [146]	Test-mae:0.23007
# [147]	Test-mae:0.23005
# [148]	Test-mae:0.23004
# [149]	Test-mae:0.23002
# [150]	Test-mae:0.22997
# [151]	Test-mae:0.22993
# [152]	Test-mae:0.22992
# [153]	Test-mae:0.22992
# [154]	Test-mae:0.22988
# [155]	Test-mae:0.22987
# [156]	Test-mae:0.22982
# [157]	Test-mae:0.22978
# [158]	Test-mae:0.22975
# [159]	Test-mae:0.22973
# [160]	Test-mae:0.22972
# [161]	Test-mae:0.22968
# [162]	Test-mae:0.22967
# [163]	Test-mae:0.22965
# [164]	Test-mae:0.22959
# [165]	Test-mae:0.22957
# [166]	Test-mae:0.22953
# [167]	Test-mae:0.22949
# [168]	Test-mae:0.22943
# [169]	Test-mae:0.22944
# [170]	Test-mae:0.22942
# [171]	Test-mae:0.22938
# [172]	Test-mae:0.22937
# [173]	Test-mae:0.22936
# [174]	Test-mae:0.22935
# [175]	Test-mae:0.22935
# [176]	Test-mae:0.22935
# [177]	Test-mae:0.22934
# [178]	Test-mae:0.22933
# [179]	Test-mae:0.22932
# [180]	Test-mae:0.22932
# [181]	Test-mae:0.22931
# [182]	Test-mae:0.22931
# [183]	Test-mae:0.22929
# [184]	Test-mae:0.22926
# [185]	Test-mae:0.22925
# [186]	Test-mae:0.22920
# [187]	Test-mae:0.22919
# [188]	Test-mae:0.22919
# [189]	Test-mae:0.22918
# [190]	Test-mae:0.22918
# [191]	Test-mae:0.22915
# [192]	Test-mae:0.22913
# [193]	Test-mae:0.22914
# [194]	Test-mae:0.22913
# [195]	Test-mae:0.22911
# [196]	Test-mae:0.22907
# [197]	Test-mae:0.22904
# [198]	Test-mae:0.22905
# [199]	Test-mae:0.22903
# [200]	Test-mae:0.22897
# [201]	Test-mae:0.22897
# [202]	Test-mae:0.22894
# [203]	Test-mae:0.22892
# [204]	Test-mae:0.22891
# [205]	Test-mae:0.22889
# [206]	Test-mae:0.22887
# [207]	Test-mae:0.22884
# [208]	Test-mae:0.22883
# [209]	Test-mae:0.22883
# [210]	Test-mae:0.22883
# [211]	Test-mae:0.22884
# [212]	Test-mae:0.22882
# [213]	Test-mae:0.22880
# [214]	Test-mae:0.22880
# [215]	Test-mae:0.22878
# [216]	Test-mae:0.22878
# [217]	Test-mae:0.22876
# [218]	Test-mae:0.22877
# [219]	Test-mae:0.22877
# [220]	Test-mae:0.22877
# [221]	Test-mae:0.22873
# [222]	Test-mae:0.22870
# [223]	Test-mae:0.22869
# [224]	Test-mae:0.22868
# [225]	Test-mae:0.22866
# [226]	Test-mae:0.22864
# [227]	Test-mae:0.22863
# [228]	Test-mae:0.22860
# [229]	Test-mae:0.22860
# [230]	Test-mae:0.22859
# [231]	Test-mae:0.22860
# [232]	Test-mae:0.22859
# [233]	Test-mae:0.22859
# [234]	Test-mae:0.22859
# [235]	Test-mae:0.22858
# [236]	Test-mae:0.22857
# [237]	Test-mae:0.22855
# [238]	Test-mae:0.22857
# [239]	Test-mae:0.22856
# [240]	Test-mae:0.22856
# [241]	Test-mae:0.22855
# [242]	Test-mae:0.22855
# [243]	Test-mae:0.22856
# [244]	Test-mae:0.22854
# [245]	Test-mae:0.22852
# [246]	Test-mae:0.22853
# [247]	Test-mae:0.22853
# [248]	Test-mae:0.22853
# [249]	Test-mae:0.22852
# [250]	Test-mae:0.22851
# [251]	Test-mae:0.22849
# [252]	Test-mae:0.22848
# [253]	Test-mae:0.22846
# [254]	Test-mae:0.22846
# [255]	Test-mae:0.22842
# [256]	Test-mae:0.22841
# [257]	Test-mae:0.22841
# [258]	Test-mae:0.22842
# [259]	Test-mae:0.22841
# [260]	Test-mae:0.22840
# [261]	Test-mae:0.22840
# [262]	Test-mae:0.22839
# [263]	Test-mae:0.22838
# [264]	Test-mae:0.22838
# [265]	Test-mae:0.22838
# [266]	Test-mae:0.22838
# [267]	Test-mae:0.22838
# [268]	Test-mae:0.22838
# [269]	Test-mae:0.22837
# [270]	Test-mae:0.22837
# [271]	Test-mae:0.22838
# [272]	Test-mae:0.22837
# [273]	Test-mae:0.22837
# [274]	Test-mae:0.22838
# [275]	Test-mae:0.22838
# [276]	Test-mae:0.22838
# [277]	Test-mae:0.22836
# [278]	Test-mae:0.22833
# [279]	Test-mae:0.22832
# [280]	Test-mae:0.22832
# [281]	Test-mae:0.22832
# [282]	Test-mae:0.22834
# [283]	Test-mae:0.22836
# [284]	Test-mae:0.22836
# [285]	Test-mae:0.22835
# [286]	Test-mae:0.22836
# [287]	Test-mae:0.22834
# [288]	Test-mae:0.22833
# [289]	Test-mae:0.22826
# [290]	Test-mae:0.22823
# [291]	Test-mae:0.22822
# [292]	Test-mae:0.22822
# [293]	Test-mae:0.22822
# [294]	Test-mae:0.22822
# [295]	Test-mae:0.22822
# [296]	Test-mae:0.22820
# [297]	Test-mae:0.22818
# [298]	Test-mae:0.22819
# [299]	Test-mae:0.22820
# [300]	Test-mae:0.22819
# [301]	Test-mae:0.22817
# [302]	Test-mae:0.22816
# [303]	Test-mae:0.22812
# [304]	Test-mae:0.22813
# [305]	Test-mae:0.22812
# [306]	Test-mae:0.22813
# [307]	Test-mae:0.22814
# [308]	Test-mae:0.22814
# [309]	Test-mae:0.22811
# [310]	Test-mae:0.22810
# [311]	Test-mae:0.22808
# [312]	Test-mae:0.22806
# [313]	Test-mae:0.22806
# [314]	Test-mae:0.22806
# [315]	Test-mae:0.22806
# [316]	Test-mae:0.22807
# [317]	Test-mae:0.22807
# [318]	Test-mae:0.22807
# [319]	Test-mae:0.22807
# [320]	Test-mae:0.22807
# [321]	Test-mae:0.22808
# [322]	Test-mae:0.22807
# [323]	Test-mae:0.22806
# [324]	Test-mae:0.22806

# %%
um_boost_round = model.best_iteration + 1
best_model = xgb.train(
    params,
    dtrain,
    num_boost_round=num_boost_round,
    evals=[(dtest, "Test")]
)
# Out:
# [17:01:09] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	Test-mae:0.43771
# [1]	Test-mae:0.42788
# [2]	Test-mae:0.41852
# [3]	Test-mae:0.40958
# [4]	Test-mae:0.40108
# [5]	Test-mae:0.39302
# [6]	Test-mae:0.38530
# [7]	Test-mae:0.37799
# [8]	Test-mae:0.37109
# [9]	Test-mae:0.36446
# [10]	Test-mae:0.35814
# [11]	Test-mae:0.35214
# [12]	Test-mae:0.34641
# [13]	Test-mae:0.34096
# [14]	Test-mae:0.33579
# [15]	Test-mae:0.33085
# [16]	Test-mae:0.32614
# [17]	Test-mae:0.32166
# [18]	Test-mae:0.31741
# [19]	Test-mae:0.31334
# [20]	Test-mae:0.30950
# [21]	Test-mae:0.30582
# [22]	Test-mae:0.30232
# [23]	Test-mae:0.29898
# [24]	Test-mae:0.29575
# [25]	Test-mae:0.29268
# [26]	Test-mae:0.28982
# [27]	Test-mae:0.28706
# [28]	Test-mae:0.28442
# [29]	Test-mae:0.28187
# [30]	Test-mae:0.27947
# [31]	Test-mae:0.27715
# [32]	Test-mae:0.27492
# [33]	Test-mae:0.27289
# [34]	Test-mae:0.27094
# [35]	Test-mae:0.26905
# [36]	Test-mae:0.26730
# [37]	Test-mae:0.26562
# [38]	Test-mae:0.26401
# [39]	Test-mae:0.26249
# [40]	Test-mae:0.26097
# [41]	Test-mae:0.25954
# [42]	Test-mae:0.25821
# [43]	Test-mae:0.25693
# [44]	Test-mae:0.25568
# [45]	Test-mae:0.25454
# [46]	Test-mae:0.25334
# [47]	Test-mae:0.25228
# [48]	Test-mae:0.25129
# [49]	Test-mae:0.25037
# [50]	Test-mae:0.24944
# [51]	Test-mae:0.24855
# [52]	Test-mae:0.24772
# [53]	Test-mae:0.24696
# [54]	Test-mae:0.24618
# [55]	Test-mae:0.24544
# [56]	Test-mae:0.24477
# [57]	Test-mae:0.24413
# [58]	Test-mae:0.24351
# [59]	Test-mae:0.24286
# [60]	Test-mae:0.24230
# [61]	Test-mae:0.24176
# [62]	Test-mae:0.24121
# [63]	Test-mae:0.24070
# [64]	Test-mae:0.24025
# [65]	Test-mae:0.23979
# [66]	Test-mae:0.23935
# [67]	Test-mae:0.23893
# [68]	Test-mae:0.23852
# [69]	Test-mae:0.23809
# [70]	Test-mae:0.23773
# [71]	Test-mae:0.23739
# [72]	Test-mae:0.23708
# [73]	Test-mae:0.23670
# [74]	Test-mae:0.23638
# [75]	Test-mae:0.23614
# [76]	Test-mae:0.23582
# [77]	Test-mae:0.23557
# [78]	Test-mae:0.23528
# [79]	Test-mae:0.23507
# [80]	Test-mae:0.23479
# [81]	Test-mae:0.23449
# [82]	Test-mae:0.23425
# [83]	Test-mae:0.23402
# [84]	Test-mae:0.23383
# [85]	Test-mae:0.23363
# [86]	Test-mae:0.23350
# [87]	Test-mae:0.23337
# [88]	Test-mae:0.23321
# [89]	Test-mae:0.23307
# [90]	Test-mae:0.23293
# [91]	Test-mae:0.23277
# [92]	Test-mae:0.23258
# [93]	Test-mae:0.23242
# [94]	Test-mae:0.23233
# [95]	Test-mae:0.23214
# [96]	Test-mae:0.23202
# [97]	Test-mae:0.23184
# [98]	Test-mae:0.23176
# [99]	Test-mae:0.23166
# [100]	Test-mae:0.23156
# [101]	Test-mae:0.23145
# [102]	Test-mae:0.23142
# [103]	Test-mae:0.23134
# [104]	Test-mae:0.23131
# [105]	Test-mae:0.23126
# [106]	Test-mae:0.23119
# [107]	Test-mae:0.23118
# [108]	Test-mae:0.23109
# [109]	Test-mae:0.23109
# [110]	Test-mae:0.23098
# [111]	Test-mae:0.23093
# [112]	Test-mae:0.23092
# [113]	Test-mae:0.23084
# [114]	Test-mae:0.23079
# [115]	Test-mae:0.23079
# [116]	Test-mae:0.23075
# [117]	Test-mae:0.23073
# [118]	Test-mae:0.23072
# [119]	Test-mae:0.23067
# [120]	Test-mae:0.23061
# [121]	Test-mae:0.23058
# [122]	Test-mae:0.23055
# [123]	Test-mae:0.23055
# [124]	Test-mae:0.23051
# [125]	Test-mae:0.23050
# [126]	Test-mae:0.23047
# [127]	Test-mae:0.23046
# [128]	Test-mae:0.23044
# [129]	Test-mae:0.23040
# [130]	Test-mae:0.23040
# [131]	Test-mae:0.23039
# [132]	Test-mae:0.23037
# [133]	Test-mae:0.23036
# [134]	Test-mae:0.23032
# [135]	Test-mae:0.23032
# [136]	Test-mae:0.23030
# [137]	Test-mae:0.23030
# [138]	Test-mae:0.23028
# [139]	Test-mae:0.23028
# [140]	Test-mae:0.23027
# [141]	Test-mae:0.23024
# [142]	Test-mae:0.23019
# [143]	Test-mae:0.23016
# [144]	Test-mae:0.23013
# [145]	Test-mae:0.23013
# [146]	Test-mae:0.23007
# [147]	Test-mae:0.23005
# [148]	Test-mae:0.23004
# [149]	Test-mae:0.23002
# [150]	Test-mae:0.22997
# [151]	Test-mae:0.22993
# [152]	Test-mae:0.22992
# [153]	Test-mae:0.22992
# [154]	Test-mae:0.22988
# [155]	Test-mae:0.22987
# [156]	Test-mae:0.22982
# [157]	Test-mae:0.22978
# [158]	Test-mae:0.22975
# [159]	Test-mae:0.22973
# [160]	Test-mae:0.22972
# [161]	Test-mae:0.22968
# [162]	Test-mae:0.22967
# [163]	Test-mae:0.22965
# [164]	Test-mae:0.22959
# [165]	Test-mae:0.22957
# [166]	Test-mae:0.22953
# [167]	Test-mae:0.22949
# [168]	Test-mae:0.22943
# [169]	Test-mae:0.22944
# [170]	Test-mae:0.22942
# [171]	Test-mae:0.22938
# [172]	Test-mae:0.22937
# [173]	Test-mae:0.22936
# [174]	Test-mae:0.22935
# [175]	Test-mae:0.22935
# [176]	Test-mae:0.22935
# [177]	Test-mae:0.22934
# [178]	Test-mae:0.22933
# [179]	Test-mae:0.22932
# [180]	Test-mae:0.22932
# [181]	Test-mae:0.22931
# [182]	Test-mae:0.22931
# [183]	Test-mae:0.22929
# [184]	Test-mae:0.22926
# [185]	Test-mae:0.22925
# [186]	Test-mae:0.22920
# [187]	Test-mae:0.22919
# [188]	Test-mae:0.22919
# [189]	Test-mae:0.22918
# [190]	Test-mae:0.22918
# [191]	Test-mae:0.22915
# [192]	Test-mae:0.22913
# [193]	Test-mae:0.22914
# [194]	Test-mae:0.22913
# [195]	Test-mae:0.22911
# [196]	Test-mae:0.22907
# [197]	Test-mae:0.22904
# [198]	Test-mae:0.22905
# [199]	Test-mae:0.22903
# [200]	Test-mae:0.22897
# [201]	Test-mae:0.22897
# [202]	Test-mae:0.22894
# [203]	Test-mae:0.22892
# [204]	Test-mae:0.22891
# [205]	Test-mae:0.22889
# [206]	Test-mae:0.22887
# [207]	Test-mae:0.22884
# [208]	Test-mae:0.22883
# [209]	Test-mae:0.22883
# [210]	Test-mae:0.22883
# [211]	Test-mae:0.22884
# [212]	Test-mae:0.22882
# [213]	Test-mae:0.22880
# [214]	Test-mae:0.22880
# [215]	Test-mae:0.22878
# [216]	Test-mae:0.22878
# [217]	Test-mae:0.22876
# [218]	Test-mae:0.22877
# [219]	Test-mae:0.22877
# [220]	Test-mae:0.22877
# [221]	Test-mae:0.22873
# [222]	Test-mae:0.22870
# [223]	Test-mae:0.22869
# [224]	Test-mae:0.22868
# [225]	Test-mae:0.22866
# [226]	Test-mae:0.22864
# [227]	Test-mae:0.22863
# [228]	Test-mae:0.22860
# [229]	Test-mae:0.22860
# [230]	Test-mae:0.22859
# [231]	Test-mae:0.22860
# [232]	Test-mae:0.22859
# [233]	Test-mae:0.22859
# [234]	Test-mae:0.22859
# [235]	Test-mae:0.22858
# [236]	Test-mae:0.22857
# [237]	Test-mae:0.22855
# [238]	Test-mae:0.22857
# [239]	Test-mae:0.22856
# [240]	Test-mae:0.22856
# [241]	Test-mae:0.22855
# [242]	Test-mae:0.22855
# [243]	Test-mae:0.22856
# [244]	Test-mae:0.22854
# [245]	Test-mae:0.22852
# [246]	Test-mae:0.22853
# [247]	Test-mae:0.22853
# [248]	Test-mae:0.22853
# [249]	Test-mae:0.22852
# [250]	Test-mae:0.22851
# [251]	Test-mae:0.22849
# [252]	Test-mae:0.22848
# [253]	Test-mae:0.22846
# [254]	Test-mae:0.22846
# [255]	Test-mae:0.22842
# [256]	Test-mae:0.22841
# [257]	Test-mae:0.22841
# [258]	Test-mae:0.22842
# [259]	Test-mae:0.22841
# [260]	Test-mae:0.22840
# [261]	Test-mae:0.22840
# [262]	Test-mae:0.22839
# [263]	Test-mae:0.22838
# [264]	Test-mae:0.22838
# [265]	Test-mae:0.22838
# [266]	Test-mae:0.22838
# [267]	Test-mae:0.22838
# [268]	Test-mae:0.22838
# [269]	Test-mae:0.22837
# [270]	Test-mae:0.22837
# [271]	Test-mae:0.22838
# [272]	Test-mae:0.22837
# [273]	Test-mae:0.22837
# [274]	Test-mae:0.22838
# [275]	Test-mae:0.22838
# [276]	Test-mae:0.22838
# [277]	Test-mae:0.22836
# [278]	Test-mae:0.22833
# [279]	Test-mae:0.22832
# [280]	Test-mae:0.22832
# [281]	Test-mae:0.22832
# [282]	Test-mae:0.22834
# [283]	Test-mae:0.22836
# [284]	Test-mae:0.22836
# [285]	Test-mae:0.22835
# [286]	Test-mae:0.22836
# [287]	Test-mae:0.22834
# [288]	Test-mae:0.22833
# [289]	Test-mae:0.22826
# [290]	Test-mae:0.22823
# [291]	Test-mae:0.22822
# [292]	Test-mae:0.22822
# [293]	Test-mae:0.22822
# [294]	Test-mae:0.22822
# [295]	Test-mae:0.22822
# [296]	Test-mae:0.22820
# [297]	Test-mae:0.22818
# [298]	Test-mae:0.22819
# [299]	Test-mae:0.22820
# [300]	Test-mae:0.22819
# [301]	Test-mae:0.22817
# [302]	Test-mae:0.22816
# [303]	Test-mae:0.22812
# [304]	Test-mae:0.22813
# [305]	Test-mae:0.22812
# [306]	Test-mae:0.22813
# [307]	Test-mae:0.22814
# [308]	Test-mae:0.22814
# [309]	Test-mae:0.22811
# [310]	Test-mae:0.22810
# [311]	Test-mae:0.22808
# [312]	Test-mae:0.22806
# [313]	Test-mae:0.22806
# [314]	Test-mae:0.22806
# [315]	Test-mae:0.22806
# [316]	Test-mae:0.22807
# [317]	Test-mae:0.22807
# [318]	Test-mae:0.22807
# [319]	Test-mae:0.22807
# [320]	Test-mae:0.22807
# [321]	Test-mae:0.22808
# [322]	Test-mae:0.22807
# [323]	Test-mae:0.22806
# [324]	Test-mae:0.22806
# [325]	Test-mae:0.22803
# [326]	Test-mae:0.22802
# [327]	Test-mae:0.22803
# [328]	Test-mae:0.22801
# [329]	Test-mae:0.22802
# [330]	Test-mae:0.22802
# [331]	Test-mae:0.22802
# [332]	Test-mae:0.22803
# [333]	Test-mae:0.22804
# [334]	Test-mae:0.22804
# [335]	Test-mae:0.22802
# [336]	Test-mae:0.22800
# [337]	Test-mae:0.22799
# [338]	Test-mae:0.22799
# [339]	Test-mae:0.22798
# [340]	Test-mae:0.22797
# [341]	Test-mae:0.22797
# [342]	Test-mae:0.22797
# [343]	Test-mae:0.22797
# [344]	Test-mae:0.22796
# [345]	Test-mae:0.22796
# [346]	Test-mae:0.22797
# [347]	Test-mae:0.22797
# [348]	Test-mae:0.22796
# [349]	Test-mae:0.22796
# [350]	Test-mae:0.22797
# [351]	Test-mae:0.22797
# [352]	Test-mae:0.22799
# [353]	Test-mae:0.22800
# [354]	Test-mae:0.22797
# [355]	Test-mae:0.22797
# [356]	Test-mae:0.22797
# [357]	Test-mae:0.22795
# [358]	Test-mae:0.22795
# [359]	Test-mae:0.22796
# [360]	Test-mae:0.22795
# [361]	Test-mae:0.22793
# [362]	Test-mae:0.22794
# [363]	Test-mae:0.22793
# [364]	Test-mae:0.22795
# [365]	Test-mae:0.22796
# [366]	Test-mae:0.22794
# [367]	Test-mae:0.22793
# [368]	Test-mae:0.22795
# [369]	Test-mae:0.22794
# [370]	Test-mae:0.22795
# [371]	Test-mae:0.22795
# [372]	Test-mae:0.22796
# [373]	Test-mae:0.22795
# [374]	Test-mae:0.22796
# [375]	Test-mae:0.22796
# [376]	Test-mae:0.22796
# [377]	Test-mae:0.22795
# [378]	Test-mae:0.22794
# [379]	Test-mae:0.22795
# [380]	Test-mae:0.22795
# [381]	Test-mae:0.22795
# [382]	Test-mae:0.22795
# [383]	Test-mae:0.22794
# [384]	Test-mae:0.22792
# [385]	Test-mae:0.22792
# [386]	Test-mae:0.22793
# [387]	Test-mae:0.22793
# [388]	Test-mae:0.22793
# [389]	Test-mae:0.22793
# [390]	Test-mae:0.22791
# [391]	Test-mae:0.22789
# [392]	Test-mae:0.22789
# [393]	Test-mae:0.22788
# [394]	Test-mae:0.22788
# [395]	Test-mae:0.22788
# [396]	Test-mae:0.22785
# [397]	Test-mae:0.22786
# [398]	Test-mae:0.22786
# [399]	Test-mae:0.22785
# [400]	Test-mae:0.22785
# [401]	Test-mae:0.22784
# [402]	Test-mae:0.22786
# [403]	Test-mae:0.22786
# [404]	Test-mae:0.22787
# [405]	Test-mae:0.22786
# [406]	Test-mae:0.22786
# [407]	Test-mae:0.22787
# [408]	Test-mae:0.22786
# [409]	Test-mae:0.22785
# [410]	Test-mae:0.22785
# [411]	Test-mae:0.22784
# [412]	Test-mae:0.22782
# [413]	Test-mae:0.22782
# [414]	Test-mae:0.22782
# [415]	Test-mae:0.22780
# [416]	Test-mae:0.22780
# [417]	Test-mae:0.22781
# [418]	Test-mae:0.22781
# [419]	Test-mae:0.22783
# [420]	Test-mae:0.22782
# [421]	Test-mae:0.22783
# [422]	Test-mae:0.22783
# [423]	Test-mae:0.22781
# [424]	Test-mae:0.22780
# [425]	Test-mae:0.22781
# [426]	Test-mae:0.22780
# [427]	Test-mae:0.22780
# [428]	Test-mae:0.22780
# [429]	Test-mae:0.22778
# [430]	Test-mae:0.22778
# [431]	Test-mae:0.22779
# [432]	Test-mae:0.22779
# [433]	Test-mae:0.22779
# [434]	Test-mae:0.22776
# [435]	Test-mae:0.22772
# [436]	Test-mae:0.22773
# [437]	Test-mae:0.22771
# [438]	Test-mae:0.22771
# [439]	Test-mae:0.22770
# [440]	Test-mae:0.22769
# [441]	Test-mae:0.22768
# [442]	Test-mae:0.22767
# [443]	Test-mae:0.22768
# [444]	Test-mae:0.22767
# [445]	Test-mae:0.22765
# [446]	Test-mae:0.22765
# [447]	Test-mae:0.22765
# [448]	Test-mae:0.22765
# [449]	Test-mae:0.22764
# [450]	Test-mae:0.22764
# [451]	Test-mae:0.22764
# [452]	Test-mae:0.22764
# [453]	Test-mae:0.22762
# [454]	Test-mae:0.22759
# [455]	Test-mae:0.22759
# [456]	Test-mae:0.22759
# [457]	Test-mae:0.22759
# [458]	Test-mae:0.22758
# [459]	Test-mae:0.22758
# [460]	Test-mae:0.22757
# [461]	Test-mae:0.22757
# [462]	Test-mae:0.22757
# [463]	Test-mae:0.22757
# [464]	Test-mae:0.22757
# [465]	Test-mae:0.22755
# [466]	Test-mae:0.22755
# [467]	Test-mae:0.22755
# [468]	Test-mae:0.22754
# [469]	Test-mae:0.22755
# [470]	Test-mae:0.22754
# [471]	Test-mae:0.22754
# [472]	Test-mae:0.22753
# [473]	Test-mae:0.22752
# [474]	Test-mae:0.22753
# [475]	Test-mae:0.22753
# [476]	Test-mae:0.22753
# [477]	Test-mae:0.22752
# [478]	Test-mae:0.22752
# [479]	Test-mae:0.22753
# [480]	Test-mae:0.22753
# [481]	Test-mae:0.22751
# [482]	Test-mae:0.22750
# [483]	Test-mae:0.22748
# [484]	Test-mae:0.22746
# [485]	Test-mae:0.22743
# [486]	Test-mae:0.22742
# [487]	Test-mae:0.22741
# [488]	Test-mae:0.22742
# [489]	Test-mae:0.22741
# [490]	Test-mae:0.22742
# [491]	Test-mae:0.22741
# [492]	Test-mae:0.22740
# [493]	Test-mae:0.22740
# [494]	Test-mae:0.22740
# [495]	Test-mae:0.22741
# [496]	Test-mae:0.22741
# [497]	Test-mae:0.22740
# [498]	Test-mae:0.22740
# [499]	Test-mae:0.22739
# [500]	Test-mae:0.22739
# [501]	Test-mae:0.22738
# [502]	Test-mae:0.22738
# [503]	Test-mae:0.22738
# [504]	Test-mae:0.22736
# [505]	Test-mae:0.22735
# [506]	Test-mae:0.22736
# [507]	Test-mae:0.22736
# [508]	Test-mae:0.22737
# [509]	Test-mae:0.22734
# [510]	Test-mae:0.22734
# [511]	Test-mae:0.22734
# [512]	Test-mae:0.22735
# [513]	Test-mae:0.22735
# [514]	Test-mae:0.22734
# [515]	Test-mae:0.22733
# [516]	Test-mae:0.22734
# [517]	Test-mae:0.22734
# [518]	Test-mae:0.22734
# [519]	Test-mae:0.22734
# [520]	Test-mae:0.22734
# [521]	Test-mae:0.22735
# [522]	Test-mae:0.22736
# [523]	Test-mae:0.22736
# [524]	Test-mae:0.22735
# [525]	Test-mae:0.22735
# [526]	Test-mae:0.22734
# [527]	Test-mae:0.22735
# [528]	Test-mae:0.22735
# [529]	Test-mae:0.22733
# [530]	Test-mae:0.22733
# [531]	Test-mae:0.22732
# [532]	Test-mae:0.22732
# [533]	Test-mae:0.22732
# [534]	Test-mae:0.22731
# [535]	Test-mae:0.22731
# [536]	Test-mae:0.22730
# [537]	Test-mae:0.22729
# [538]	Test-mae:0.22730
# [539]	Test-mae:0.22730
# [540]	Test-mae:0.22730
# [541]	Test-mae:0.22731
# [542]	Test-mae:0.22730
# [543]	Test-mae:0.22730
# [544]	Test-mae:0.22730
# [545]	Test-mae:0.22730
# [546]	Test-mae:0.22731
# [547]	Test-mae:0.22731
# [548]	Test-mae:0.22730
# [549]	Test-mae:0.22730
# [550]	Test-mae:0.22730
# [551]	Test-mae:0.22730
# [552]	Test-mae:0.22730
# [553]	Test-mae:0.22728
# [554]	Test-mae:0.22728
# [555]	Test-mae:0.22728
# [556]	Test-mae:0.22728
# [557]	Test-mae:0.22728
# [558]	Test-mae:0.22728
# [559]	Test-mae:0.22728
# [560]	Test-mae:0.22728
# [561]	Test-mae:0.22726
# [562]	Test-mae:0.22724
# [563]	Test-mae:0.22725
# [564]	Test-mae:0.22725
# [565]	Test-mae:0.22727
# [566]	Test-mae:0.22726
# [567]	Test-mae:0.22726
# [568]	Test-mae:0.22726
# [569]	Test-mae:0.22725
# [570]	Test-mae:0.22725
# [571]	Test-mae:0.22725
# [572]	Test-mae:0.22726
# [573]	Test-mae:0.22726
# [574]	Test-mae:0.22726
# [575]	Test-mae:0.22726
# [576]	Test-mae:0.22726
# [577]	Test-mae:0.22726
# [578]	Test-mae:0.22726
# [579]	Test-mae:0.22725
# [580]	Test-mae:0.22725
# [581]	Test-mae:0.22725
# [582]	Test-mae:0.22724
# [583]	Test-mae:0.22724
# [584]	Test-mae:0.22724
# [585]	Test-mae:0.22724
# [586]	Test-mae:0.22723
# [587]	Test-mae:0.22723
# [588]	Test-mae:0.22723
# [589]	Test-mae:0.22725
# [590]	Test-mae:0.22724
# [591]	Test-mae:0.22724
# [592]	Test-mae:0.22724
# [593]	Test-mae:0.22723
# [594]	Test-mae:0.22724
# [595]	Test-mae:0.22724
# [596]	Test-mae:0.22724
# [597]	Test-mae:0.22723
# [598]	Test-mae:0.22723
# [599]	Test-mae:0.22720
# [600]	Test-mae:0.22721
# [601]	Test-mae:0.22721
# [602]	Test-mae:0.22720
# [603]	Test-mae:0.22720
# [604]	Test-mae:0.22718
# [605]	Test-mae:0.22719
# [606]	Test-mae:0.22720
# [607]	Test-mae:0.22720
# [608]	Test-mae:0.22721
# [609]	Test-mae:0.22721
# [610]	Test-mae:0.22721
# [611]	Test-mae:0.22723
# [612]	Test-mae:0.22721
# [613]	Test-mae:0.22722
# [614]	Test-mae:0.22721
# [615]	Test-mae:0.22719
# [616]	Test-mae:0.22718
# [617]	Test-mae:0.22718
# [618]	Test-mae:0.22717
# [619]	Test-mae:0.22717
# [620]	Test-mae:0.22717
# [621]	Test-mae:0.22717
# [622]	Test-mae:0.22717
# [623]	Test-mae:0.22715
# [624]	Test-mae:0.22715
# [625]	Test-mae:0.22716
# [626]	Test-mae:0.22715
# [627]	Test-mae:0.22715
# [628]	Test-mae:0.22715
# [629]	Test-mae:0.22715
# [630]	Test-mae:0.22715
# [631]	Test-mae:0.22715
# [632]	Test-mae:0.22713
# [633]	Test-mae:0.22711
# [634]	Test-mae:0.22711
# [635]	Test-mae:0.22711
# [636]	Test-mae:0.22711
# [637]	Test-mae:0.22711
# [638]	Test-mae:0.22710
# [639]	Test-mae:0.22711
# [640]	Test-mae:0.22711
# [641]	Test-mae:0.22710
# [642]	Test-mae:0.22710
# [643]	Test-mae:0.22710
# [644]	Test-mae:0.22711
# [645]	Test-mae:0.22711
# [646]	Test-mae:0.22711
# [647]	Test-mae:0.22711
# [648]	Test-mae:0.22712
# [649]	Test-mae:0.22712
# [650]	Test-mae:0.22711
# [651]	Test-mae:0.22710
# [652]	Test-mae:0.22706
# [653]	Test-mae:0.22706
# [654]	Test-mae:0.22705
# [655]	Test-mae:0.22705
# [656]	Test-mae:0.22705
# [657]	Test-mae:0.22705
# [658]	Test-mae:0.22705
# [659]	Test-mae:0.22704
# [660]	Test-mae:0.22703
# [661]	Test-mae:0.22703
# [662]	Test-mae:0.22704
# [663]	Test-mae:0.22705
# [664]	Test-mae:0.22704
# [665]	Test-mae:0.22704
# [666]	Test-mae:0.22704
# [667]	Test-mae:0.22704
# [668]	Test-mae:0.22704
# [669]	Test-mae:0.22704
# [670]	Test-mae:0.22704
# [671]	Test-mae:0.22705
# [672]	Test-mae:0.22705
# [673]	Test-mae:0.22704
# [674]	Test-mae:0.22704
# [675]	Test-mae:0.22703
# [676]	Test-mae:0.22703
# [677]	Test-mae:0.22703
# [678]	Test-mae:0.22703
# [679]	Test-mae:0.22702
# [680]	Test-mae:0.22701
# [681]	Test-mae:0.22700
# [682]	Test-mae:0.22699
# [683]	Test-mae:0.22699
# [684]	Test-mae:0.22698
# [685]	Test-mae:0.22697
# [686]	Test-mae:0.22698
# [687]	Test-mae:0.22698
# [688]	Test-mae:0.22697
# [689]	Test-mae:0.22697
# [690]	Test-mae:0.22697
# [691]	Test-mae:0.22697
# [692]	Test-mae:0.22697
# [693]	Test-mae:0.22696
# [694]	Test-mae:0.22697
# [695]	Test-mae:0.22695
# [696]	Test-mae:0.22695
# [697]	Test-mae:0.22696
# [698]	Test-mae:0.22696
# [699]	Test-mae:0.22695
# [700]	Test-mae:0.22695
# [701]	Test-mae:0.22694
# [702]	Test-mae:0.22695
# [703]	Test-mae:0.22694
# [704]	Test-mae:0.22694
# [705]	Test-mae:0.22693
# [706]	Test-mae:0.22693
# [707]	Test-mae:0.22693
# [708]	Test-mae:0.22693
# [709]	Test-mae:0.22694
# [710]	Test-mae:0.22694
# [711]	Test-mae:0.22693
# [712]	Test-mae:0.22693
# [713]	Test-mae:0.22693
# [714]	Test-mae:0.22693
# [715]	Test-mae:0.22691
# [716]	Test-mae:0.22690
# [717]	Test-mae:0.22690
# [718]	Test-mae:0.22689
# [719]	Test-mae:0.22689
# [720]	Test-mae:0.22689
# [721]	Test-mae:0.22689
# [722]	Test-mae:0.22688
# [723]	Test-mae:0.22688
# [724]	Test-mae:0.22688
# [725]	Test-mae:0.22687
# [726]	Test-mae:0.22686
# [727]	Test-mae:0.22685
# [728]	Test-mae:0.22683
# [729]	Test-mae:0.22682
# [730]	Test-mae:0.22683
# [731]	Test-mae:0.22684
# [732]	Test-mae:0.22684
# [733]	Test-mae:0.22684
# [734]	Test-mae:0.22683
# [735]	Test-mae:0.22683
# [736]	Test-mae:0.22680
# [737]	Test-mae:0.22680
# [738]	Test-mae:0.22680
# [739]	Test-mae:0.22679
# [740]	Test-mae:0.22679
# [741]	Test-mae:0.22678
# [742]	Test-mae:0.22678
# [743]	Test-mae:0.22679
# [744]	Test-mae:0.22678
# [745]	Test-mae:0.22678
# [746]	Test-mae:0.22677
# [747]	Test-mae:0.22676
# [748]	Test-mae:0.22676
# [749]	Test-mae:0.22675
# [750]	Test-mae:0.22676
# [751]	Test-mae:0.22675
# [752]	Test-mae:0.22675
# [753]	Test-mae:0.22674
# [754]	Test-mae:0.22674
# [755]	Test-mae:0.22673
# [756]	Test-mae:0.22673
# [757]	Test-mae:0.22670
# [758]	Test-mae:0.22669
# [759]	Test-mae:0.22667
# [760]	Test-mae:0.22667
# [761]	Test-mae:0.22666
# [762]	Test-mae:0.22664
# [763]	Test-mae:0.22664
# [764]	Test-mae:0.22665
# [765]	Test-mae:0.22666
# [766]	Test-mae:0.22666
# [767]	Test-mae:0.22666
# [768]	Test-mae:0.22665
# [769]	Test-mae:0.22664
# [770]	Test-mae:0.22664
# [771]	Test-mae:0.22664
# [772]	Test-mae:0.22664
# [773]	Test-mae:0.22664
# [774]	Test-mae:0.22663
# [775]	Test-mae:0.22663
# [776]	Test-mae:0.22663
# [777]	Test-mae:0.22663
# [778]	Test-mae:0.22662
# [779]	Test-mae:0.22663
# [780]	Test-mae:0.22663
# [781]	Test-mae:0.22664
# [782]	Test-mae:0.22663
# [783]	Test-mae:0.22663
# [784]	Test-mae:0.22662
# [785]	Test-mae:0.22663
# [786]	Test-mae:0.22663
# [787]	Test-mae:0.22663
# [788]	Test-mae:0.22661
# [789]	Test-mae:0.22661
# [790]	Test-mae:0.22660
# [791]	Test-mae:0.22660
# [792]	Test-mae:0.22660
# [793]	Test-mae:0.22659
# [794]	Test-mae:0.22660
# [795]	Test-mae:0.22660
# [796]	Test-mae:0.22660
# [797]	Test-mae:0.22659
# [798]	Test-mae:0.22657
# [799]	Test-mae:0.22658
# [800]	Test-mae:0.22658
# [801]	Test-mae:0.22658
# [802]	Test-mae:0.22658
# [803]	Test-mae:0.22657
# [804]	Test-mae:0.22656
# [805]	Test-mae:0.22654
# [806]	Test-mae:0.22654
# [807]	Test-mae:0.22655
# [808]	Test-mae:0.22656
# [809]	Test-mae:0.22655
# [810]	Test-mae:0.22653
# [811]	Test-mae:0.22652
# [812]	Test-mae:0.22652
# [813]	Test-mae:0.22650
# [814]	Test-mae:0.22650
# [815]	Test-mae:0.22649
# [816]	Test-mae:0.22650
# [817]	Test-mae:0.22649
# [818]	Test-mae:0.22648
# [819]	Test-mae:0.22647
# [820]	Test-mae:0.22647
# [821]	Test-mae:0.22646
# [822]	Test-mae:0.22645
# [823]	Test-mae:0.22645
# [824]	Test-mae:0.22644
# [825]	Test-mae:0.22644
# [826]	Test-mae:0.22644
# [827]	Test-mae:0.22645
# [828]	Test-mae:0.22645
# [829]	Test-mae:0.22645
# [830]	Test-mae:0.22644
# [831]	Test-mae:0.22645
# [832]	Test-mae:0.22644
# [833]	Test-mae:0.22644
# [834]	Test-mae:0.22642
# [835]	Test-mae:0.22643
# [836]	Test-mae:0.22643
# [837]	Test-mae:0.22643
# [838]	Test-mae:0.22643
# [839]	Test-mae:0.22641
# [840]	Test-mae:0.22641
# [841]	Test-mae:0.22640
# [842]	Test-mae:0.22641
# [843]	Test-mae:0.22642
# [844]	Test-mae:0.22641
# [845]	Test-mae:0.22642
# [846]	Test-mae:0.22642
# [847]	Test-mae:0.22642
# [848]	Test-mae:0.22643
# [849]	Test-mae:0.22643
# [850]	Test-mae:0.22643
# [851]	Test-mae:0.22643
# [852]	Test-mae:0.22642
# [853]	Test-mae:0.22643
# [854]	Test-mae:0.22641
# [855]	Test-mae:0.22641
# [856]	Test-mae:0.22641
# [857]	Test-mae:0.22641
# [858]	Test-mae:0.22641
# [859]	Test-mae:0.22641
# [860]	Test-mae:0.22641
# [861]	Test-mae:0.22641
# [862]	Test-mae:0.22642
# [863]	Test-mae:0.22642
# [864]	Test-mae:0.22642
# [865]	Test-mae:0.22642
# [866]	Test-mae:0.22642
# [867]	Test-mae:0.22642
# [868]	Test-mae:0.22643
# [869]	Test-mae:0.22643
# [870]	Test-mae:0.22644
# [871]	Test-mae:0.22643
# [872]	Test-mae:0.22643
# [873]	Test-mae:0.22644
# [874]	Test-mae:0.22644
# [875]	Test-mae:0.22643
# [876]	Test-mae:0.22639
# [877]	Test-mae:0.22639
# [878]	Test-mae:0.22638
# [879]	Test-mae:0.22638
# [880]	Test-mae:0.22638
# [881]	Test-mae:0.22639
# [882]	Test-mae:0.22639
# [883]	Test-mae:0.22638
# [884]	Test-mae:0.22638
# [885]	Test-mae:0.22637
# [886]	Test-mae:0.22636
# [887]	Test-mae:0.22637
# [888]	Test-mae:0.22636
# [889]	Test-mae:0.22636
# [890]	Test-mae:0.22636
# [891]	Test-mae:0.22635
# [892]	Test-mae:0.22634
# [893]	Test-mae:0.22635
# [894]	Test-mae:0.22634
# [895]	Test-mae:0.22634
# [896]	Test-mae:0.22633
# [897]	Test-mae:0.22631
# [898]	Test-mae:0.22630
# [899]	Test-mae:0.22629
# [900]	Test-mae:0.22626
# [901]	Test-mae:0.22626
# [902]	Test-mae:0.22626
# [903]	Test-mae:0.22625
# [904]	Test-mae:0.22624
# [905]	Test-mae:0.22623
# [906]	Test-mae:0.22622
# [907]	Test-mae:0.22621
# [908]	Test-mae:0.22620
# [909]	Test-mae:0.22619
# [910]	Test-mae:0.22619
# [911]	Test-mae:0.22618
# [912]	Test-mae:0.22618
# [913]	Test-mae:0.22618
# [914]	Test-mae:0.22619
# [915]	Test-mae:0.22619
# [916]	Test-mae:0.22621
# [917]	Test-mae:0.22621
# [918]	Test-mae:0.22621
# [919]	Test-mae:0.22621
# [920]	Test-mae:0.22621
# [921]	Test-mae:0.22622
# [922]	Test-mae:0.22620
# [923]	Test-mae:0.22620
# [924]	Test-mae:0.22620
# [925]	Test-mae:0.22617
# [926]	Test-mae:0.22617
# [927]	Test-mae:0.22617
# [928]	Test-mae:0.22618
# [929]	Test-mae:0.22616
# [930]	Test-mae:0.22616
# [931]	Test-mae:0.22615
# [932]	Test-mae:0.22614
# [933]	Test-mae:0.22614
# [934]	Test-mae:0.22613
# [935]	Test-mae:0.22613
# [936]	Test-mae:0.22613
# [937]	Test-mae:0.22613
# [938]	Test-mae:0.22614
# [939]	Test-mae:0.22613
# [940]	Test-mae:0.22613
# [941]	Test-mae:0.22613
# [942]	Test-mae:0.22612
# [943]	Test-mae:0.22612
# [944]	Test-mae:0.22613
# [945]	Test-mae:0.22614
# [946]	Test-mae:0.22614
# [947]	Test-mae:0.22615
# [948]	Test-mae:0.22614
# [949]	Test-mae:0.22615
# [950]	Test-mae:0.22615
# [951]	Test-mae:0.22614
# [952]	Test-mae:0.22615
# [953]	Test-mae:0.22615
# [954]	Test-mae:0.22615
# [955]	Test-mae:0.22615
# [956]	Test-mae:0.22615
# [957]	Test-mae:0.22614
# [958]	Test-mae:0.22614
# [959]	Test-mae:0.22614
# [960]	Test-mae:0.22613
# [961]	Test-mae:0.22613
# [962]	Test-mae:0.22613
# [963]	Test-mae:0.22613
# [964]	Test-mae:0.22612
# [965]	Test-mae:0.22612
# [966]	Test-mae:0.22612
# [967]	Test-mae:0.22611
# [968]	Test-mae:0.22611
# [969]	Test-mae:0.22610
# [970]	Test-mae:0.22609
# [971]	Test-mae:0.22609
# [972]	Test-mae:0.22609
# [973]	Test-mae:0.22609
# [974]	Test-mae:0.22609
# [975]	Test-mae:0.22609
# [976]	Test-mae:0.22609
# [977]	Test-mae:0.22609
# [978]	Test-mae:0.22609
# [979]	Test-mae:0.22607
# [980]	Test-mae:0.22607
# [981]	Test-mae:0.22605
# [982]	Test-mae:0.22605
# [983]	Test-mae:0.22604
# [984]	Test-mae:0.22603
# [985]	Test-mae:0.22603
# [986]	Test-mae:0.22603
# [987]	Test-mae:0.22603
# [988]	Test-mae:0.22602
# [989]	Test-mae:0.22602
# [990]	Test-mae:0.22601
# [991]	Test-mae:0.22602
# [992]	Test-mae:0.22602
# [993]	Test-mae:0.22603
# [994]	Test-mae:0.22603
# [995]	Test-mae:0.22602
# [996]	Test-mae:0.22602
# [997]	Test-mae:0.22602
# [998]	Test-mae:0.22602

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(best_model.predict(dtest), y_test2)
# Out:
# 0.22602249246174633

# %% [markdown]
# ### Guardado del modelo y predicciones.
# -------------------------------------------------------------------------------------------------------------------------------

# %%
best_model.save_model("SHAP-20%-10V.model")

# %%
loaded_model = xgb.Booster()
loaded_model.load_model("SHAP-20%-10V.model")
# And use it for predictions.
# Out:
# [17:02:06] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.

# %%
Prediccion = loaded_model.predict(dtest)

# %%
Prediccion.min()
# Out:
# -0.20984684

# %%
Prediccion.max()
# Out:
# 1.1657025

# %%
from sklearn.metrics import confusion_matrix, f1_score, precision_score, recall_score, accuracy_score, classification_report, roc_curve, auc, roc_auc_score, ConfusionMatrixDisplay

# %%
testing_list =[]
for i in  np.linspace(0.1,0.9,9):
    d = {}
    y_p = Prediccion >= i
    print("Threshold:",i)
    cm = confusion_matrix(y_test2,y_p)
    d["th"] = i
    d["F1"] = np.round(f1_score(y_test2,y_p),2)
    d["Prec"] = np.round(precision_score(y_test2,y_p),2)
    d["Rec"] = np.round(recall_score(y_test2,y_p),2)
    d["Acc"] = np.round(accuracy_score(y_test2,y_p),2)
    d["RocAuc"] = np.round(roc_auc_score(y_test2,y_p),2)
    testing_list.append(d)
# Out:
# Threshold: 0.1
# Threshold: 0.2
# Threshold: 0.30000000000000004
# Threshold: 0.4
# Threshold: 0.5
# Threshold: 0.6
# Threshold: 0.7000000000000001
# Threshold: 0.8
# Threshold: 0.9

# %% [markdown]
# # Metricas para cada umbral.
# - th: umbral
# -------------------------------------------------------------------------------------------------------------------------------

# %%
testing_metrics_pd = pd.DataFrame(testing_list)
testing_metrics_pd
# Out:
#     th    F1  Prec   Rec   Acc  RocAuc
# 0  0.1  0.68  0.52  0.96  0.69    0.76
# 1  0.2  0.73  0.61  0.91  0.77    0.81
# 2  0.3  0.76  0.68  0.86  0.81    0.82
# 3  0.4  0.77  0.74  0.80  0.84    0.83
# 4  0.5  0.76  0.79  0.73  0.84    0.81
# 5  0.6  0.73  0.83  0.65  0.84    0.79
# 6  0.7  0.68  0.87  0.56  0.82    0.76
# 7  0.8  0.59  0.90  0.44  0.80    0.71
# 8  0.9  0.44  0.93  0.29  0.75    0.64

# %%
print(testing_metrics_pd.to_latex(index=False))
# Out:
# \begin{tabular}{rrrrrr}
# \toprule
#  th &   F1 &  Prec &  Rec &  Acc &  RocAuc \\
# \midrule
# 0.1 & 0.68 &  0.52 & 0.96 & 0.69 &    0.76 \\
# 0.2 & 0.73 &  0.61 & 0.91 & 0.77 &    0.81 \\
# 0.3 & 0.76 &  0.68 & 0.86 & 0.81 &    0.82 \\
# 0.4 & 0.77 &  0.74 & 0.80 & 0.84 &    0.83 \\
# 0.5 & 0.76 &  0.79 & 0.73 & 0.84 &    0.81 \\
# 0.6 & 0.73 &  0.83 & 0.65 & 0.84 &    0.79 \\
# 0.7 & 0.68 &  0.87 & 0.56 & 0.82 &    0.76 \\
# 0.8 & 0.59 &  0.90 & 0.44 & 0.80 &    0.71 \\
# 0.9 & 0.44 &  0.93 & 0.29 & 0.75 &    0.64 \\
# \bottomrule
# \end{tabular}

# %%
fpr, tpr, ths = roc_curve(y_test2,  Prediccion)
auc_ = auc(fpr, tpr)
plt.plot(fpr,tpr, label='ROC curve (area = %.2f)' %auc_)
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.legend()
plt.grid()
plt.show()

# %%
for i in  np.linspace(0.1,0.9,9):
    print(i)
    y_p = Prediccion >= i
    print(classification_report(y_test2, y_p))
    f1 = f1_score(y_test2, y_p)
    prec = precision_score(y_test2, y_p)
    rec = recall_score(y_test2, y_p)
    acc = accuracy_score(y_test2, y_p)
    cm=confusion_matrix(y_test2, y_p)
    print("Matriz de confusión: ")
    print(cm)
    print("----------------------------------------------------------")
    print("F1: %.2f" %f1 , " -- prec: %.2f" %prec, " -- recall: %.2f" %rec, " -- acc: %.2f" %acc)
    print("----------------------------------------------------------")
# Out:
# 0.1
#               precision    recall  f1-score   support
#
#            0       0.97      0.55      0.70     13263
#            1       0.52      0.96      0.68      6737
#
#     accuracy                           0.69     20000
#    macro avg       0.74      0.76      0.69     20000
# weighted avg       0.82      0.69      0.69     20000
#
# Matriz de confusión:
# [[7307 5956]
#  [ 260 6477]]
# ----------------------------------------------------------
# F1: 0.68  -- prec: 0.52  -- recall: 0.96  -- acc: 0.69
# ----------------------------------------------------------
# 0.2
#               precision    recall  f1-score   support
#
#            0       0.94      0.70      0.80     13263
#            1       0.61      0.91      0.73      6737
#
#     accuracy                           0.77     20000
#    macro avg       0.77      0.81      0.77     20000
# weighted avg       0.83      0.77      0.78     20000
#
# Matriz de confusión:
# [[9302 3961]
#  [ 591 6146]]
# ----------------------------------------------------------
# F1: 0.73  -- prec: 0.61  -- recall: 0.91  -- acc: 0.77
# ----------------------------------------------------------
# 0.30000000000000004
#               precision    recall  f1-score   support
#
#            0       0.92      0.79      0.85     13263
#            1       0.68      0.86      0.76      6737
#
#     accuracy                           0.81     20000
#    macro avg       0.80      0.82      0.80     20000
# weighted avg       0.84      0.81      0.82     20000
#
# Matriz de confusión:
# [[10491  2772]
#  [  958  5779]]
# ----------------------------------------------------------
# F1: 0.76  -- prec: 0.68  -- recall: 0.86  -- acc: 0.81
# ----------------------------------------------------------
# 0.4
#               precision    recall  f1-score   support
#
#            0       0.89      0.86      0.87     13263
#            1       0.74      0.80      0.77      6737
#
#     accuracy                           0.84     20000
#    macro avg       0.82      0.83      0.82     20000
# weighted avg       0.84      0.84      0.84     20000
#
# Matriz de confusión:
# [[11344  1919]
#  [ 1335  5402]]
# ----------------------------------------------------------
# F1: 0.77  -- prec: 0.74  -- recall: 0.80  -- acc: 0.84
# ----------------------------------------------------------
# 0.5
#               precision    recall  f1-score   support
#
#            0       0.87      0.90      0.88     13263
#            1       0.79      0.73      0.76      6737
#
#     accuracy                           0.84     20000
#    macro avg       0.83      0.81      0.82     20000
# weighted avg       0.84      0.84      0.84     20000
#
# Matriz de confusión:
# [[11932  1331]
#  [ 1819  4918]]
# ----------------------------------------------------------
# F1: 0.76  -- prec: 0.79  -- recall: 0.73  -- acc: 0.84
# ----------------------------------------------------------
# 0.6
#               precision    recall  f1-score   support
#
#            0       0.84      0.93      0.88     13263
#            1       0.83      0.65      0.73      6737
#
#     accuracy                           0.84     20000
#    macro avg       0.83      0.79      0.81     20000
# weighted avg       0.84      0.84      0.83     20000
#
# Matriz de confusión:
# [[12348   915]
#  [ 2345  4392]]
# ----------------------------------------------------------
# F1: 0.73  -- prec: 0.83  -- recall: 0.65  -- acc: 0.84
# ----------------------------------------------------------
# 0.7000000000000001
#               precision    recall  f1-score   support
#
#            0       0.81      0.96      0.88     13263
#            1       0.87      0.56      0.68      6737
#
#     accuracy                           0.82     20000
#    macro avg       0.84      0.76      0.78     20000
# weighted avg       0.83      0.82      0.81     20000
#
# Matriz de confusión:
# [[12692   571]
#  [ 2952  3785]]
# ----------------------------------------------------------
# F1: 0.68  -- prec: 0.87  -- recall: 0.56  -- acc: 0.82
# ----------------------------------------------------------
# 0.8
#               precision    recall  f1-score   support
#
#            0       0.77      0.98      0.86     13263
#            1       0.90      0.44      0.59      6737
#
#     accuracy                           0.80     20000
#    macro avg       0.84      0.71      0.73     20000
# weighted avg       0.82      0.80      0.77     20000
#
# Matriz de confusión:
# [[12945   318]
#  [ 3759  2978]]
# ----------------------------------------------------------
# F1: 0.59  -- prec: 0.90  -- recall: 0.44  -- acc: 0.80
# ----------------------------------------------------------
# 0.9
#               precision    recall  f1-score   support
#
#            0       0.73      0.99      0.84     13263
#            1       0.93      0.29      0.44      6737
#
#     accuracy                           0.75     20000
#    macro avg       0.83      0.64      0.64     20000
# weighted avg       0.80      0.75      0.71     20000
#
# Matriz de confusión:
# [[13127   136]
#  [ 4808  1929]]
# ----------------------------------------------------------
# F1: 0.44  -- prec: 0.93  -- recall: 0.29  -- acc: 0.75
# ----------------------------------------------------------

# %%
umbral = 0.4

# %%
maskSignal=Prediccion>umbral

# %%
predicBin=[]
for i in maskSignal:
    if(i==True):
        predicBin.append(1)
    else:
        predicBin.append(0)

# %%
npPredict=np.array(predicBin)

# %%
cm=confusion_matrix(y_test2, npPredict)
cm
# Out:
# array([[11344,  1919],
#        [ 1335,  5402]], dtype=int64)

# %%
cm_display = ConfusionMatrixDisplay(cm).plot()

# %%
f1= f1_score(y_test2, npPredict)
f1
# Out:
# 0.768530374164177

# %%
prec=precision_score(y_test2, npPredict)
prec
# Out:
# 0.7273954116059379

# %%
rec=recall_score(y_test2, npPredict)
rec
# Out:
# 0.7948289421942587

# %%
accu=accuracy_score(y_test2, npPredict)
accu
# Out:
# 0.8294333333333334

# %%
print(classification_report(y_test2, npPredict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.85      0.87     19828
#            1       0.73      0.79      0.76     10172
#
#     accuracy                           0.83     30000
#    macro avg       0.81      0.82      0.81     30000
# weighted avg       0.83      0.83      0.83     30000

# %%
print("F1: %.2f" %f1 , " -- prec: %.2f" %prec, " -- recall: %.2f" %rec, " -- acc: %.2f" %acc)
# Out:
# F1: 0.76  -- prec: 0.73  -- recall: 0.79  -- acc: 0.75
