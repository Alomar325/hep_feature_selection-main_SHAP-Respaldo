# %% [markdown]
# # Random Forest
#
# ### Clasificación de eventos usando Random Forest como seleccionador de características.

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------
#
# Alex Toro, Raquel Pezoa

# %% [markdown]
# ## Librerias necesarias.
# -------------------------------------------------------------------------------------------------------------------------------

# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import SelectFromModel
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error

# %%
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
import numpy as np
from scipy.stats import randint

# %%
import xgboost as xgb

# %%
from sklearn.metrics import confusion_matrix, f1_score, precision_score, recall_score, accuracy_score, classification_report, roc_curve, auc, roc_auc_score, ConfusionMatrixDisplay

# %%
import winsound

# %% [markdown]
# ## Lectura del set de datos reducido.
#
# - El set original proviene de https://www.kaggle.com/competitions/higgs-boson/data.
# - Separación de la variable Label de las demas variables.
# -------------------------------------------------------------------------------------------------------------------------------

# %%
df = pd.read_csv("/Users/Alex/Downloads/Pre-procesado.csv")

# %%
X = df.drop(labels=['Label'], axis=1)
Y = df['Label']

# %% [markdown]
# ### Entrenamiento y testeo del set de datos.
# -------------------------------------------------------------------------------------------------------------------------------

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    Y,
    test_size=0.01,
    random_state=0)

# %%
params = {
    'max_depth': [3, None],
    'max_features': randint(1,11),
    'min_samples_split': randint(2,11),
    'bootstrap': [True, False],
    'criterion': ['gini', 'entropy']
}

# %%
classifier=RandomForestClassifier(n_estimators = 100)

# %%
random_search=RandomizedSearchCV(classifier,param_distributions=params,n_iter=5,scoring='roc_auc',n_jobs=-1,cv=5,verbose=3)

# %%
random_search.fit(X_train,y_train) # el de 5 iteraciones
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# RandomizedSearchCV(cv=5, estimator=RandomForestClassifier(), n_iter=5,
#                    n_jobs=-1,
#                    param_distributions={'bootstrap': [True, False],
#                                         'criterion': ['gini', 'entropy'],
#                                         'max_depth': [3, None],
#                                         'max_features': <scipy.stats._distn_infrastructure.rv_frozen object at 0x0000020EF75B7760>,
#                                         'min_samples_split': <scipy.stats._distn_infrastructure.rv_frozen object at 0x0000020EF75C0310>},
#                    scoring='roc_auc', verbose=3)

# %%
frequency = 2500  # Set Frequency To 2500 Hertz
duration = 1000  # Set Duration To 1000 ms == 1 second
winsound.Beep(frequency, duration)

# %%
print(random_search.best_estimator_) # 5 iteraciones
# Out:
# RandomForestClassifier(bootstrap=False, criterion='entropy', max_features=1,
#                        min_samples_split=3)

# %%
random_search.best_params_ # 5 iteraciones
# Out:
# {'bootstrap': False,
#  'criterion': 'entropy',
#  'max_depth': None,
#  'max_features': 1,
#  'min_samples_split': 3}

# %%
n_top=3
results = random_search.cv_results_
for i in range(1, n_top + 1):
        candidates = np.flatnonzero(results['rank_test_score'] == i)
        for candidate in candidates:
            print('Model with rank: {0}'.format(i))
            print('Mean validation score: {0:.3f}(std: {1:.3f})'.format(
                results['mean_test_score'][candidate],
                results['std_test_score'][candidate]))
            print('Parameters: {0}'.format(results['params'][candidate]))
# Out:
# Model with rank: 1
# Mean validation score: 0.913(std: 0.001)
# Parameters: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': None, 'max_features': 1, 'min_samples_split': 3}
# Model with rank: 2
# Mean validation score: 0.912(std: 0.001)
# Parameters: {'bootstrap': False, 'criterion': 'gini', 'max_depth': None, 'max_features': 1, 'min_samples_split': 3}
# Model with rank: 3
# Mean validation score: 0.864(std: 0.002)
# Parameters: {'bootstrap': True, 'criterion': 'gini', 'max_depth': 3, 'max_features': 9, 'min_samples_split': 8}

# %%
rf1 = RandomForestClassifier(n_estimators = 100, bootstrap = False, criterion = 'entropy', max_depth = None, max_features = 1, min_samples_split = 3)
rf1.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=False, criterion='entropy', max_features=1,
#                        min_samples_split=3)

# %%
print(rf1.feature_importances_) #buscar feature_importance en selectfromModel
# Out:
# [0.09189173 0.06963448 0.06506951 0.03760286 0.01600939 0.01735547
#  0.01312899 0.05241235 0.03358633 0.04124417 0.04988507 0.0458115
#  0.01329937 0.05527768 0.0318568  0.03042194 0.03667102 0.03341423
#  0.03102081 0.04580037 0.03120045 0.03496517 0.00628842 0.02246621
#  0.02271622 0.01972054 0.01001634 0.00955796 0.0089992  0.02267542]

# %% [markdown]
# ### Convertir los datos a  una lista de duplas
#
# - Se convierte la matriz entregada por random forest junto a las columnas del dataframe en una lista de duplas.
# - Se realizan las duplas para así poder reordenar las variables de la más relevante a la menos relevante.
# - Se Reordena la duplas de mayor a menor.
# - Se separan las duplas en listas separadas y transformar las 10 primeras en arreglos de numpy.
# -------------------------------------------------------------------------------------------------------------------------------

# %%
l = []
for feature in zip(rf1.feature_importances_,X_train.columns):
    l.append(feature)
    print(feature)
# Out:
# (0.0918917288583955, 'DER_mass_MMC')
# (0.06963447744001296, 'DER_mass_transverse_met_lep')
# (0.0650695095891659, 'DER_mass_vis')
# (0.03760285979842202, 'DER_pt_h')
# (0.016009389310136384, 'DER_deltaeta_jet_jet')
# (0.01735546949917598, 'DER_mass_jet_jet')
# (0.013128991854293209, 'DER_prodeta_jet_jet')
# (0.05241235348073208, 'DER_deltar_tau_lep')
# (0.03358633437445088, 'DER_pt_tot')
# (0.041244167105427734, 'DER_sum_pt')
# (0.04988506798117116, 'DER_pt_ratio_lep_tau')
# (0.04581149683803421, 'DER_met_phi_centrality')
# (0.013299368804941137, 'DER_lep_eta_centrality')
# (0.055277683277637636, 'PRI_tau_pt')
# (0.031856798502586665, 'PRI_tau_eta')
# (0.030421942707797873, 'PRI_tau_phi')
# (0.0366710199301594, 'PRI_lep_pt')
# (0.033414234062908624, 'PRI_lep_eta')
# (0.03102081348821623, 'PRI_lep_phi')
# (0.045800365783410124, 'PRI_met')
# (0.03120044754807166, 'PRI_met_phi')
# (0.03496517082924982, 'PRI_met_sumet')
# (0.00628842112684592, 'PRI_jet_num')
# (0.022466208446321453, 'PRI_jet_leading_pt')
# (0.022716221822879083, 'PRI_jet_leading_eta')
# (0.019720543934694836, 'PRI_jet_leading_phi')
# (0.010016344466315838, 'PRI_jet_subleading_pt')
# (0.009557956734337913, 'PRI_jet_subleading_eta')
# (0.008999196714332143, 'PRI_jet_subleading_phi')
# (0.022675415689875616, 'PRI_jet_all_pt')

# %%
l.sort(reverse=True)

# %%
l
# Out:
# [(0.0918917288583955, 'DER_mass_MMC'),
#  (0.06963447744001296, 'DER_mass_transverse_met_lep'),
#  (0.0650695095891659, 'DER_mass_vis'),
#  (0.055277683277637636, 'PRI_tau_pt'),
#  (0.05241235348073208, 'DER_deltar_tau_lep'),
#  (0.04988506798117116, 'DER_pt_ratio_lep_tau'),
#  (0.04581149683803421, 'DER_met_phi_centrality'),
#  (0.045800365783410124, 'PRI_met'),
#  (0.041244167105427734, 'DER_sum_pt'),
#  (0.03760285979842202, 'DER_pt_h'),
#  (0.0366710199301594, 'PRI_lep_pt'),
#  (0.03496517082924982, 'PRI_met_sumet'),
#  (0.03358633437445088, 'DER_pt_tot'),
#  (0.033414234062908624, 'PRI_lep_eta'),
#  (0.031856798502586665, 'PRI_tau_eta'),
#  (0.03120044754807166, 'PRI_met_phi'),
#  (0.03102081348821623, 'PRI_lep_phi'),
#  (0.030421942707797873, 'PRI_tau_phi'),
#  (0.022716221822879083, 'PRI_jet_leading_eta'),
#  (0.022675415689875616, 'PRI_jet_all_pt'),
#  (0.022466208446321453, 'PRI_jet_leading_pt'),
#  (0.019720543934694836, 'PRI_jet_leading_phi'),
#  (0.01735546949917598, 'DER_mass_jet_jet'),
#  (0.016009389310136384, 'DER_deltaeta_jet_jet'),
#  (0.013299368804941137, 'DER_lep_eta_centrality'),
#  (0.013128991854293209, 'DER_prodeta_jet_jet'),
#  (0.010016344466315838, 'PRI_jet_subleading_pt'),
#  (0.009557956734337913, 'PRI_jet_subleading_eta'),
#  (0.008999196714332143, 'PRI_jet_subleading_phi'),
#  (0.00628842112684592, 'PRI_jet_num')]

# %%
l_i = []
l_v = []
for importance in range(len(l)):
    for var in range(len(l[importance])):
        if(var == 0):
            l_i.append(l[importance][var])
        else:
            l_v.append(l[importance][var])

# %%
import matplotlib.pyplot as plt
import numpy as np
y = np.array(l_i[0:10])
x = np.array(l_v[0:10])
x
# Out:
# array(['DER_mass_MMC', 'DER_mass_transverse_met_lep', 'DER_mass_vis',
#        'PRI_tau_pt', 'DER_deltar_tau_lep', 'DER_pt_ratio_lep_tau',
#        'DER_met_phi_centrality', 'PRI_met', 'DER_sum_pt', 'DER_pt_h'],
#       dtype='<U27')

# %% [markdown]
# ### Graficación de las variables más importantes.
#
# -------------------------------------------------------------------------------------------------------------------------------

# %%
import matplotlib
font = {'size'   : 16}
matplotlib.rc('font', **font)
fig = plt.figure(figsize = (20, 3))


# creating the bar plot
plt.ylabel("Importancia")
plt.bar(x, y, color ='green',
        width = 0.9)
plt.xticks(rotation=45, ha='right')
plt.title("Ranking Top 10 de variables usando Random forest")
plt.show()

# %%
X_train[x].head()
# Out:
#        DER_mass_MMC  DER_mass_transverse_met_lep  DER_mass_vis  PRI_tau_pt  \
# 49563        85.915                       50.407        54.588      23.200
# 49733      -999.000                      103.063       240.301      26.645
# 87086       210.817                       57.625       163.601      24.339
# 97372      -999.000                       92.812        27.787      33.514
# 11049       114.842                        3.224        74.441      35.805
#
#        DER_deltar_tau_lep  DER_pt_ratio_lep_tau  DER_met_phi_centrality  \
# 49563               2.488                 1.310                   1.414
# 49733               4.223                 2.284                  -1.285
# 87086               4.183                 1.760                  -1.384
# 97372               0.789                 1.054                  -1.402
# 11049               2.195                 0.828                   1.113
#
#        PRI_met  DER_sum_pt  DER_pt_h
# 49563   63.122     391.775    84.397
# 49733   45.000      87.495     4.254
# 87086   21.070      67.176     3.315
# 97372   61.111      68.849     7.507
# 11049   25.803     277.607    71.743

# %% [markdown]
# ### Entrenamiento, testeo y optimizacion de parametros de DMatrix de XGBoost con las variables entregadas por XGBoost.
# -------------------------------------------------------------------------------------------------------------------------------

# %%
X_train2 = X[x] 
X_train2, X_test2, y_train2, y_test2 = train_test_split(X_train2, Y, test_size=0.3, random_state=0)

# %%
dtrain = xgb.DMatrix(X_train2, label=y_train2)
dtest = xgb.DMatrix(X_test2, label=y_test2)

# %%
params = {
    # Parameters that we are going to tune.
    'max_depth':6,
    'min_child_weight': 1,
    'eta':.3,
    'subsample': 1,
    'colsample_bytree': 1,
    # Other parameters
    'objective':'reg:linear',
}
params['eval_metric'] = "mae"
num_boost_round = 999

# %%
modelo = xgb.train( 
    params, 
    dtrain, 
    num_boost_round=num_boost_round, 
    evals=[(dtest, "Test")], 
    early_stopping_rounds=10 
)
# Out:
# [15:48:04] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	Test-mae:0.42939
# [1]	Test-mae:0.37914
# [2]	Test-mae:0.34296
# [3]	Test-mae:0.31626
# [4]	Test-mae:0.29642
# [5]	Test-mae:0.28238
# [6]	Test-mae:0.27258
# [7]	Test-mae:0.26509
# [8]	Test-mae:0.25913
# [9]	Test-mae:0.25514
# [10]	Test-mae:0.25197
# [11]	Test-mae:0.25012
# [12]	Test-mae:0.24888
# [13]	Test-mae:0.24781
# [14]	Test-mae:0.24727
# [15]	Test-mae:0.24671
# [16]	Test-mae:0.24649
# [17]	Test-mae:0.24656
# [18]	Test-mae:0.24601
# [19]	Test-mae:0.24567
# [20]	Test-mae:0.24568
# [21]	Test-mae:0.24547
# [22]	Test-mae:0.24540
# [23]	Test-mae:0.24517
# [24]	Test-mae:0.24502
# [25]	Test-mae:0.24490
# [26]	Test-mae:0.24467
# [27]	Test-mae:0.24486
# [28]	Test-mae:0.24490
# [29]	Test-mae:0.24489
# [30]	Test-mae:0.24488
# [31]	Test-mae:0.24483
# [32]	Test-mae:0.24476
# [33]	Test-mae:0.24472
# [34]	Test-mae:0.24477
# [35]	Test-mae:0.24483

# %%
print("Best MAE: {:.2f} with {} rounds".format(
                 modelo.best_score,
                 modelo.best_iteration+1))
# Out:
# Best MAE: 0.24 with 27 rounds

# %%
cv_results = xgb.cv( 
    params, 
    dtrain, 
    num_boost_round=num_boost_round, 
    seed=42, 
    nfold=5, 
    metrics={'mae'}, 
    early_stopping_rounds=10 
)
cv_results
# Out:
# [15:48:06] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:48:06] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:48:06] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:48:06] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:48:06] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
#     train-mae-mean  train-mae-std  test-mae-mean  test-mae-std
# 0         0.428511       0.000277       0.429508      0.000420
# 1         0.377406       0.000278       0.379317      0.000681
# 2         0.340293       0.000336       0.342906      0.000863
# 3         0.312645       0.000604       0.316122      0.000892
# 4         0.292484       0.000702       0.296721      0.000889
# 5         0.277567       0.000706       0.282547      0.001007
# 6         0.266537       0.000397       0.272230      0.001284
# 7         0.258351       0.000418       0.264631      0.001407
# 8         0.252161       0.000394       0.259117      0.001547
# 9         0.247675       0.000424       0.255325      0.001737
# 10        0.244153       0.000523       0.252396      0.001607
# 11        0.241397       0.000415       0.250102      0.001644
# 12        0.239348       0.000436       0.248565      0.001504
# 13        0.238035       0.000436       0.247578      0.001408
# 14        0.236890       0.000590       0.246806      0.001254
# 15        0.236277       0.000626       0.246469      0.001269
# 16        0.235577       0.000630       0.246048      0.001412
# 17        0.235082       0.000654       0.245889      0.001395
# 18        0.234589       0.000732       0.245781      0.001481
# 19        0.234183       0.000599       0.245744      0.001512
# 20        0.233684       0.000540       0.245649      0.001596
# 21        0.233266       0.000495       0.245488      0.001649
# 22        0.232803       0.000447       0.245381      0.001643
# 23        0.232336       0.000290       0.245252      0.001500
# 24        0.231861       0.000348       0.245216      0.001546
# 25        0.231348       0.000270       0.245036      0.001538
# 26        0.231074       0.000348       0.245017      0.001534
# 27        0.230520       0.000405       0.244835      0.001422
# 28        0.230185       0.000372       0.244821      0.001466
# 29        0.229784       0.000212       0.244822      0.001432
# 30        0.229607       0.000204       0.244890      0.001358
# 31        0.229280       0.000319       0.244895      0.001412
# 32        0.229039       0.000177       0.244976      0.001280
# 33        0.228674       0.000311       0.245020      0.001285
# 34        0.228184       0.000291       0.244910      0.001276
# 35        0.227802       0.000313       0.244829      0.001287
# 36        0.227390       0.000440       0.244766      0.001232
# 37        0.226904       0.000385       0.244661      0.001247
# 38        0.226613       0.000383       0.244650      0.001208

# %%
cv_results['test-mae-mean'].min()
# Out:
# 0.24464975663991603

# %%
gridsearch_params = [
    (max_depth, min_child_weight)
    for max_depth in range(9,12)
    for min_child_weight in range(5,8)
]

# %%
min_mae = float("Inf")
best_params = None
for max_depth, min_child_weight in gridsearch_params:
    print("CV with max_depth={}, min_child_weight={}".format(
                             max_depth,
                             min_child_weight))
    # Update our parameters
    params['max_depth'] = max_depth
    params['min_child_weight'] = min_child_weight
    # Run CV
    cv_results = xgb.cv(
        params,
        dtrain,
        num_boost_round=num_boost_round,
        seed=42,
        nfold=5,
        metrics={'mae'},
        early_stopping_rounds=10
    )
    # Update best MAE
    mean_mae = cv_results['test-mae-mean'].min()
    boost_rounds = cv_results['test-mae-mean'].argmin()
    print("\tMAE {} for {} rounds".format(mean_mae, boost_rounds))
    if mean_mae < min_mae:
        min_mae = mean_mae
        best_params = (max_depth,min_child_weight)
print("Best params: {}, {}, MAE: {}".format(best_params[0], best_params[1], min_mae))
frequency = 2500  # Set Frequency To 2500 Hertz
duration = 1000  # Set Duration To 1000 ms == 1 second
winsound.Beep(frequency, duration)
# Out:
# CV with max_depth=9, min_child_weight=5
# [15:48:13] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:48:13] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:48:13] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:48:14] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:48:14] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.24107848214472782 for 32 rounds
# CV with max_depth=9, min_child_weight=6
# [15:48:23] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:48:24] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:48:24] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:48:24] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:48:24] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.24065113860214749 for 28 rounds
# CV with max_depth=9, min_child_weight=7
# [15:48:33] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:48:33] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:48:33] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:48:33] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:48:33] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.24089065966261405 for 20 rounds
# CV with max_depth=10, min_child_weight=5
# [15:48:40] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:48:40] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:48:40] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:48:40] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:48:40] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.24048892915953574 for 29 rounds
# CV with max_depth=10, min_child_weight=6
# [15:48:51] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:48:51] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:48:51] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:48:51] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:48:51] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.24060633940209555 for 26 rounds
# CV with max_depth=10, min_child_weight=7
# [15:49:00] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:49:00] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:49:00] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:49:01] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:49:01] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.24102977910175002 for 25 rounds
# CV with max_depth=11, min_child_weight=5
# [15:49:10] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:49:10] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:49:10] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:49:10] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:49:10] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.2402177738426412 for 23 rounds
# CV with max_depth=11, min_child_weight=6
# [15:49:20] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:49:20] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:49:20] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:49:20] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:49:20] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.24030977591478386 for 20 rounds
# CV with max_depth=11, min_child_weight=7
# [15:49:29] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:49:29] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:49:29] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:49:29] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:49:29] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.2399329923851235 for 20 rounds
# Best params: 11, 7, MAE: 0.2399329923851235

# %%
params['max_depth'] = 11
params['min_child_weight'] = 7

# %%
gridsearch_params = [
    (subsample, colsample)
    for subsample in [i/10. for i in range(7,11)]
    for colsample in [i/10. for i in range(7,11)]
]

# %%
min_mae = float("Inf")
best_params = None
# We start by the largest values and go down to the smallest
for subsample, colsample in reversed(gridsearch_params):
    print("CV with subsample={}, colsample={}".format(
                             subsample,
                             colsample))
    # We update our parameters
    params['subsample'] = subsample
    params['colsample_bytree'] = colsample
    # Run CV
    cv_results = xgb.cv(
        params,
        dtrain,
        num_boost_round=num_boost_round,
        seed=42,
        nfold=5,
        metrics={'mae'},
        early_stopping_rounds=10
    )
    # Update best score
    mean_mae = cv_results['test-mae-mean'].min()
    boost_rounds = cv_results['test-mae-mean'].argmin()
    print("\tMAE {} for {} rounds".format(mean_mae, boost_rounds))
    if mean_mae < min_mae:
        min_mae = mean_mae
        best_params = (subsample,colsample)
print("Best params: {}, {}, MAE: {}".format(best_params[0], best_params[1], min_mae))
frequency = 2500  # Set Frequency To 2500 Hertz
duration = 1000  # Set Duration To 1000 ms == 1 second
winsound.Beep(frequency, duration)
# Out:
# CV with subsample=1.0, colsample=1.0
# [15:49:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:49:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:49:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:49:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:49:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.2399329923851235 for 20 rounds
# CV with subsample=1.0, colsample=0.9
# [15:49:56] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:49:56] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:49:56] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:49:56] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:49:56] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.24151040457946055 for 22 rounds
# CV with subsample=1.0, colsample=0.8
# [15:50:04] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:50:04] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:50:05] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:50:05] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:50:05] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.2421930219910266 for 20 rounds
# CV with subsample=1.0, colsample=0.7
# [15:50:12] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:50:12] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:50:12] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:50:12] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:50:12] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.2443857456531778 for 19 rounds
# CV with subsample=0.9, colsample=1.0
# [15:50:19] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:50:19] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:50:19] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:50:19] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:50:19] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.24095110504277337 for 23 rounds
# CV with subsample=0.9, colsample=0.9
# [15:50:29] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:50:29] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:50:29] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:50:29] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:50:29] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.2423748713747854 for 19 rounds
# CV with subsample=0.9, colsample=0.8
# [15:50:37] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:50:37] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:50:37] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:50:37] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:50:37] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.2426222153755307 for 21 rounds
# CV with subsample=0.9, colsample=0.7
# [15:50:45] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:50:45] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:50:45] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:50:45] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:50:45] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.24411615013103188 for 19 rounds
# CV with subsample=0.8, colsample=1.0
# [15:50:52] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:50:52] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:50:52] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:50:52] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:50:53] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.24148446578095917 for 20 rounds
# CV with subsample=0.8, colsample=0.9
# [15:51:01] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:51:01] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:51:01] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:51:01] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:51:01] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.24239127595248636 for 18 rounds
# CV with subsample=0.8, colsample=0.8
# [15:51:09] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:51:09] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:51:09] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:51:09] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:51:09] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.24302858337391225 for 19 rounds
# CV with subsample=0.8, colsample=0.7
# [15:51:16] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:51:16] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:51:16] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:51:17] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:51:17] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.24464254365613822 for 19 rounds
# CV with subsample=0.7, colsample=1.0
# [15:51:23] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:51:23] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:51:23] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:51:23] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:51:24] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.2426003485220892 for 15 rounds
# CV with subsample=0.7, colsample=0.9
# [15:51:31] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:51:31] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:51:31] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:51:31] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:51:31] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.24320649509109044 for 15 rounds
# CV with subsample=0.7, colsample=0.8
# [15:51:37] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:51:37] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:51:37] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:51:37] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:51:38] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.24396018720278684 for 15 rounds
# CV with subsample=0.7, colsample=0.7
# [15:51:44] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:51:44] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:51:44] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:51:44] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:51:44] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.24614175326367066 for 16 rounds
# Best params: 1.0, 1.0, MAE: 0.2399329923851235

# %%
params['subsample'] = 1.
params['colsample_bytree'] = 1.

# %%
# This can take some time…
min_mae = float("Inf")
best_params = None
for eta in [.3, .2, .1, .05, .01, .005]:
    print("CV with eta={}".format(eta))
    # We update our parameters
    params['eta'] = eta
    # Run and time CV
    cv_results = xgb.cv(
            params,
            dtrain,
            num_boost_round=num_boost_round,
            seed=42,
            nfold=5,
            metrics=['mae'],
            early_stopping_rounds=10
          )
    # Update best score
    mean_mae = cv_results['test-mae-mean'].min()
    boost_rounds = cv_results['test-mae-mean'].argmin()
    print("\tMAE {} for {} rounds\n".format(mean_mae, boost_rounds))
    if mean_mae < min_mae:
        min_mae = mean_mae
        best_params = eta
print("Best params: {}, MAE: {}".format(best_params, min_mae))
frequency = 2500  # Set Frequency To 2500 Hertz
duration = 1000  # Set Duration To 1000 ms == 1 second
winsound.Beep(frequency, duration)
# Out:
# CV with eta=0.3
# [15:51:59] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:52:00] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:52:00] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:52:00] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:52:00] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.2399329923851235 for 20 rounds
#
# CV with eta=0.2
# [15:52:09] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:52:09] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:52:09] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:52:09] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:52:09] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.23833567228553285 for 50 rounds
#
# CV with eta=0.1
# [15:52:27] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:52:27] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:52:27] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:52:27] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:52:27] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.23698466326253134 for 150 rounds
#
# CV with eta=0.05
# [15:53:12] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:53:12] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:53:12] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:53:12] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:53:12] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.23622318038778914 for 382 rounds
#
# CV with eta=0.01
# [15:55:06] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:55:06] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:55:06] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:55:06] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [15:55:06] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.23672031074384842 for 998 rounds
#
# CV with eta=0.005
# [16:00:16] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:00:16] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:00:16] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:00:16] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [16:00:16] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 0.23945888206902052 for 998 rounds
#
# Best params: 0.05, MAE: 0.23622318038778914

# %%
params['eta'] = .05

# %%
params
# Out:
# {'max_depth': 11,
#  'min_child_weight': 7,
#  'eta': 0.05,
#  'subsample': 1.0,
#  'colsample_bytree': 1.0,
#  'objective': 'reg:linear',
#  'eval_metric': 'mae'}

# %%
model = xgb.train(
    params,
    dtrain,
    num_boost_round=num_boost_round,
    evals=[(dtest, "Test")],
    early_stopping_rounds=10
)
# Out:
# [16:05:46] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	Test-mae:0.48718
# [1]	Test-mae:0.47498
# [2]	Test-mae:0.46341
# [3]	Test-mae:0.45236
# [4]	Test-mae:0.44189
# [5]	Test-mae:0.43196
# [6]	Test-mae:0.42244
# [7]	Test-mae:0.41348
# [8]	Test-mae:0.40490
# [9]	Test-mae:0.39683
# [10]	Test-mae:0.38909
# [11]	Test-mae:0.38168
# [12]	Test-mae:0.37466
# [974]	Test-mae:0.23278
# [975]	Test-mae:0.23279
# [976]	Test-mae:0.23280
# [977]	Test-mae:0.23280
# [978]	Test-mae:0.23281
# [979]	Test-mae:0.23281
# [980]	Test-mae:0.23281
# [981]	Test-mae:0.23280
# [982]	Test-mae:0.23281
# [983]	Test-mae:0.23281
# [984]	Test-mae:0.23281
# [985]	Test-mae:0.23281
# [986]	Test-mae:0.23281
# [987]	Test-mae:0.23281
# [988]	Test-mae:0.23281
# [989]	Test-mae:0.23280
# [990]	Test-mae:0.23280
# [991]	Test-mae:0.23279
# [992]	Test-mae:0.23279
# [993]	Test-mae:0.23278
# [994]	Test-mae:0.23278
# [995]	Test-mae:0.23278
# [996]	Test-mae:0.23279
# [997]	Test-mae:0.23279
# [998]	Test-mae:0.23279

# %%
mean_absolute_error(best_model.predict(dtest), y_test2)
# Out:
# 0.2327877744639643

# %% [markdown]
# ### Guardado del modelo y predicciones.
# -------------------------------------------------------------------------------------------------------------------------------

# %%
best_model.save_model("Random_forest.model")

# %%
loaded_model = xgb.Booster()
loaded_model.load_model("Random_forest.model")
# And use it for predictions.
# Out:
# [16:07:10] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.

# %%
Prediccion = loaded_model.predict(dtest)

# %%
Prediccion.min()
# Out:
# -0.1881546

# %%
Prediccion.max()
# Out:
# 1.2614595

# %%
testing_list =[]
for i in  np.linspace(0.1,0.9,9):
    d = {}
    y_p = Prediccion >= i
    print("Threshold:",i)
    cm = confusion_matrix(y_test2,y_p)
    d["th"] = i
    d["F1"] = np.round(f1_score(y_test2,y_p),2)
    d["Prec"] = np.round(precision_score(y_test2,y_p),2)
    d["Rec"] = np.round(recall_score(y_test2,y_p),2)
    d["Acc"] = np.round(accuracy_score(y_test2,y_p),2)
    d["RocAuc"] = np.round(roc_auc_score(y_test2,y_p),2)
    testing_list.append(d)
# Out:
# Threshold: 0.1
# Threshold: 0.2
# Threshold: 0.30000000000000004
# Threshold: 0.4
# Threshold: 0.5
# Threshold: 0.6
# Threshold: 0.7000000000000001
# Threshold: 0.8
# Threshold: 0.9

# %% [markdown]
# # Metricas para cada umbral.
# - th: umbral
# -------------------------------------------------------------------------------------------------------------------------------

# %%
testing_metrics_pd = pd.DataFrame(testing_list)
testing_metrics_pd
# Out:
#     th    F1  Prec   Rec   Acc  RocAuc
# 0  0.1  0.67  0.52  0.96  0.68    0.75
# 1  0.2  0.72  0.60  0.91  0.77    0.80
# 2  0.3  0.75  0.67  0.86  0.81    0.82
# 3  0.4  0.76  0.72  0.80  0.83    0.82
# 4  0.5  0.75  0.77  0.73  0.83    0.81
# 5  0.6  0.72  0.82  0.65  0.83    0.79
# 6  0.7  0.68  0.86  0.56  0.82    0.76
# 7  0.8  0.59  0.89  0.44  0.79    0.71
# 8  0.9  0.41  0.92  0.26  0.74    0.63

# %%
print(testing_metrics_pd.to_latex(index=False))
# Out:
# \begin{tabular}{rrrrrr}
# \toprule
#  th &   F1 &  Prec &  Rec &  Acc &  RocAuc \\
# \midrule
# 0.1 & 0.67 &  0.52 & 0.96 & 0.68 &    0.75 \\
# 0.2 & 0.72 &  0.60 & 0.91 & 0.77 &    0.80 \\
# 0.3 & 0.75 &  0.67 & 0.86 & 0.81 &    0.82 \\
# 0.4 & 0.76 &  0.72 & 0.80 & 0.83 &    0.82 \\
# 0.5 & 0.75 &  0.77 & 0.73 & 0.83 &    0.81 \\
# 0.6 & 0.72 &  0.82 & 0.65 & 0.83 &    0.79 \\
# 0.7 & 0.68 &  0.86 & 0.56 & 0.82 &    0.76 \\
# 0.8 & 0.59 &  0.89 & 0.44 & 0.79 &    0.71 \\
# 0.9 & 0.41 &  0.92 & 0.26 & 0.74 &    0.63 \\
# \bottomrule
# \end{tabular}

# %%
fpr, tpr, ths = roc_curve(y_test2,  Prediccion)
auc_ = auc(fpr, tpr)
plt.plot(fpr,tpr, label='ROC curve (area = %.2f)' %auc_)
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.legend()
plt.grid()
plt.show()

# %%
for i in  np.linspace(0.1,0.9,9):
    print(i)
    y_p = Prediccion >= i
    print(classification_report(y_test2, y_p))
    f1 = f1_score(y_test2, y_p)
    prec = precision_score(y_test2, y_p)
    rec = recall_score(y_test2, y_p)
    acc = accuracy_score(y_test2, y_p)
    cm=confusion_matrix(y_test2, y_p)
    print("Matriz de confusión: ")
    print(cm)
    print("----------------------------------------------------------")
    print("F1: %.2f" %f1 , " -- prec: %.2f" %prec, " -- recall: %.2f" %rec, " -- acc: %.2f" %acc)
    print("----------------------------------------------------------")
# Out:
# 0.1
#               precision    recall  f1-score   support
#
#            0       0.96      0.54      0.69     19828
#            1       0.52      0.96      0.67     10172
#
#     accuracy                           0.68     30000
#    macro avg       0.74      0.75      0.68     30000
# weighted avg       0.81      0.68      0.69     30000
#
# Matriz de confusión:
# [[10739  9089]
#  [  446  9726]]
# ----------------------------------------------------------
# F1: 0.67  -- prec: 0.52  -- recall: 0.96  -- acc: 0.68
# ----------------------------------------------------------
# 0.2
#               precision    recall  f1-score   support
#
#            0       0.94      0.69      0.80     19828
#            1       0.60      0.91      0.72     10172
#
#     accuracy                           0.77     30000
#    macro avg       0.77      0.80      0.76     30000
# weighted avg       0.82      0.77      0.77     30000
#
# Matriz de confusión:
# [[13719  6109]
#  [  924  9248]]
# ----------------------------------------------------------
# F1: 0.72  -- prec: 0.60  -- recall: 0.91  -- acc: 0.77
# ----------------------------------------------------------
# 0.30000000000000004
#               precision    recall  f1-score   support
#
#            0       0.91      0.78      0.84     19828
#            1       0.67      0.86      0.75     10172
#
#     accuracy                           0.81     30000
#    macro avg       0.79      0.82      0.80     30000
# weighted avg       0.83      0.81      0.81     30000
#
# Matriz de confusión:
# [[15495  4333]
#  [ 1463  8709]]
# ----------------------------------------------------------
# F1: 0.75  -- prec: 0.67  -- recall: 0.86  -- acc: 0.81
# ----------------------------------------------------------
# 0.4
#               precision    recall  f1-score   support
#
#            0       0.89      0.84      0.86     19828
#            1       0.72      0.80      0.76     10172
#
#     accuracy                           0.83     30000
#    macro avg       0.80      0.82      0.81     30000
# weighted avg       0.83      0.83      0.83     30000
#
# Matriz de confusión:
# [[16694  3134]
#  [ 2083  8089]]
# ----------------------------------------------------------
# F1: 0.76  -- prec: 0.72  -- recall: 0.80  -- acc: 0.83
# ----------------------------------------------------------
# 0.5
#               precision    recall  f1-score   support
#
#            0       0.86      0.89      0.88     19828
#            1       0.77      0.73      0.75     10172
#
#     accuracy                           0.83     30000
#    macro avg       0.82      0.81      0.81     30000
# weighted avg       0.83      0.83      0.83     30000
#
# Matriz de confusión:
# [[17638  2190]
#  [ 2785  7387]]
# ----------------------------------------------------------
# F1: 0.75  -- prec: 0.77  -- recall: 0.73  -- acc: 0.83
# ----------------------------------------------------------
# 0.6
#               precision    recall  f1-score   support
#
#            0       0.84      0.93      0.88     19828
#            1       0.82      0.65      0.72     10172
#
#     accuracy                           0.83     30000
#    macro avg       0.83      0.79      0.80     30000
# weighted avg       0.83      0.83      0.83     30000
#
# Matriz de confusión:
# [[18348  1480]
#  [ 3583  6589]]
# ----------------------------------------------------------
# F1: 0.72  -- prec: 0.82  -- recall: 0.65  -- acc: 0.83
# ----------------------------------------------------------
# 0.7000000000000001
#               precision    recall  f1-score   support
#
#            0       0.81      0.95      0.87     19828
#            1       0.86      0.56      0.68     10172
#
#     accuracy                           0.82     30000
#    macro avg       0.83      0.76      0.78     30000
# weighted avg       0.83      0.82      0.81     30000
#
# Matriz de confusión:
# [[18893   935]
#  [ 4492  5680]]
# ----------------------------------------------------------
# F1: 0.68  -- prec: 0.86  -- recall: 0.56  -- acc: 0.82
# ----------------------------------------------------------
# 0.8
#               precision    recall  f1-score   support
#
#            0       0.77      0.97      0.86     19828
#            1       0.89      0.44      0.59     10172
#
#     accuracy                           0.79     30000
#    macro avg       0.83      0.71      0.73     30000
# weighted avg       0.81      0.79      0.77     30000
#
# Matriz de confusión:
# [[19276   552]
#  [ 5674  4498]]
# ----------------------------------------------------------
# F1: 0.59  -- prec: 0.89  -- recall: 0.44  -- acc: 0.79
# ----------------------------------------------------------
# 0.9
#               precision    recall  f1-score   support
#
#            0       0.72      0.99      0.84     19828
#            1       0.92      0.26      0.41     10172
#
#     accuracy                           0.74     30000
#    macro avg       0.82      0.63      0.62     30000
# weighted avg       0.79      0.74      0.69     30000
#
# Matriz de confusión:
# [[19590   238]
#  [ 7502  2670]]
# ----------------------------------------------------------
# F1: 0.41  -- prec: 0.92  -- recall: 0.26  -- acc: 0.74
# ----------------------------------------------------------

# %%
umbral = 0.4

# %%
maskSignal=Prediccion>umbral

# %%
predicBin=[]
for i in maskSignal:
    if(i==True):
        predicBin.append(1)
    else:
        predicBin.append(0)

# %%
npPredict=np.array(predicBin)

# %%
cm=confusion_matrix(y_test2, npPredict)
cm
# Out:
# array([[16694,  3134],
#        [ 2083,  8089]], dtype=int64)

# %%
cm_display = ConfusionMatrixDisplay(cm).plot()

# %%
f1= f1_score(y_test2, npPredict)
f1
# Out:
# 0.7561579808366441

# %%
prec=precision_score(y_test2, npPredict)
prec
# Out:
# 0.7218881809207575

# %%
rec=recall_score(y_test2, npPredict)
rec
# Out:
# 0.7907982697601258

# %%
accu=accuracy_score(y_test2, npPredict)
accu
# Out:
# 0.8257666666666666

# %%
print(classification_report(y_test2, npPredict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.84      0.86     19828
#            1       0.72      0.79      0.75     10172
#
#     accuracy                           0.83     30000
#    macro avg       0.80      0.82      0.81     30000
# weighted avg       0.83      0.83      0.83     30000

# %%
print("F1: %.2f" %f1 , " -- prec: %.2f" %prec, " -- recall: %.2f" %rec, " -- acc: %.2f" %acc)
# Out:
# F1: 0.75  -- prec: 0.72  -- recall: 0.79  -- acc: 0.74
